# %%
# import libraries
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load WHO TB Burden - incidence number 2023 + severity level, enriched with external data + corrections done in EDA
TB_burden_enriched = "df_TB_burden_enriched_new.csv"
df_TB_burden_enriched = pd.read_csv(TB_burden_enriched)
df_TB_burden_enriched
# Out:
#           country_name iso2 iso3  iso_numeric g_whoregion  year  e_pop_num  \
# 0          Afghanistan   AF  AFG            4         EMR  2023   41454760
# 1              Albania   AL  ALB            8         EUR  2023    2811661
# 2              Algeria   DZ  DZA           12         AFR  2023   46164214
# 3       American Samoa   AS  ASM           16         WPR  2023      47521
# 4              Andorra   AD  AND           20         EUR  2023      80854
# ..                 ...  ...  ...          ...         ...   ...        ...
# 209           Viet Nam   VN  VNM          704         WPR  2023  100352197
# 210  Wallis and Futuna   WF  WLF          876         WPR  2023      11377
# 211              Yemen   YE  YEM          887         EMR  2023   39390797
# 212             Zambia   ZM  ZMB          894         AFR  2023   20723959
# 213           Zimbabwe   ZW  ZWE          716         AFR  2023   16340822
#
#      e_inc_num  e_tbhiv_prct  e_inc_tbhiv_num  ...  targets_number      doses  \
# 0        75000          0.03             19.0  ...       2057002.0  1969540.0
# 1          430          1.10              4.0  ...         22887.0    22703.0
# 2        22000          0.83            180.0  ...        936973.0   924725.0
# 3            2          0.37              0.0  ...             NaN        NaN
# 4            5          0.47              0.0  ...             NaN        NaN
# ..         ...           ...              ...  ...             ...        ...
# 209     182000          2.50           4600.0  ...       1267834.0  1205427.0
# 210          0          0.15              0.0  ...             NaN        NaN
# 211      19000          0.72            140.0  ...       1254398.0   802445.0
# 212      59000         32.00          19000.0  ...        877840.0   707320.0
# 213      35000         62.00          21000.0  ...        539232.0   482999.0
#
#      BCG_coverage  population_density  MPI_value  pop_in_MP_percent  \
# 0           95.75             63.8457   0.271721          55.910239
# 1           99.20            102.6226   0.002748           0.703561
# 2           98.69             19.3826   0.005409           1.380835
# 3             NaN            237.6050        NaN                NaN
# 4             NaN            172.0340        NaN                NaN
# ..            ...                 ...        ...                ...
# 209         95.08            320.1956   0.007729           1.919121
# 210           NaN             81.2179        NaN                NaN
# 211         63.97             74.6080   0.245166          48.466429
# 212         80.58             27.8776   0.231685          47.906131
# 213         89.57             42.2407   0.109942          25.800038
#
#     total_smokers_2022_percent  avg_air_pollution_PM2-5_in_2023  \
# 0                         22.7                              NaN
# 1                         21.9                             16.7
# 2                         21.2                             13.8
# 3                          NaN                              NaN
# 4                         36.3                              7.9
# ..                         ...                              ...
# 209                       22.5                             29.6
# 210                        NaN                              NaN
# 211                       21.4                              NaN
# 212                       14.6                             24.1
# 213                       11.3                             33.3
#
#      e_tb_inc_prct tb_severity
# 0         0.180920    Moderate
# 1         0.015293    Very Low
# 2         0.047656    Very Low
# 3         0.004209    Very Low
# 4         0.006184    Very Low
# ..             ...         ...
# 209       0.181361    Moderate
# 210       0.000000    Very Low
# 211       0.048235    Very Low
# 212       0.284695        High
# 213       0.214188    Moderate
#
# [214 rows x 31 columns]

# %%
# Summary of the data: checking data types
column_summary_df_TB_burden_enriched = pd.DataFrame({
    'Column Name': df_TB_burden_enriched.columns,
    'Data Type': df_TB_burden_enriched.dtypes.values,
    'Non-Null Count': df_TB_burden_enriched.notnull().sum().values,
    'Null Count': df_TB_burden_enriched.isnull().sum().values,
    'Data Type': df_TB_burden_enriched.dtypes.values,
    'Percentage Null': df_TB_burden_enriched.isnull().mean().values * 100,
    'Unique Values': df_TB_burden_enriched.nunique().values
})

print(column_summary_df_TB_burden_enriched)
# Out:
#                         Column Name Data Type  Non-Null Count  Null Count  \
# 0                      country_name    object             214           0
# 1                              iso2    object             213           1
# 2                              iso3    object             214           0
# 3                       iso_numeric     int64             214           0
# 4                       g_whoregion    object             214           0
# 5                              year     int64             214           0
# 6                         e_pop_num     int64             214           0
# 7                         e_inc_num     int64             214           0
# 8                      e_tbhiv_prct   float64             214           0
# 9                   e_inc_tbhiv_num   float64             214           0
# 10             e_mort_exc_tbhiv_num   float64             213           1
# 11                 e_mort_tbhiv_num   float64             211           3
# 12                       e_mort_num   float64             204          10
# 13                              cfr   float64             204          10
# 14                          cfr_pct   float64             196          18
# 15                            c_cdr   float64             192          22
# 16                    source_rr_new    object             214           0
# 17                     e_rr_pct_new   float64             214           0
# 18                     e_inc_rr_num     int64             214           0
# 19                  vaccine_antigen    object             205           9
# 20                coverage_category    object             205           9
# 21                   targets_number   float64             161          53
# 22                            doses   float64             157          57
# 23                     BCG_coverage   float64             156          58
# 24               population_density   float64             214           0
# 25                        MPI_value   float64             109         105
# 26                pop_in_MP_percent   float64             109         105
# 27       total_smokers_2022_percent   float64             164          50
# 28  avg_air_pollution_PM2-5_in_2023   float64             131          83
# 29                    e_tb_inc_prct   float64             214           0
# 30                      tb_severity    object             214           0
#
#     Percentage Null  Unique Values
# 0          0.000000            214
# 1          0.467290            213
# 2          0.000000            214
# 3          0.000000            214
# 4          0.000000              6
# 5          0.000000              1
# 6          0.000000            214
# 7          0.000000            152
# 8          0.000000            111
# 9          0.000000            118
# 10         0.467290            135
# 11         1.401869             93
# 12         4.672897            143
# 13         4.672897             40
# 14         8.411215             38
# 15        10.280374             61
# 16         0.000000              5
# 17         0.000000             76
# 18         0.000000            117
# 19         4.205607              1
# 20         4.205607              1
# 21        24.766355            160
# 22        26.635514            157
# 23        27.102804            147
# 24         0.000000            214
# 25        49.065421            109
# 26        49.065421            109
# 27        23.364486            130
# 28        38.785047            110
# 29         0.000000            209
# 30         0.000000              5

# %%
# assign grade numerical values to TB_severity and store in a new TB_severity_level column:
TB_severity_mapping = {"Very Low": 1, "Low": 2, "Moderate": 3, "High": 4, "Critical": 5}
df_TB_burden_enriched["tb_severity_level"] = df_TB_burden_enriched["tb_severity"].map(TB_severity_mapping)
df_TB_burden_enriched.head(50)
# Out:
#                 country_name iso2 iso3  iso_numeric g_whoregion  year  \
# 0                Afghanistan   AF  AFG            4         EMR  2023
# 1                    Albania   AL  ALB            8         EUR  2023
# 2                    Algeria   DZ  DZA           12         AFR  2023
# 3             American Samoa   AS  ASM           16         WPR  2023
# 4                    Andorra   AD  AND           20         EUR  2023
# 5                     Angola   AO  AGO           24         AFR  2023
# 6                   Anguilla   AI  AIA          660         AMR  2023
# 7        Antigua and Barbuda   AG  ATG           28         AMR  2023
# 8                  Argentina   AR  ARG           32         AMR  2023
# 9                    Armenia   AM  ARM           51         EUR  2023
# 10                     Aruba   AW  ABW          533         AMR  2023
# 11                 Australia   AU  AUS           36         WPR  2023
# 12                   Austria   AT  AUT           40         EUR  2023
# 13                Azerbaijan   AZ  AZE           31         EUR  2023
# 14                   Bahamas   BS  BHS           44         AMR  2023
# 15                   Bahrain   BH  BHR           48         EMR  2023
# 16                Bangladesh   BD  BGD           50         SEA  2023
# 17                  Barbados   BB  BRB           52         AMR  2023
# 18                   Belarus   BY  BLR          112         EUR  2023
# 19                   Belgium   BE  BEL           56         EUR  2023
# 20                    Belize   BZ  BLZ           84         AMR  2023
# 21                     Benin   BJ  BEN          204         AFR  2023
# 22                   Bermuda   BM  BMU           60         AMR  2023
# 23                    Bhutan   BT  BTN           64         SEA  2023
# 24                   Bolivia   BO  BOL           68         AMR  2023
# 25    Bosnia and Herzegovina   BA  BIH           70         EUR  2023
# 26                  Botswana   BW  BWA           72         AFR  2023
# 27                    Brazil   BR  BRA           76         AMR  2023
# 28    British Virgin Islands   VG  VGB           92         AMR  2023
# 29         Brunei Darussalam   BN  BRN           96         WPR  2023
# 30                  Bulgaria   BG  BGR          100         EUR  2023
# 31              Burkina Faso   BF  BFA          854         AFR  2023
# 32                   Burundi   BI  BDI          108         AFR  2023
# 33                Cabo Verde   CV  CPV          132         AFR  2023
# 34                  Cambodia   KH  KHM          116         WPR  2023
# 35                  Cameroon   CM  CMR          120         AFR  2023
# 36                    Canada   CA  CAN          124         AMR  2023
# 37            Cayman Islands   KY  CYM          136         AMR  2023
# 38  Central African Republic   CF  CAF          140         AFR  2023
# 39                      Chad   TD  TCD          148         AFR  2023
# 40                     Chile   CL  CHL          152         AMR  2023
# 41                     China   CN  CHN          156         WPR  2023
# 42      China, Hong Kong SAR   HK  HKG          344         WPR  2023
# 43          China, Macao SAR   MO  MAC          446         WPR  2023
# 44                  Colombia   CO  COL          170         AMR  2023
# 45                   Comoros   KM  COM          174         AFR  2023
# 46                     Congo   CG  COG          178         AFR  2023
# 47              Cook Islands   CK  COK          184         WPR  2023
# 48                Costa Rica   CR  CRI          188         AMR  2023
# 49             Côte d'Ivoire   CI  CIV          384         AFR  2023
#
#      e_pop_num  e_inc_num  e_tbhiv_prct  e_inc_tbhiv_num  ...      doses  \
# 0     41454760      75000          0.03             19.0  ...  1969540.0
# 1      2811661        430          1.10              4.0  ...    22703.0
# 2     46164214      22000          0.83            180.0  ...   924725.0
# 3        47521          2          0.37              0.0  ...        NaN
# 4        80854          5          0.47              0.0  ...        NaN
# 5     36749909     125000          7.90           9800.0  ...  1163980.0
# 6        14413          3          8.20              0.0  ...      167.0
# 7        93317          1          1.20              0.0  ...        NaN
# 8     45538407      16000          6.10            980.0  ...   339846.0
# 9      2943390        720         11.00             83.0  ...    32287.0
# 10      107935          4          0.29              0.0  ...        NaN
# 11    26451115       1600          1.80             30.0  ...        NaN
# 12     9130417        470          2.20             10.0  ...        NaN
# 13    10318209       7400          1.50            110.0  ...   100810.0
# 14      399445         31         33.00             10.0  ...        NaN
# 15     1569662        190          5.10             10.0  ...     5229.0
# 16   171466988     379000          0.20            740.0  ...  4229615.0
# 17      282338          2         17.00              0.0  ...        NaN
# 18     9115675       2500          8.20            200.0  ...    58846.0
# 19    11712891        880          3.70             33.0  ...        NaN
# 20      411105        110         15.00             17.0  ...     5480.0
# 21    14111025       7100         12.00            860.0  ...   512705.0
# 22       64703          2          0.00              0.0  ...        NaN
# 23      786378       1300          0.69              9.0  ...     9516.0
# 24    12244156      13000          5.60            710.0  ...   175255.0
# 25     3185078        750          0.20              2.0  ...    24708.0
# 26     2480246       6000         45.00           2600.0  ...    43649.0
# 27   211140731     103000         19.00          20000.0  ...  2004532.0
# 28       38989          0          0.00              0.0  ...        NaN
# 29      458954        300          2.00              6.0  ...     6088.0
# 30     6795799       1100          0.47              5.0  ...    46727.0
# 31    23025766       9800          6.50            640.0  ...   902733.0
# 32    13689449      13000          5.90            750.0  ...   431149.0
# 33      522332        250         11.00             27.0  ...        NaN
# 34    17423885      58000          1.30            740.0  ...   316632.0
# 35    28372684      43000         17.00           7100.0  ...   962500.0
# 36    39299105       2300          2.80             65.0  ...        NaN
# 37       73035          3          0.00              0.0  ...      725.0
# 38     5152418      28000         23.00           6400.0  ...   207545.0
# 39    19319066      27000         11.00           3000.0  ...   974906.0
# 40    19658834       3600          9.30            340.0  ...   169655.0
# 41  1422584930     741000          1.30           9500.0  ...  8352584.0
# 42     7442727       3700          0.79             29.0  ...    32150.0
# 43      713923        360          1.00              4.0  ...     4188.0
# 44    52321145      24000         15.00           3500.0  ...   517672.0
# 45      850387        300          2.00              6.0  ...    18760.0
# 46     6182884      23000         30.00           6900.0  ...   171841.0
# 47       14227          5          0.00              0.0  ...      197.0
# 48     5105518        510         11.00             58.0  ...    46575.0
# 49    31165656      37000         13.00           4700.0  ...  1048209.0
#
#     BCG_coverage  population_density  MPI_value  pop_in_MP_percent  \
# 0          95.75             63.8457   0.271721          55.910239
# 1          99.20            102.6226   0.002748           0.703561
# 2          98.69             19.3826   0.005409           1.380835
# 3            NaN            237.6050        NaN                NaN
# 4            NaN            172.0340        NaN                NaN
# 5          95.52             29.4777   0.282435          51.104112
# 6         109.87            163.7500        NaN                NaN
# 7            NaN            212.0807        NaN                NaN
# 8          68.77             16.3114   0.001469           0.432323
# 9          98.54            103.4076   0.000690           0.190553
# 10           NaN            599.6583        NaN                NaN
# 11           NaN              3.4431        NaN                NaN
# 12           NaN            110.6464        NaN                NaN
# 13         95.45            124.8301        NaN                NaN
# 14           NaN             74.5503        NaN                NaN
# 15        100.00           2004.6814        NaN                NaN
# 16        125.90           1317.2543   0.104060          24.640573
# 17           NaN            656.5953   0.008529           2.491337
# 18         97.75             44.9247        NaN                NaN
# 19           NaN            386.8450        NaN                NaN
# 20         87.98             18.0230   0.017109           4.303543
# 21        114.39            125.1422   0.367675          66.798888
# 22           NaN           1198.1111        NaN                NaN
# 23         96.64             20.4820        NaN                NaN
# 24         73.73             11.3027   0.037754           9.060217
# 25         95.35             62.2121   0.008307           2.190133
# 26         74.63              4.3764   0.072639          17.219296
# 27         79.10             25.2617   0.016346           3.841927
# 28           NaN            253.1494        NaN                NaN
# 29        100.00             79.6095        NaN                NaN
# 30         96.51             62.6942        NaN                NaN
# 31        101.30             84.1585        NaN                NaN
# 32         70.04            527.5318   0.408861          75.097473
# 33           NaN            129.6105        NaN                NaN
# 34         91.30             96.2459   0.070368          16.644697
# 35         93.44             60.8791   0.232060          43.591636
# 36           NaN              4.3217        NaN                NaN
# 37         94.77            303.0622        NaN                NaN
# 38         92.66              8.2706   0.461348          80.414178
# 39        109.41             15.3423   0.517011          84.174947
# 40         98.22             26.1089        NaN                NaN
# 41         98.84            148.1859   0.016067           3.885020
# 42         96.75           6772.2789        NaN                NaN
# 43         99.50          22309.7344        NaN                NaN
# 44         86.76             46.5620   0.019657           4.846250
# 45         71.87            456.9516   0.180771          37.264919
# 46         67.12             46.6640   0.331189          64.517980
# 47         98.99             59.2583        NaN                NaN
# 48         92.77             99.9907   0.002006           0.540467
# 49         87.26             98.0052   0.235871          46.067484
#
#     total_smokers_2022_percent avg_air_pollution_PM2-5_in_2023  e_tb_inc_prct  \
# 0                         22.7                             NaN       0.180920
# 1                         21.9                            16.7       0.015293
# 2                         21.2                            13.8       0.047656
# 3                          NaN                             NaN       0.004209
# 4                         36.3                             7.9       0.006184
# 5                          NaN                             7.8       0.340137
# 6                          NaN                             7.4       0.020815
# 7                          NaN                             NaN       0.001072
# 8                         23.8                             9.2       0.035135
# 9                         24.9                            26.4       0.024462
# 10                         NaN                             NaN       0.003706
# 11                        13.1                             4.5       0.006049
# 12                        24.9                             9.6       0.005148
# 13                        19.6                            18.8       0.071718
# 14                        11.3                             5.2       0.007761
# 15                        15.0                            39.2       0.012105
# 16                        32.9                            79.9       0.221034
# 17                         7.0                             NaN       0.000708
# 18                        30.1                             NaN       0.027425
# 19                        26.7                             9.4       0.007513
# 20                         8.8                             8.3       0.026757
# 21                         6.3                             NaN       0.050315
# 22                         NaN                             4.1       0.003091
# 23                        18.7                             NaN       0.165315
# 24                        12.4                            12.6       0.106173
# 25                        36.2                            27.5       0.023547
# 26                        18.7                             NaN       0.241911
# 27                        12.2                            12.6       0.048783
# 28                         NaN                             NaN       0.000000
# 29                        16.4                             NaN       0.065366
# 30                        39.5                            13.2       0.016186
# 31                        14.3                            46.6       0.042561
# 32                        11.2                             NaN       0.094964
# 33                        11.0                             NaN       0.047862
# 34                        17.2                            22.8       0.332876
# 35                         6.5                            24.0       0.151554
# 36                        12.0                            10.3       0.005853
# 37                         NaN                             NaN       0.004108
# 38                         NaN                             NaN       0.543434
# 39                         7.4                             NaN       0.139758
# 40                        28.7                            18.8       0.018312
# 41                        23.4                            32.5       0.052088
# 42                         NaN                            15.6       0.049713
# 43                         NaN                            16.2       0.050426
# 44                         8.2                            14.1       0.045871
# 45                        17.2                             NaN       0.035278
# 46                        12.2                            40.8       0.371995
# 47                        27.0                             NaN       0.035144
# 48                         8.9                             6.1       0.009989
# 49                         8.8                            16.6       0.118720
#
#     tb_severity tb_severity_level
# 0      Moderate                 3
# 1      Very Low                 1
# 2      Very Low                 1
# 3      Very Low                 1
# 4      Very Low                 1
# 5          High                 4
# 6      Very Low                 1
# 7      Very Low                 1
# 8      Very Low                 1
# 9      Very Low                 1
# 10     Very Low                 1
# 11     Very Low                 1
# 12     Very Low                 1
# 13          Low                 2
# 14     Very Low                 1
# 15     Very Low                 1
# 16     Moderate                 3
# 17     Very Low                 1
# 18     Very Low                 1
# 19     Very Low                 1
# 20     Very Low                 1
# 21          Low                 2
# 22     Very Low                 1
# 23     Moderate                 3
# 24     Moderate                 3
# 25     Very Low                 1
# 26     Moderate                 3
# 27     Very Low                 1
# 28     Very Low                 1
# 29          Low                 2
# 30     Very Low                 1
# 31     Very Low                 1
# 32          Low                 2
# 33     Very Low                 1
# 34         High                 4
# 35     Moderate                 3
# 36     Very Low                 1
# 37     Very Low                 1
# 38     Critical                 5
# 39     Moderate                 3
# 40     Very Low                 1
# 41          Low                 2
# 42     Very Low                 1
# 43          Low                 2
# 44     Very Low                 1
# 45     Very Low                 1
# 46         High                 4
# 47     Very Low                 1
# 48     Very Low                 1
# 49     Moderate                 3
#
# [50 rows x 32 columns]

# %%
# Select features and target columns: 10 features + 2 targets
df_TB_burden_selected = df_TB_burden_enriched[["e_tbhiv_prct", "cfr_pct", "c_cdr", "e_rr_pct_new", "BCG_coverage", "population_density","MPI_value",
                                               "pop_in_MP_percent", "total_smokers_2022_percent", "avg_air_pollution_PM2-5_in_2023", "e_tb_inc_prct", "tb_severity", "tb_severity_level"]]
df_TB_burden_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   e_tbhiv_prct                     214 non-null    float64
#  1   cfr_pct                          196 non-null    float64
#  2   c_cdr                            192 non-null    float64
#  3   e_rr_pct_new                     214 non-null    float64
#  4   BCG_coverage                     156 non-null    float64
#  5   population_density               214 non-null    float64
#  6   MPI_value                        109 non-null    float64
#  7   pop_in_MP_percent                109 non-null    float64
#  8   total_smokers_2022_percent       164 non-null    float64
#  9   avg_air_pollution_PM2-5_in_2023  131 non-null    float64
#  10  e_tb_inc_prct                    214 non-null    float64
#  11  tb_severity                      214 non-null    object
#  12  tb_severity_level                214 non-null    int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 21.9+ KB

# %%
# Select feature columns: 9 features selected, 1 dropped
df_TB_burden_selected = df_TB_burden_selected.drop(["pop_in_MP_percent"], axis=1)
df_TB_burden_selected.info()
