# %% [raw]
# Obtain air pollution values per country from 2023 from Open Meteo
# Then calculate Air pollution Index

# %%
import pandas as pd
import requests

# %%
# load country longitude and latitude coordinates from csv
# https://developers.google.com/public-data/docs/canonical/countries_csv 
countries = "countries_coordinates.csv"
df_countries = pd.read_csv(countries)
df_countries
# Out:
#     country_abbr   latitude  longitude          country_name
# 0             AD  42.546245   1.601554               Andorra
# 1             AE  23.424076  53.847818  United Arab Emirates
# 2             AF  33.939110  67.709953           Afghanistan
# 3             AG  17.060816 -61.796428   Antigua and Barbuda
# 4             AI  18.220554 -63.068615              Anguilla
# ..           ...        ...        ...                   ...
# 239           YE  15.552727  48.516388                 Yemen
# 240           YT -12.827500  45.166244               Mayotte
# 241           ZA -30.559482  22.937506          South Africa
# 242           ZM -13.133897  27.849332                Zambia
# 243           ZW -19.015438  29.154857              Zimbabwe
#
# [244 rows x 4 columns]

# %%
# check if the latitude and longitude values from df_countries are correctly passed to the get_air_quality function
# Modify the apply() function to print the values before they are passed:

df_countries[['avg_pm10', 'avg_pm2_5', 'avg_no2', 'avg_so2', 'avg_o3']] = df_countries.apply(
    lambda row: print(f"Fetching data for: {row['country_name']} - Lat: {row['latitude']}, Lon: {row['longitude']}") or get_air_quality(row['latitude'], row['longitude']), 
    axis=1, result_type='expand'
)
# Out:
# Fetching data for: Andorra - Lat: 42.546245, Lon: 1.601554
# API request for coordinates: Lat=42.546245, Lon=1.601554
# Received data for Lat=42.546245, Lon=1.601554: {'latitude': 42.5, 'longitude': 1.6000004, 'generationtime_ms': 0.0020265579223632812, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Andorra', 'timezone_abbreviation': 'GMT+1', 'elevation': 1943.0}
# Fetching data for: United Arab Emirates - Lat: 23.424076, Lon: 53.847818
# API request for coordinates: Lat=23.424076, Lon=53.847818
# Received data for Lat=23.424076, Lon=53.847818: {'latitude': 23.400002, 'longitude': 53.800003, 'generationtime_ms': 0.0026226043701171875, 'utc_offset_seconds': 14400, 'timezone': 'Asia/Dubai', 'timezone_abbreviation': 'GMT+4', 'elevation': 155.0}
# Fetching data for: Afghanistan - Lat: 33.93911, Lon: 67.709953
# API request for coordinates: Lat=33.93911, Lon=67.709953
# Received data for Lat=33.93911, Lon=67.709953: {'latitude': 33.9, 'longitude': 67.7, 'generationtime_ms': 0.0025033950805664062, 'utc_offset_seconds': 16200, 'timezone': 'Asia/Kabul', 'timezone_abbreviation': 'GMT+4:30', 'elevation': 3777.0}
# Fetching data for: Antigua and Barbuda - Lat: 17.060816, Lon: -61.796428
# API request for coordinates: Lat=17.060816, Lon=-61.796428
# Received data for Lat=17.060816, Lon=-61.796428: {'latitude': 17.099998, 'longitude': -61.799995, 'generationtime_ms': 0.0045299530029296875, 'utc_offset_seconds': -14400, 'timezone': 'America/Antigua', 'timezone_abbreviation': 'GMT-4', 'elevation': 67.0}
# Fetching data for: Anguilla - Lat: 18.220554, Lon: -63.068615
# API request for coordinates: Lat=18.220554, Lon=-63.068615
# Received data for Lat=18.220554, Lon=-63.068615: {'latitude': 18.200005, 'longitude': -63.1, 'generationtime_ms': 0.0045299530029296875, 'utc_offset_seconds': -14400, 'timezone': 'America/Anguilla', 'timezone_abbreviation': 'GMT-4', 'elevation': 0.0}
# Fetching data for: Albania - Lat: 41.153332, Lon: 20.168331
# API request for coordinates: Lat=41.153332, Lon=20.168331
# Received data for Lat=41.153332, Lon=20.168331: {'latitude': 41.2, 'longitude': 20.2, 'generationtime_ms': 0.0015497207641601562, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Tirane', 'timezone_abbreviation': 'GMT+1', 'elevation': 149.0}
# Fetching data for: Armenia - Lat: 40.069099, Lon: 45.038189
# API request for coordinates: Lat=40.069099, Lon=45.038189
# Received data for Lat=40.069099, Lon=45.038189: {'latitude': 40.1, 'longitude': 45.0, 'generationtime_ms': 0.0035762786865234375, 'utc_offset_seconds': 14400, 'timezone': 'Asia/Yerevan', 'timezone_abbreviation': 'GMT+4', 'elevation': 2769.0}
# Fetching data for: Netherlands Antilles - Lat: 12.226079, Lon: -69.060087
# API request for coordinates: Lat=12.226079, Lon=-69.060087
# Received data for Lat=12.226079, Lon=-69.060087: {'latitude': 12.200005, 'longitude': -69.1, 'generationtime_ms': 0.002384185791015625, 'utc_offset_seconds': -14400, 'timezone': 'America/Curacao', 'timezone_abbreviation': 'GMT-4', 'elevation': 41.0}
# Fetching data for: Angola - Lat: -11.202692, Lon: 17.873887
# API request for coordinates: Lat=-11.202692, Lon=17.873887
# Received data for Lat=-11.202692, Lon=17.873887: {'latitude': -11.199997, 'longitude': 17.90001, 'generationtime_ms': 0.0019073486328125, 'utc_offset_seconds': 3600, 'timezone': 'Africa/Luanda', 'timezone_abbreviation': 'GMT+1', 'elevation': 1135.0}
# Fetching data for: Antarctica - Lat: -75.250973, Lon: -0.071389
# API request for coordinates: Lat=-75.250973, Lon=-0.071389
# Received data for Lat=-75.250973, Lon=-0.071389: {'latitude': -75.3, 'longitude': -0.099990845, 'generationtime_ms': 0.0064373016357421875, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Johannesburg', 'timezone_abbreviation': 'GMT+2', 'elevation': 2855.0}
# Fetching data for: Argentina - Lat: -38.416097, Lon: -63.616672
# API request for coordinates: Lat=-38.416097, Lon=-63.616672
# Received data for Lat=-38.416097, Lon=-63.616672: {'latitude': -38.399998, 'longitude': -63.6, 'generationtime_ms': 0.0040531158447265625, 'utc_offset_seconds': -10800, 'timezone': 'America/Argentina/Salta', 'timezone_abbreviation': 'GMT-3', 'elevation': 113.0}
# Fetching data for: American Samoa - Lat: -14.270972, Lon: -170.132217
# API request for coordinates: Lat=-14.270972, Lon=-170.132217
# Received data for Lat=-14.270972, Lon=-170.132217: {'latitude': -14.299995, 'longitude': -170.1, 'generationtime_ms': 0.0027418136596679688, 'utc_offset_seconds': -39600, 'timezone': 'Etc/GMT+11', 'timezone_abbreviation': 'GMT-11', 'elevation': 0.0}
# Fetching data for: Austria - Lat: 47.516231, Lon: 14.550072
# API request for coordinates: Lat=47.516231, Lon=14.550072
# Received data for Lat=47.516231, Lon=14.550072: {'latitude': 47.5, 'longitude': 14.600002, 'generationtime_ms': 0.0022649765014648438, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Vienna', 'timezone_abbreviation': 'GMT+1', 'elevation': 1191.0}
# Fetching data for: Australia - Lat: -25.274398, Lon: 133.775136
# API request for coordinates: Lat=-25.274398, Lon=133.775136
# Received data for Lat=-25.274398, Lon=133.775136: {'latitude': -25.299995, 'longitude': 133.80002, 'generationtime_ms': 0.00476837158203125, 'utc_offset_seconds': 34200, 'timezone': 'Australia/Darwin', 'timezone_abbreviation': 'GMT+9:30', 'elevation': 396.0}
# Fetching data for: Aruba - Lat: 12.52111, Lon: -69.968338
# API request for coordinates: Lat=12.52111, Lon=-69.968338
# Received data for Lat=12.52111, Lon=-69.968338: {'latitude': 12.5, 'longitude': -70.0, 'generationtime_ms': 0.0019073486328125, 'utc_offset_seconds': -14400, 'timezone': 'America/Aruba', 'timezone_abbreviation': 'GMT-4', 'elevation': 59.0}
# Fetching data for: Azerbaijan - Lat: 40.143105, Lon: 47.576927
# API request for coordinates: Lat=40.143105, Lon=47.576927
# Received data for Lat=40.143105, Lon=47.576927: {'latitude': 40.100006, 'longitude': 47.600006, 'generationtime_ms': 0.0034570693969726562, 'utc_offset_seconds': 14400, 'timezone': 'Asia/Baku', 'timezone_abbreviation': 'GMT+4', 'elevation': -2.0}
# Fetching data for: Bosnia and Herzegovina - Lat: 43.915886, Lon: 17.679076
# API request for coordinates: Lat=43.915886, Lon=17.679076
# Received data for Lat=43.915886, Lon=17.679076: {'latitude': 43.9, 'longitude': 17.7, 'generationtime_ms': 0.0040531158447265625, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Sarajevo', 'timezone_abbreviation': 'GMT+1', 'elevation': 1750.0}
# Fetching data for: Barbados - Lat: 13.193887, Lon: -59.543198
# API request for coordinates: Lat=13.193887, Lon=-59.543198
# Received data for Lat=13.193887, Lon=-59.543198: {'latitude': 13.200005, 'longitude': -59.5, 'generationtime_ms': 0.00762939453125, 'utc_offset_seconds': -14400, 'timezone': 'America/Barbados', 'timezone_abbreviation': 'GMT-4', 'elevation': 321.0}
# Fetching data for: Bangladesh - Lat: 23.684994, Lon: 90.356331
# API request for coordinates: Lat=23.684994, Lon=90.356331
# Received data for Lat=23.684994, Lon=90.356331: {'latitude': 23.700005, 'longitude': 90.399994, 'generationtime_ms': 0.00286102294921875, 'utc_offset_seconds': 21600, 'timezone': 'Asia/Dhaka', 'timezone_abbreviation': 'GMT+6', 'elevation': 3.0}
# Fetching data for: Belgium - Lat: 50.503887, Lon: 4.469936
# API request for coordinates: Lat=50.503887, Lon=4.469936
# Received data for Lat=50.503887, Lon=4.469936: {'latitude': 50.5, 'longitude': 4.5, 'generationtime_ms': 0.0013113021850585938, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Brussels', 'timezone_abbreviation': 'GMT+1', 'elevation': 142.0}
# Fetching data for: Burkina Faso - Lat: 12.238333, Lon: -1.561593
# API request for coordinates: Lat=12.238333, Lon=-1.561593
# Received data for Lat=12.238333, Lon=-1.561593: {'latitude': 12.200005, 'longitude': -1.5999908, 'generationtime_ms': 0.0040531158447265625, 'utc_offset_seconds': 0, 'timezone': 'Africa/Ouagadougou', 'timezone_abbreviation': 'GMT', 'elevation': 297.0}
# Fetching data for: Bulgaria - Lat: 42.733883, Lon: 25.48583
# API request for coordinates: Lat=42.733883, Lon=25.48583
# Received data for Lat=42.733883, Lon=25.48583: {'latitude': 42.7, 'longitude': 25.5, 'generationtime_ms': 0.005602836608886719, 'utc_offset_seconds': 7200, 'timezone': 'Europe/Sofia', 'timezone_abbreviation': 'GMT+2', 'elevation': 1131.0}
# Fetching data for: Bahrain - Lat: 25.930414, Lon: 50.637772
# API request for coordinates: Lat=25.930414, Lon=50.637772
# Received data for Lat=25.930414, Lon=50.637772: {'latitude': 25.900002, 'longitude': 50.600006, 'generationtime_ms': 0.0016689300537109375, 'utc_offset_seconds': 10800, 'timezone': 'Asia/Bahrain', 'timezone_abbreviation': 'GMT+3', 'elevation': 0.0}
# Fetching data for: Burundi - Lat: -3.373056, Lon: 29.918886
# API request for coordinates: Lat=-3.373056, Lon=29.918886
# Received data for Lat=-3.373056, Lon=29.918886: {'latitude': -3.4000015, 'longitude': 29.90001, 'generationtime_ms': 0.0025033950805664062, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Bujumbura', 'timezone_abbreviation': 'GMT+2', 'elevation': 1711.0}
# Fetching data for: Benin - Lat: 9.30769, Lon: 2.315834
# API request for coordinates: Lat=9.30769, Lon=2.315834
# Received data for Lat=9.30769, Lon=2.315834: {'latitude': 9.300003, 'longitude': 2.300003, 'generationtime_ms': 0.0019073486328125, 'utc_offset_seconds': 3600, 'timezone': 'Africa/Porto-Novo', 'timezone_abbreviation': 'GMT+1', 'elevation': 340.0}
# Fetching data for: Bermuda - Lat: 32.321384, Lon: -64.75737
# API request for coordinates: Lat=32.321384, Lon=-64.75737
# Received data for Lat=32.321384, Lon=-64.75737: {'latitude': 32.300003, 'longitude': -64.799995, 'generationtime_ms': 0.00286102294921875, 'utc_offset_seconds': -14400, 'timezone': 'Atlantic/Bermuda', 'timezone_abbreviation': 'GMT-4', 'elevation': 0.0}
# Fetching data for: Brunei - Lat: 4.535277, Lon: 114.727669
# API request for coordinates: Lat=4.535277, Lon=114.727669
# Received data for Lat=4.535277, Lon=114.727669: {'latitude': 4.5, 'longitude': 114.70001, 'generationtime_ms': 0.006556510925292969, 'utc_offset_seconds': 28800, 'timezone': 'Asia/Brunei', 'timezone_abbreviation': 'GMT+8', 'elevation': 61.0}
# Fetching data for: Bolivia - Lat: -16.290154, Lon: -63.588653
# API request for coordinates: Lat=-16.290154, Lon=-63.588653
# Received data for Lat=-16.290154, Lon=-63.588653: {'latitude': -16.299995, 'longitude': -63.6, 'generationtime_ms': 0.003337860107421875, 'utc_offset_seconds': -14400, 'timezone': 'America/La_Paz', 'timezone_abbreviation': 'GMT-4', 'elevation': 200.0}
# Fetching data for: Brazil - Lat: -14.235004, Lon: -51.92528
# API request for coordinates: Lat=-14.235004, Lon=-51.92528
# Received data for Lat=-14.235004, Lon=-51.92528: {'latitude': -14.199997, 'longitude': -51.899994, 'generationtime_ms': 0.0030994415283203125, 'utc_offset_seconds': -14400, 'timezone': 'America/Cuiaba', 'timezone_abbreviation': 'GMT-4', 'elevation': 259.0}
# Fetching data for: Bahamas - Lat: 25.03428, Lon: -77.39628
# API request for coordinates: Lat=25.03428, Lon=-77.39628
# Received data for Lat=25.03428, Lon=-77.39628: {'latitude': 25.0, 'longitude': -77.4, 'generationtime_ms': 0.0029802322387695312, 'utc_offset_seconds': -18000, 'timezone': 'America/Nassau', 'timezone_abbreviation': 'GMT-5', 'elevation': 5.0}
# Fetching data for: Bhutan - Lat: 27.514162, Lon: 90.433601
# API request for coordinates: Lat=27.514162, Lon=90.433601
# Received data for Lat=27.514162, Lon=90.433601: {'latitude': 27.5, 'longitude': 90.399994, 'generationtime_ms': 0.00476837158203125, 'utc_offset_seconds': 21600, 'timezone': 'Asia/Thimphu', 'timezone_abbreviation': 'GMT+6', 'elevation': 2583.0}
# Fetching data for: Bouvet Island - Lat: -54.423199, Lon: 3.413194
# API request for coordinates: Lat=-54.423199, Lon=3.413194
# Received data for Lat=-54.423199, Lon=3.413194: {'latitude': -54.399998, 'longitude': 3.4000092, 'generationtime_ms': 0.007987022399902344, 'utc_offset_seconds': 0, 'timezone': 'Etc/GMT', 'timezone_abbreviation': 'GMT', 'elevation': 222.0}
# Fetching data for: Botswana - Lat: -22.328474, Lon: 24.684866
# API request for coordinates: Lat=-22.328474, Lon=24.684866
# Received data for Lat=-22.328474, Lon=24.684866: {'latitude': -22.299995, 'longitude': 24.699997, 'generationtime_ms': 0.007033348083496094, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Gaborone', 'timezone_abbreviation': 'GMT+2', 'elevation': 1015.0}
# Fetching data for: Belarus - Lat: 53.709807, Lon: 27.953389
# API request for coordinates: Lat=53.709807, Lon=27.953389
# Received data for Lat=53.709807, Lon=27.953389: {'latitude': 53.7, 'longitude': 28.0, 'generationtime_ms': 0.0030994415283203125, 'utc_offset_seconds': 10800, 'timezone': 'Europe/Minsk', 'timezone_abbreviation': 'GMT+3', 'elevation': 190.0}
# Fetching data for: Belize - Lat: 17.189877, Lon: -88.49765
# API request for coordinates: Lat=17.189877, Lon=-88.49765
# Received data for Lat=17.189877, Lon=-88.49765: {'latitude': 17.200005, 'longitude': -88.5, 'generationtime_ms': 0.0034570693969726562, 'utc_offset_seconds': -21600, 'timezone': 'America/Belize', 'timezone_abbreviation': 'GMT-6', 'elevation': 37.0}
# Fetching data for: Canada - Lat: 56.130366, Lon: -106.346771
# API request for coordinates: Lat=56.130366, Lon=-106.346771
# Received data for Lat=56.130366, Lon=-106.346771: {'latitude': 56.100006, 'longitude': -106.299995, 'generationtime_ms': 0.00858306884765625, 'utc_offset_seconds': -21600, 'timezone': 'America/Regina', 'timezone_abbreviation': 'GMT-6', 'elevation': 478.0}
# Fetching data for: Cocos [Keeling] Islands - Lat: -12.164165, Lon: 96.870956
# API request for coordinates: Lat=-12.164165, Lon=96.870956
# Received data for Lat=-12.164165, Lon=96.870956: {'latitude': -12.199997, 'longitude': 96.899994, 'generationtime_ms': 0.0019073486328125, 'utc_offset_seconds': 23400, 'timezone': 'Indian/Cocos', 'timezone_abbreviation': 'GMT+6:30', 'elevation': 0.0}
# Fetching data for: Congo [DRC] - Lat: -4.038333, Lon: 21.758664
# API request for coordinates: Lat=-4.038333, Lon=21.758664
# Received data for Lat=-4.038333, Lon=21.758664: {'latitude': -4.0, 'longitude': 21.800003, 'generationtime_ms': 0.0034570693969726562, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Lubumbashi', 'timezone_abbreviation': 'GMT+2', 'elevation': 420.0}
# Fetching data for: Central African Republic - Lat: 6.611111, Lon: 20.939444
# API request for coordinates: Lat=6.611111, Lon=20.939444
# Received data for Lat=6.611111, Lon=20.939444: {'latitude': 6.5999985, 'longitude': 20.90001, 'generationtime_ms': 0.0022649765014648438, 'utc_offset_seconds': 3600, 'timezone': 'Africa/Bangui', 'timezone_abbreviation': 'GMT+1', 'elevation': 621.0}
# Fetching data for: Congo [Republic] - Lat: -0.228021, Lon: 15.827659
# API request for coordinates: Lat=-0.228021, Lon=15.827659
# Received data for Lat=-0.228021, Lon=15.827659: {'latitude': -0.19999695, 'longitude': 15.800003, 'generationtime_ms': 0.00286102294921875, 'utc_offset_seconds': 3600, 'timezone': 'Africa/Brazzaville', 'timezone_abbreviation': 'GMT+1', 'elevation': 331.0}
# Fetching data for: Switzerland - Lat: 46.818188, Lon: 8.227512
# API request for coordinates: Lat=46.818188, Lon=8.227512
# Received data for Lat=46.818188, Lon=8.227512: {'latitude': 46.800003, 'longitude': 8.200001, 'generationtime_ms': 0.004172325134277344, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Zurich', 'timezone_abbreviation': 'GMT+1', 'elevation': 1507.0}
# Fetching data for: Cote d'Ivoire - Lat: 7.539989, Lon: -5.54708
# API request for coordinates: Lat=7.539989, Lon=-5.54708
# Received data for Lat=7.539989, Lon=-5.54708: {'latitude': 7.5, 'longitude': -5.5, 'generationtime_ms': 0.003933906555175781, 'utc_offset_seconds': 0, 'timezone': 'Africa/Abidjan', 'timezone_abbreviation': 'GMT', 'elevation': 237.0}
# Fetching data for: Cook Islands - Lat: -21.236736, Lon: -159.777671
# API request for coordinates: Lat=-21.236736, Lon=-159.777671
# Received data for Lat=-21.236736, Lon=-159.777671: {'latitude': -21.199997, 'longitude': -159.8, 'generationtime_ms': 0.0032186508178710938, 'utc_offset_seconds': -36000, 'timezone': 'Pacific/Rarotonga', 'timezone_abbreviation': 'GMT-10', 'elevation': 306.0}
# Fetching data for: Chile - Lat: -35.675147, Lon: -71.542969
# API request for coordinates: Lat=-35.675147, Lon=-71.542969
# Received data for Lat=-35.675147, Lon=-71.542969: {'latitude': -35.7, 'longitude': -71.5, 'generationtime_ms': 0.0035762786865234375, 'utc_offset_seconds': -10800, 'timezone': 'America/Santiago', 'timezone_abbreviation': 'GMT-3', 'elevation': 187.0}
# Fetching data for: Cameroon - Lat: 7.369722, Lon: 12.354722
# API request for coordinates: Lat=7.369722, Lon=12.354722
# Received data for Lat=7.369722, Lon=12.354722: {'latitude': 7.4000015, 'longitude': 12.400009, 'generationtime_ms': 0.00476837158203125, 'utc_offset_seconds': 3600, 'timezone': 'Africa/Douala', 'timezone_abbreviation': 'GMT+1', 'elevation': 1299.0}
# Fetching data for: China - Lat: 35.86166, Lon: 104.195397
# API request for coordinates: Lat=35.86166, Lon=104.195397
# Received data for Lat=35.86166, Lon=104.195397: {'latitude': 35.9, 'longitude': 104.20001, 'generationtime_ms': 0.0015497207641601562, 'utc_offset_seconds': 28800, 'timezone': 'Asia/Shanghai', 'timezone_abbreviation': 'GMT+8', 'elevation': 1836.0}
# Fetching data for: Colombia - Lat: 4.570868, Lon: -74.297333
# API request for coordinates: Lat=4.570868, Lon=-74.297333
# Received data for Lat=4.570868, Lon=-74.297333: {'latitude': 4.5999985, 'longitude': -74.299995, 'generationtime_ms': 0.0034570693969726562, 'utc_offset_seconds': -18000, 'timezone': 'America/Bogota', 'timezone_abbreviation': 'GMT-5', 'elevation': 2497.0}
# Fetching data for: Costa Rica - Lat: 9.748917, Lon: -83.753428
# API request for coordinates: Lat=9.748917, Lon=-83.753428
# Received data for Lat=9.748917, Lon=-83.753428: {'latitude': 9.700005, 'longitude': -83.799995, 'generationtime_ms': 0.0019073486328125, 'utc_offset_seconds': -21600, 'timezone': 'America/Costa_Rica', 'timezone_abbreviation': 'GMT-6', 'elevation': 1391.0}
# Fetching data for: Cuba - Lat: 21.521757, Lon: -77.781167
# API request for coordinates: Lat=21.521757, Lon=-77.781167
# Received data for Lat=21.521757, Lon=-77.781167: {'latitude': 21.5, 'longitude': -77.799995, 'generationtime_ms': 0.0016689300537109375, 'utc_offset_seconds': -18000, 'timezone': 'America/Havana', 'timezone_abbreviation': 'GMT-5', 'elevation': 71.0}
# Fetching data for: Cape Verde - Lat: 16.002082, Lon: -24.013197
# API request for coordinates: Lat=16.002082, Lon=-24.013197
# Received data for Lat=16.002082, Lon=-24.013197: {'latitude': 16.0, 'longitude': -24.0, 'generationtime_ms': 0.0025033950805664062, 'utc_offset_seconds': -3600, 'timezone': 'Atlantic/Cape_Verde', 'timezone_abbreviation': 'GMT-1', 'elevation': 0.0}
# Fetching data for: Christmas Island - Lat: -10.447525, Lon: 105.690449
# API request for coordinates: Lat=-10.447525, Lon=105.690449
# Received data for Lat=-10.447525, Lon=105.690449: {'latitude': -10.400002, 'longitude': 105.70001, 'generationtime_ms': 0.0022649765014648438, 'utc_offset_seconds': 25200, 'timezone': 'Indian/Christmas', 'timezone_abbreviation': 'GMT+7', 'elevation': 270.0}
# Fetching data for: Cyprus - Lat: 35.126413, Lon: 33.429859
# API request for coordinates: Lat=35.126413, Lon=33.429859
# Received data for Lat=35.126413, Lon=33.429859: {'latitude': 35.1, 'longitude': 33.4, 'generationtime_ms': 0.005602836608886719, 'utc_offset_seconds': 7200, 'timezone': 'Asia/Nicosia', 'timezone_abbreviation': 'GMT+2', 'elevation': 143.0}
# Fetching data for: Czech Republic - Lat: 49.817492, Lon: 15.472962
# API request for coordinates: Lat=49.817492, Lon=15.472962
# Received data for Lat=49.817492, Lon=15.472962: {'latitude': 49.800003, 'longitude': 15.5, 'generationtime_ms': 0.003814697265625, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Prague', 'timezone_abbreviation': 'GMT+1', 'elevation': 373.0}
# Fetching data for: Germany - Lat: 51.165691, Lon: 10.451526
# API request for coordinates: Lat=51.165691, Lon=10.451526
# Received data for Lat=51.165691, Lon=10.451526: {'latitude': 51.2, 'longitude': 10.5, 'generationtime_ms': 0.00286102294921875, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Berlin', 'timezone_abbreviation': 'GMT+1', 'elevation': 203.0}
# Fetching data for: Djibouti - Lat: 11.825138, Lon: 42.590275
# API request for coordinates: Lat=11.825138, Lon=42.590275
# Received data for Lat=11.825138, Lon=42.590275: {'latitude': 11.800003, 'longitude': 42.600006, 'generationtime_ms': 0.008225440979003906, 'utc_offset_seconds': 10800, 'timezone': 'Africa/Djibouti', 'timezone_abbreviation': 'GMT+3', 'elevation': 1289.0}
# Fetching data for: Denmark - Lat: 56.26392, Lon: 9.501785
# API request for coordinates: Lat=56.26392, Lon=9.501785
# Received data for Lat=56.26392, Lon=9.501785: {'latitude': 56.300003, 'longitude': 9.5, 'generationtime_ms': 0.007748603820800781, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Copenhagen', 'timezone_abbreviation': 'GMT+1', 'elevation': 50.0}
# Fetching data for: Dominica - Lat: 15.414999, Lon: -61.370976
# API request for coordinates: Lat=15.414999, Lon=-61.370976
# Received data for Lat=15.414999, Lon=-61.370976: {'latitude': 15.400002, 'longitude': -61.4, 'generationtime_ms': 0.0022649765014648438, 'utc_offset_seconds': -14400, 'timezone': 'America/Dominica', 'timezone_abbreviation': 'GMT-4', 'elevation': 287.0}
# Fetching data for: Dominican Republic - Lat: 18.735693, Lon: -70.162651
# API request for coordinates: Lat=18.735693, Lon=-70.162651
# Received data for Lat=18.735693, Lon=-70.162651: {'latitude': 18.700005, 'longitude': -70.2, 'generationtime_ms': 0.0021457672119140625, 'utc_offset_seconds': -14400, 'timezone': 'America/Santo_Domingo', 'timezone_abbreviation': 'GMT-4', 'elevation': 908.0}
# Fetching data for: Algeria - Lat: 28.033886, Lon: 1.659626
# API request for coordinates: Lat=28.033886, Lon=1.659626
# Received data for Lat=28.033886, Lon=1.659626: {'latitude': 28.0, 'longitude': 1.699997, 'generationtime_ms': 0.00476837158203125, 'utc_offset_seconds': 3600, 'timezone': 'Africa/Algiers', 'timezone_abbreviation': 'GMT+1', 'elevation': 549.0}
# Fetching data for: Ecuador - Lat: -1.831239, Lon: -78.183406
# API request for coordinates: Lat=-1.831239, Lon=-78.183406
# Received data for Lat=-1.831239, Lon=-78.183406: {'latitude': -1.7999954, 'longitude': -78.2, 'generationtime_ms': 0.00667572021484375, 'utc_offset_seconds': -18000, 'timezone': 'America/Guayaquil', 'timezone_abbreviation': 'GMT-5', 'elevation': 1354.0}
# Fetching data for: Estonia - Lat: 58.595272, Lon: 25.013607
# API request for coordinates: Lat=58.595272, Lon=25.013607
# Received data for Lat=58.595272, Lon=25.013607: {'latitude': 58.6, 'longitude': 25.0, 'generationtime_ms': 0.0019073486328125, 'utc_offset_seconds': 7200, 'timezone': 'Europe/Tallinn', 'timezone_abbreviation': 'GMT+2', 'elevation': 37.0}
# Fetching data for: Egypt - Lat: 26.820553, Lon: 30.802498
# API request for coordinates: Lat=26.820553, Lon=30.802498
# Received data for Lat=26.820553, Lon=30.802498: {'latitude': 26.800003, 'longitude': 30.800003, 'generationtime_ms': 0.0020265579223632812, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Cairo', 'timezone_abbreviation': 'GMT+2', 'elevation': 288.0}
# Fetching data for: Western Sahara - Lat: 24.215527, Lon: -12.885834
# API request for coordinates: Lat=24.215527, Lon=-12.885834
# Received data for Lat=24.215527, Lon=-12.885834: {'latitude': 24.200005, 'longitude': -12.899994, 'generationtime_ms': 0.003337860107421875, 'utc_offset_seconds': 0, 'timezone': 'Africa/El_Aaiun', 'timezone_abbreviation': 'GMT', 'elevation': 215.0}
# Fetching data for: Eritrea - Lat: 15.179384, Lon: 39.782334
# API request for coordinates: Lat=15.179384, Lon=39.782334
# Received data for Lat=15.179384, Lon=39.782334: {'latitude': 15.200005, 'longitude': 39.800003, 'generationtime_ms': 0.0016689300537109375, 'utc_offset_seconds': 10800, 'timezone': 'Africa/Asmara', 'timezone_abbreviation': 'GMT+3', 'elevation': 0.0}
# Fetching data for: Spain - Lat: 40.463667, Lon: -3.74922
# API request for coordinates: Lat=40.463667, Lon=-3.74922
# Received data for Lat=40.463667, Lon=-3.74922: {'latitude': 40.5, 'longitude': -3.6999989, 'generationtime_ms': 0.0019073486328125, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Madrid', 'timezone_abbreviation': 'GMT+1', 'elevation': 591.0}
# Fetching data for: Ethiopia - Lat: 9.145, Lon: 40.489673
# API request for coordinates: Lat=9.145, Lon=40.489673
# Received data for Lat=9.145, Lon=40.489673: {'latitude': 9.099998, 'longitude': 40.5, 'generationtime_ms': 0.0017881393432617188, 'utc_offset_seconds': 10800, 'timezone': 'Africa/Addis_Ababa', 'timezone_abbreviation': 'GMT+3', 'elevation': 1355.0}
# Fetching data for: Finland - Lat: 61.92411, Lon: 25.748151
# API request for coordinates: Lat=61.92411, Lon=25.748151
# Received data for Lat=61.92411, Lon=25.748151: {'latitude': 61.9, 'longitude': 25.7, 'generationtime_ms': 0.0015497207641601562, 'utc_offset_seconds': 7200, 'timezone': 'Europe/Helsinki', 'timezone_abbreviation': 'GMT+2', 'elevation': 175.0}
# Fetching data for: Fiji - Lat: -16.578193, Lon: 179.414413
# API request for coordinates: Lat=-16.578193, Lon=179.414413
# Received data for Lat=-16.578193, Lon=179.414413: {'latitude': -16.599998, 'longitude': 179.4, 'generationtime_ms': 0.0015497207641601562, 'utc_offset_seconds': 43200, 'timezone': 'Pacific/Fiji', 'timezone_abbreviation': 'GMT+12', 'elevation': 546.0}
# Fetching data for: Falkland Islands [Islas Malvinas] - Lat: -51.796253, Lon: -59.523613
# API request for coordinates: Lat=-51.796253, Lon=-59.523613
# Received data for Lat=-51.796253, Lon=-59.523613: {'latitude': -51.8, 'longitude': -59.5, 'generationtime_ms': 0.0020265579223632812, 'utc_offset_seconds': -10800, 'timezone': 'Atlantic/Stanley', 'timezone_abbreviation': 'GMT-3', 'elevation': 0.0}
# Fetching data for: Micronesia - Lat: 7.425554, Lon: 150.550812
# API request for coordinates: Lat=7.425554, Lon=150.550812
# Received data for Lat=7.425554, Lon=150.550812: {'latitude': 7.4000015, 'longitude': 150.6, 'generationtime_ms': 0.0019073486328125, 'utc_offset_seconds': 36000, 'timezone': 'Etc/GMT-10', 'timezone_abbreviation': 'GMT+10', 'elevation': 0.0}
# Fetching data for: Faroe Islands - Lat: 61.892635, Lon: -6.911806
# API request for coordinates: Lat=61.892635, Lon=-6.911806
# Received data for Lat=61.892635, Lon=-6.911806: {'latitude': 61.9, 'longitude': -6.8999996, 'generationtime_ms': 0.0019073486328125, 'utc_offset_seconds': 0, 'timezone': 'Atlantic/Faroe', 'timezone_abbreviation': 'GMT', 'elevation': 218.0}
# Fetching data for: France - Lat: 46.227638, Lon: 2.213749
# API request for coordinates: Lat=46.227638, Lon=2.213749
# Received data for Lat=46.227638, Lon=2.213749: {'latitude': 46.2, 'longitude': 2.2000008, 'generationtime_ms': 0.007033348083496094, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Paris', 'timezone_abbreviation': 'GMT+1', 'elevation': 427.0}
# Fetching data for: Gabon - Lat: -0.803689, Lon: 11.609444
# API request for coordinates: Lat=-0.803689, Lon=11.609444
# Received data for Lat=-0.803689, Lon=11.609444: {'latitude': -0.7999954, 'longitude': 11.600006, 'generationtime_ms': 0.004649162292480469, 'utc_offset_seconds': 3600, 'timezone': 'Africa/Libreville', 'timezone_abbreviation': 'GMT+1', 'elevation': 519.0}
# Fetching data for: United Kingdom - Lat: 55.378051, Lon: -3.435973
# API request for coordinates: Lat=55.378051, Lon=-3.435973
# Received data for Lat=55.378051, Lon=-3.435973: {'latitude': 55.4, 'longitude': -3.3999996, 'generationtime_ms': 0.004649162292480469, 'utc_offset_seconds': 0, 'timezone': 'Europe/London', 'timezone_abbreviation': 'GMT', 'elevation': 370.0}
# Fetching data for: Grenada - Lat: 12.262776, Lon: -61.604171
# API request for coordinates: Lat=12.262776, Lon=-61.604171
# Received data for Lat=12.262776, Lon=-61.604171: {'latitude': 12.300003, 'longitude': -61.6, 'generationtime_ms': 0.0027418136596679688, 'utc_offset_seconds': -14400, 'timezone': 'America/Grenada', 'timezone_abbreviation': 'GMT-4', 'elevation': 0.0}
# Fetching data for: Georgia - Lat: 42.315407, Lon: 43.356892
# API request for coordinates: Lat=42.315407, Lon=43.356892
# Received data for Lat=42.315407, Lon=43.356892: {'latitude': 42.3, 'longitude': 43.4, 'generationtime_ms': 0.0025033950805664062, 'utc_offset_seconds': 14400, 'timezone': 'Asia/Tbilisi', 'timezone_abbreviation': 'GMT+4', 'elevation': 499.0}
# Fetching data for: French Guiana - Lat: 3.933889, Lon: -53.125782
# API request for coordinates: Lat=3.933889, Lon=-53.125782
# Received data for Lat=3.933889, Lon=-53.125782: {'latitude': 3.9000015, 'longitude': -53.1, 'generationtime_ms': 0.004649162292480469, 'utc_offset_seconds': -10800, 'timezone': 'America/Cayenne', 'timezone_abbreviation': 'GMT-3', 'elevation': 278.0}
# Fetching data for: Guernsey - Lat: 49.465691, Lon: -2.585278
# API request for coordinates: Lat=49.465691, Lon=-2.585278
# Received data for Lat=49.465691, Lon=-2.585278: {'latitude': 49.5, 'longitude': -2.6000004, 'generationtime_ms': 0.0017881393432617188, 'utc_offset_seconds': 0, 'timezone': 'Europe/Guernsey', 'timezone_abbreviation': 'GMT', 'elevation': 54.0}
# Fetching data for: Ghana - Lat: 7.946527, Lon: -1.023194
# API request for coordinates: Lat=7.946527, Lon=-1.023194
# Received data for Lat=7.946527, Lon=-1.023194: {'latitude': 7.9000015, 'longitude': -1.0, 'generationtime_ms': 0.00286102294921875, 'utc_offset_seconds': 0, 'timezone': 'Africa/Accra', 'timezone_abbreviation': 'GMT', 'elevation': 124.0}
# Fetching data for: Gibraltar - Lat: 36.137741, Lon: -5.345374
# API request for coordinates: Lat=36.137741, Lon=-5.345374
# Received data for Lat=36.137741, Lon=-5.345374: {'latitude': 36.1, 'longitude': -5.299999, 'generationtime_ms': 0.007510185241699219, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Gibraltar', 'timezone_abbreviation': 'GMT+1', 'elevation': 271.0}
# Fetching data for: Greenland - Lat: 71.706936, Lon: -42.604303
# API request for coordinates: Lat=71.706936, Lon=-42.604303
# Received data for Lat=71.706936, Lon=-42.604303: {'latitude': 71.7, 'longitude': -42.59999, 'generationtime_ms': 0.008821487426757812, 'utc_offset_seconds': -7200, 'timezone': 'America/Godthab', 'timezone_abbreviation': 'GMT-2', 'elevation': 2892.0}
# Fetching data for: Gambia - Lat: 13.443182, Lon: -15.310139
# API request for coordinates: Lat=13.443182, Lon=-15.310139
# Received data for Lat=13.443182, Lon=-15.310139: {'latitude': 13.400002, 'longitude': -15.300003, 'generationtime_ms': 0.0020265579223632812, 'utc_offset_seconds': 0, 'timezone': 'Africa/Banjul', 'timezone_abbreviation': 'GMT', 'elevation': 15.0}
# Fetching data for: Guinea - Lat: 9.945587, Lon: -9.696645
# API request for coordinates: Lat=9.945587, Lon=-9.696645
# Received data for Lat=9.945587, Lon=-9.696645: {'latitude': 9.900002, 'longitude': -9.699997, 'generationtime_ms': 0.004410743713378906, 'utc_offset_seconds': 0, 'timezone': 'Africa/Conakry', 'timezone_abbreviation': 'GMT', 'elevation': 412.0}
# Fetching data for: Guadeloupe - Lat: 16.995971, Lon: -62.067641
# API request for coordinates: Lat=16.995971, Lon=-62.067641
# Received data for Lat=16.995971, Lon=-62.067641: {'latitude': 17.0, 'longitude': -62.1, 'generationtime_ms': 0.0021457672119140625, 'utc_offset_seconds': -14400, 'timezone': 'America/Antigua', 'timezone_abbreviation': 'GMT-4', 'elevation': 0.0}
# Fetching data for: Equatorial Guinea - Lat: 1.650801, Lon: 10.267895
# API request for coordinates: Lat=1.650801, Lon=10.267895
# Received data for Lat=1.650801, Lon=10.267895: {'latitude': 1.7000046, 'longitude': 10.300003, 'generationtime_ms': 0.003933906555175781, 'utc_offset_seconds': 3600, 'timezone': 'Africa/Malabo', 'timezone_abbreviation': 'GMT+1', 'elevation': 925.0}
# Fetching data for: Greece - Lat: 39.074208, Lon: 21.824312
# API request for coordinates: Lat=39.074208, Lon=21.824312
# Received data for Lat=39.074208, Lon=21.824312: {'latitude': 39.1, 'longitude': 21.8, 'generationtime_ms': 0.0027418136596679688, 'utc_offset_seconds': 7200, 'timezone': 'Europe/Athens', 'timezone_abbreviation': 'GMT+2', 'elevation': 864.0}
# Fetching data for: South Georgia and the South Sandwich Islands - Lat: -54.429579, Lon: -36.587909
# API request for coordinates: Lat=-54.429579, Lon=-36.587909
# Received data for Lat=-54.429579, Lon=-36.587909: {'latitude': -54.399998, 'longitude': -36.59999, 'generationtime_ms': 0.0059604644775390625, 'utc_offset_seconds': -7200, 'timezone': 'Atlantic/South_Georgia', 'timezone_abbreviation': 'GMT-2', 'elevation': 2137.0}
# Fetching data for: Guatemala - Lat: 15.783471, Lon: -90.230759
# API request for coordinates: Lat=15.783471, Lon=-90.230759
# Received data for Lat=15.783471, Lon=-90.230759: {'latitude': 15.800003, 'longitude': -90.2, 'generationtime_ms': 0.0057220458984375, 'utc_offset_seconds': -21600, 'timezone': 'America/Guatemala', 'timezone_abbreviation': 'GMT-6', 'elevation': 369.0}
# Fetching data for: Guam - Lat: 13.444304, Lon: 144.793731
# API request for coordinates: Lat=13.444304, Lon=144.793731
# Received data for Lat=13.444304, Lon=144.793731: {'latitude': 13.400002, 'longitude': 144.80002, 'generationtime_ms': 0.0021457672119140625, 'utc_offset_seconds': 36000, 'timezone': 'Pacific/Guam', 'timezone_abbreviation': 'GMT+10', 'elevation': 47.0}
# Fetching data for: Guinea-Bissau - Lat: 11.803749, Lon: -15.180413
# API request for coordinates: Lat=11.803749, Lon=-15.180413
# Received data for Lat=11.803749, Lon=-15.180413: {'latitude': 11.800003, 'longitude': -15.199997, 'generationtime_ms': 0.0050067901611328125, 'utc_offset_seconds': 0, 'timezone': 'Africa/Bissau', 'timezone_abbreviation': 'GMT', 'elevation': 11.0}
# Fetching data for: Guyana - Lat: 4.860416, Lon: -58.93018
# API request for coordinates: Lat=4.860416, Lon=-58.93018
# Received data for Lat=4.860416, Lon=-58.93018: {'latitude': 4.9000015, 'longitude': -58.9, 'generationtime_ms': 0.002384185791015625, 'utc_offset_seconds': -14400, 'timezone': 'America/Guyana', 'timezone_abbreviation': 'GMT-4', 'elevation': 324.0}
# Fetching data for: Gaza Strip - Lat: 31.354676, Lon: 34.308825
# API request for coordinates: Lat=31.354676, Lon=34.308825
# Received data for Lat=31.354676, Lon=34.308825: {'latitude': 31.4, 'longitude': 34.3, 'generationtime_ms': 0.004649162292480469, 'utc_offset_seconds': 7200, 'timezone': 'Asia/Gaza', 'timezone_abbreviation': 'GMT+2', 'elevation': 28.0}
# Fetching data for: Hong Kong - Lat: 22.396428, Lon: 114.109497
# API request for coordinates: Lat=22.396428, Lon=114.109497
# Received data for Lat=22.396428, Lon=114.109497: {'latitude': 22.400002, 'longitude': 114.100006, 'generationtime_ms': 0.00286102294921875, 'utc_offset_seconds': 28800, 'timezone': 'Asia/Hong_Kong', 'timezone_abbreviation': 'GMT+8', 'elevation': 329.0}
# Fetching data for: Heard Island and McDonald Islands - Lat: -53.08181, Lon: 73.504158
# API request for coordinates: Lat=-53.08181, Lon=73.504158
# Received data for Lat=-53.08181, Lon=73.504158: {'latitude': -53.1, 'longitude': 73.5, 'generationtime_ms': 0.0034570693969726562, 'utc_offset_seconds': 18000, 'timezone': 'Etc/GMT-5', 'timezone_abbreviation': 'GMT+5', 'elevation': 2244.0}
# Fetching data for: Honduras - Lat: 15.199999, Lon: -86.241905
# API request for coordinates: Lat=15.199999, Lon=-86.241905
# Received data for Lat=15.199999, Lon=-86.241905: {'latitude': 15.200005, 'longitude': -86.2, 'generationtime_ms': 0.0034570693969726562, 'utc_offset_seconds': -21600, 'timezone': 'America/Tegucigalpa', 'timezone_abbreviation': 'GMT-6', 'elevation': 910.0}
# Fetching data for: Croatia - Lat: 45.1, Lon: 15.2
# API request for coordinates: Lat=45.1, Lon=15.2
# Received data for Lat=45.1, Lon=15.2: {'latitude': 45.1, 'longitude': 15.200001, 'generationtime_ms': 0.0020265579223632812, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Zagreb', 'timezone_abbreviation': 'GMT+1', 'elevation': 909.0}
# Fetching data for: Haiti - Lat: 18.971187, Lon: -72.285215
# API request for coordinates: Lat=18.971187, Lon=-72.285215
# Received data for Lat=18.971187, Lon=-72.285215: {'latitude': 19.0, 'longitude': -72.299995, 'generationtime_ms': 0.0030994415283203125, 'utc_offset_seconds': -18000, 'timezone': 'America/Port-au-Prince', 'timezone_abbreviation': 'GMT-5', 'elevation': 352.0}
# Fetching data for: Hungary - Lat: 47.162494, Lon: 19.503304
# API request for coordinates: Lat=47.162494, Lon=19.503304
# Received data for Lat=47.162494, Lon=19.503304: {'latitude': 47.2, 'longitude': 19.5, 'generationtime_ms': 0.004410743713378906, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Budapest', 'timezone_abbreviation': 'GMT+1', 'elevation': 134.0}
# Fetching data for: Indonesia - Lat: -0.789275, Lon: 113.921327
# API request for coordinates: Lat=-0.789275, Lon=113.921327
# Received data for Lat=-0.789275, Lon=113.921327: {'latitude': -0.7999954, 'longitude': 113.899994, 'generationtime_ms': 0.005364418029785156, 'utc_offset_seconds': 25200, 'timezone': 'Asia/Pontianak', 'timezone_abbreviation': 'GMT+7', 'elevation': 104.0}
# Fetching data for: Ireland - Lat: 53.41291, Lon: -8.24389
# API request for coordinates: Lat=53.41291, Lon=-8.24389
# Received data for Lat=53.41291, Lon=-8.24389: {'latitude': 53.4, 'longitude': -8.199999, 'generationtime_ms': 0.0036954879760742188, 'utc_offset_seconds': 0, 'timezone': 'Europe/Dublin', 'timezone_abbreviation': 'GMT', 'elevation': 39.0}
# Fetching data for: Israel - Lat: 31.046051, Lon: 34.851612
# API request for coordinates: Lat=31.046051, Lon=34.851612
# Received data for Lat=31.046051, Lon=34.851612: {'latitude': 31.0, 'longitude': 34.9, 'generationtime_ms': 0.0022649765014648438, 'utc_offset_seconds': 7200, 'timezone': 'Asia/Jerusalem', 'timezone_abbreviation': 'GMT+2', 'elevation': 456.0}
# Fetching data for: Isle of Man - Lat: 54.236107, Lon: -4.548056
# API request for coordinates: Lat=54.236107, Lon=-4.548056
# Received data for Lat=54.236107, Lon=-4.548056: {'latitude': 54.2, 'longitude': -4.5, 'generationtime_ms': 0.0026226043701171875, 'utc_offset_seconds': 0, 'timezone': 'Europe/Isle_of_Man', 'timezone_abbreviation': 'GMT', 'elevation': 372.0}
# Fetching data for: India - Lat: 20.593684, Lon: 78.96288
# API request for coordinates: Lat=20.593684, Lon=78.96288
# Received data for Lat=20.593684, Lon=78.96288: {'latitude': 20.599998, 'longitude': 79.0, 'generationtime_ms': 0.00476837158203125, 'utc_offset_seconds': 19800, 'timezone': 'Asia/Kolkata', 'timezone_abbreviation': 'GMT+5:30', 'elevation': 245.0}
# Fetching data for: British Indian Ocean Territory - Lat: -6.343194, Lon: 71.876519
# API request for coordinates: Lat=-6.343194, Lon=71.876519
# Received data for Lat=-6.343194, Lon=71.876519: {'latitude': -6.2999954, 'longitude': 71.90001, 'generationtime_ms': 0.00286102294921875, 'utc_offset_seconds': 18000, 'timezone': 'Etc/GMT-5', 'timezone_abbreviation': 'GMT+5', 'elevation': 0.0}
# Fetching data for: Iraq - Lat: 33.223191, Lon: 43.679291
# API request for coordinates: Lat=33.223191, Lon=43.679291
# Received data for Lat=33.223191, Lon=43.679291: {'latitude': 33.2, 'longitude': 43.700005, 'generationtime_ms': 0.0050067901611328125, 'utc_offset_seconds': 10800, 'timezone': 'Asia/Baghdad', 'timezone_abbreviation': 'GMT+3', 'elevation': 73.0}
# Fetching data for: Iran - Lat: 32.427908, Lon: 53.688046
# API request for coordinates: Lat=32.427908, Lon=53.688046
# Received data for Lat=32.427908, Lon=53.688046: {'latitude': 32.4, 'longitude': 53.699997, 'generationtime_ms': 0.002384185791015625, 'utc_offset_seconds': 12600, 'timezone': 'Asia/Tehran', 'timezone_abbreviation': 'GMT+3:30', 'elevation': 1142.0}
# Fetching data for: Iceland - Lat: 64.963051, Lon: -19.020835
# API request for coordinates: Lat=64.963051, Lon=-19.020835
# Received data for Lat=64.963051, Lon=-19.020835: {'latitude': 65.0, 'longitude': -19.0, 'generationtime_ms': 0.00667572021484375, 'utc_offset_seconds': 0, 'timezone': 'Atlantic/Reykjavik', 'timezone_abbreviation': 'GMT', 'elevation': 816.0}
# Fetching data for: Italy - Lat: 41.87194, Lon: 12.56738
# API request for coordinates: Lat=41.87194, Lon=12.56738
# Received data for Lat=41.87194, Lon=12.56738: {'latitude': 41.9, 'longitude': 12.600002, 'generationtime_ms': 0.0013113021850585938, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Rome', 'timezone_abbreviation': 'GMT+1', 'elevation': 47.0}
# Fetching data for: Jersey - Lat: 49.214439, Lon: -2.13125
# API request for coordinates: Lat=49.214439, Lon=-2.13125
# Received data for Lat=49.214439, Lon=-2.13125: {'latitude': 49.2, 'longitude': -2.1000004, 'generationtime_ms': 0.005245208740234375, 'utc_offset_seconds': 0, 'timezone': 'Europe/Jersey', 'timezone_abbreviation': 'GMT', 'elevation': 62.0}
# Fetching data for: Jamaica - Lat: 18.109581, Lon: -77.297508
# API request for coordinates: Lat=18.109581, Lon=-77.297508
# Received data for Lat=18.109581, Lon=-77.297508: {'latitude': 18.099998, 'longitude': -77.299995, 'generationtime_ms': 0.005364418029785156, 'utc_offset_seconds': -18000, 'timezone': 'America/Jamaica', 'timezone_abbreviation': 'GMT-5', 'elevation': 207.0}
# Fetching data for: Jordan - Lat: 30.585164, Lon: 36.238414
# API request for coordinates: Lat=30.585164, Lon=36.238414
# Received data for Lat=30.585164, Lon=36.238414: {'latitude': 30.6, 'longitude': 36.2, 'generationtime_ms': 0.0034570693969726562, 'utc_offset_seconds': 10800, 'timezone': 'Asia/Amman', 'timezone_abbreviation': 'GMT+3', 'elevation': 910.0}
# Fetching data for: Japan - Lat: 36.204824, Lon: 138.252924
# API request for coordinates: Lat=36.204824, Lon=138.252924
# Received data for Lat=36.204824, Lon=138.252924: {'latitude': 36.200005, 'longitude': 138.30002, 'generationtime_ms': 0.005125999450683594, 'utc_offset_seconds': 32400, 'timezone': 'Asia/Tokyo', 'timezone_abbreviation': 'GMT+9', 'elevation': 1006.0}
# Fetching data for: Kenya - Lat: -0.023559, Lon: 37.906193
# API request for coordinates: Lat=-0.023559, Lon=37.906193
# Received data for Lat=-0.023559, Lon=37.906193: {'latitude': 0.0, 'longitude': 37.90001, 'generationtime_ms': 0.0034570693969726562, 'utc_offset_seconds': 10800, 'timezone': 'Africa/Nairobi', 'timezone_abbreviation': 'GMT+3', 'elevation': 821.0}
# Fetching data for: Kyrgyzstan - Lat: 41.20438, Lon: 74.766098
# API request for coordinates: Lat=41.20438, Lon=74.766098
# Received data for Lat=41.20438, Lon=74.766098: {'latitude': 41.199997, 'longitude': 74.8, 'generationtime_ms': 0.004172325134277344, 'utc_offset_seconds': 21600, 'timezone': 'Asia/Bishkek', 'timezone_abbreviation': 'GMT+6', 'elevation': 2118.0}
# Fetching data for: Cambodia - Lat: 12.565679, Lon: 104.990963
# API request for coordinates: Lat=12.565679, Lon=104.990963
# Received data for Lat=12.565679, Lon=104.990963: {'latitude': 12.599998, 'longitude': 105.0, 'generationtime_ms': 0.00286102294921875, 'utc_offset_seconds': 25200, 'timezone': 'Asia/Phnom_Penh', 'timezone_abbreviation': 'GMT+7', 'elevation': 9.0}
# Fetching data for: Kiribati - Lat: -3.370417, Lon: -168.734039
# API request for coordinates: Lat=-3.370417, Lon=-168.734039
# Received data for Lat=-3.370417, Lon=-168.734039: {'latitude': -3.4000015, 'longitude': -168.7, 'generationtime_ms': 0.0011920928955078125, 'utc_offset_seconds': -39600, 'timezone': 'Etc/GMT+11', 'timezone_abbreviation': 'GMT-11', 'elevation': 0.0}
# Fetching data for: Comoros - Lat: -11.875001, Lon: 43.872219
# API request for coordinates: Lat=-11.875001, Lon=43.872219
# Received data for Lat=-11.875001, Lon=43.872219: {'latitude': -11.900002, 'longitude': 43.90001, 'generationtime_ms': 0.0050067901611328125, 'utc_offset_seconds': 10800, 'timezone': 'Indian/Comoro', 'timezone_abbreviation': 'GMT+3', 'elevation': 0.0}
# Fetching data for: Saint Kitts and Nevis - Lat: 17.357822, Lon: -62.782998
# API request for coordinates: Lat=17.357822, Lon=-62.782998
# Received data for Lat=17.357822, Lon=-62.782998: {'latitude': 17.400002, 'longitude': -62.799995, 'generationtime_ms': 0.0035762786865234375, 'utc_offset_seconds': -14400, 'timezone': 'America/St_Kitts', 'timezone_abbreviation': 'GMT-4', 'elevation': 719.0}
# Fetching data for: North Korea - Lat: 40.339852, Lon: 127.510093
# API request for coordinates: Lat=40.339852, Lon=127.510093
# Received data for Lat=40.339852, Lon=127.510093: {'latitude': 40.300003, 'longitude': 127.5, 'generationtime_ms': 0.0022649765014648438, 'utc_offset_seconds': 32400, 'timezone': 'Asia/Pyongyang', 'timezone_abbreviation': 'GMT+9', 'elevation': 841.0}
# Fetching data for: South Korea - Lat: 35.907757, Lon: 127.766922
# API request for coordinates: Lat=35.907757, Lon=127.766922
# Received data for Lat=35.907757, Lon=127.766922: {'latitude': 35.9, 'longitude': 127.80002, 'generationtime_ms': 0.005841255187988281, 'utc_offset_seconds': 32400, 'timezone': 'Asia/Seoul', 'timezone_abbreviation': 'GMT+9', 'elevation': 576.0}
# Fetching data for: Kuwait - Lat: 29.31166, Lon: 47.481766
# API request for coordinates: Lat=29.31166, Lon=47.481766
# Received data for Lat=29.31166, Lon=47.481766: {'latitude': 29.300003, 'longitude': 47.5, 'generationtime_ms': 0.004291534423828125, 'utc_offset_seconds': 10800, 'timezone': 'Asia/Kuwait', 'timezone_abbreviation': 'GMT+3', 'elevation': 151.0}
# Fetching data for: Cayman Islands - Lat: 19.513469, Lon: -80.566956
# API request for coordinates: Lat=19.513469, Lon=-80.566956
# Received data for Lat=19.513469, Lon=-80.566956: {'latitude': 19.5, 'longitude': -80.6, 'generationtime_ms': 0.0019073486328125, 'utc_offset_seconds': -18000, 'timezone': 'Etc/GMT+5', 'timezone_abbreviation': 'GMT-5', 'elevation': 0.0}
# Fetching data for: Kazakhstan - Lat: 48.019573, Lon: 66.923684
# API request for coordinates: Lat=48.019573, Lon=66.923684
# Received data for Lat=48.019573, Lon=66.923684: {'latitude': 48.0, 'longitude': 66.90001, 'generationtime_ms': 0.0025033950805664062, 'utc_offset_seconds': 21600, 'timezone': 'Asia/Almaty', 'timezone_abbreviation': 'GMT+6', 'elevation': 480.0}
# Fetching data for: Laos - Lat: 19.85627, Lon: 102.495496
# API request for coordinates: Lat=19.85627, Lon=102.495496
# Received data for Lat=19.85627, Lon=102.495496: {'latitude': 19.900002, 'longitude': 102.5, 'generationtime_ms': 0.005125999450683594, 'utc_offset_seconds': 25200, 'timezone': 'Asia/Vientiane', 'timezone_abbreviation': 'GMT+7', 'elevation': 795.0}
# Fetching data for: Lebanon - Lat: 33.854721, Lon: 35.862285
# API request for coordinates: Lat=33.854721, Lon=35.862285
# Received data for Lat=33.854721, Lon=35.862285: {'latitude': 33.9, 'longitude': 35.9, 'generationtime_ms': 0.0035762786865234375, 'utc_offset_seconds': 7200, 'timezone': 'Asia/Beirut', 'timezone_abbreviation': 'GMT+2', 'elevation': 1190.0}
# Fetching data for: Saint Lucia - Lat: 13.909444, Lon: -60.978893
# API request for coordinates: Lat=13.909444, Lon=-60.978893
# Received data for Lat=13.909444, Lon=-60.978893: {'latitude': 13.900002, 'longitude': -61.0, 'generationtime_ms': 0.004291534423828125, 'utc_offset_seconds': -14400, 'timezone': 'America/St_Lucia', 'timezone_abbreviation': 'GMT-4', 'elevation': 297.0}
# Fetching data for: Liechtenstein - Lat: 47.166, Lon: 9.555373
# API request for coordinates: Lat=47.166, Lon=9.555373
# Received data for Lat=47.166, Lon=9.555373: {'latitude': 47.2, 'longitude': 9.600002, 'generationtime_ms': 0.0020265579223632812, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Vaduz', 'timezone_abbreviation': 'GMT+1', 'elevation': 1756.0}
# Fetching data for: Sri Lanka - Lat: 7.873054, Lon: 80.771797
# API request for coordinates: Lat=7.873054, Lon=80.771797
# Received data for Lat=7.873054, Lon=80.771797: {'latitude': 7.9000015, 'longitude': 80.80002, 'generationtime_ms': 0.003337860107421875, 'utc_offset_seconds': 19800, 'timezone': 'Asia/Colombo', 'timezone_abbreviation': 'GMT+5:30', 'elevation': 232.0}
# Fetching data for: Liberia - Lat: 6.428055, Lon: -9.429499
# API request for coordinates: Lat=6.428055, Lon=-9.429499
# Received data for Lat=6.428055, Lon=-9.429499: {'latitude': 6.4000015, 'longitude': -9.399994, 'generationtime_ms': 0.0025033950805664062, 'utc_offset_seconds': 0, 'timezone': 'Africa/Monrovia', 'timezone_abbreviation': 'GMT', 'elevation': 240.0}
# Fetching data for: Lesotho - Lat: -29.609988, Lon: 28.233608
# API request for coordinates: Lat=-29.609988, Lon=28.233608
# Received data for Lat=-29.609988, Lon=28.233608: {'latitude': -29.599998, 'longitude': 28.199997, 'generationtime_ms': 0.0022649765014648438, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Maseru', 'timezone_abbreviation': 'GMT+2', 'elevation': 2247.0}
# Fetching data for: Lithuania - Lat: 55.169438, Lon: 23.881275
# ...
# Fetching data for: Senegal - Lat: 14.497401, Lon: -14.452362
# API request for coordinates: Lat=14.497401, Lon=-14.452362
# Received data for Lat=14.497401, Lon=-14.452362: {'latitude': 14.5, 'longitude': -14.5, 'generationtime_ms': 0.004649162292480469, 'utc_offset_seconds': 0, 'timezone': 'Africa/Dakar', 'timezone_abbreviation': 'GMT', 'elevation': 48.0}
# Fetching data for: Somalia - Lat: 5.152149, Lon: 46.199616
# API request for coordinates: Lat=5.152149, Lon=46.199616
# Received data for Lat=5.152149, Lon=46.199616: {'latitude': 5.2000046, 'longitude': 46.199997, 'generationtime_ms': 0.0017881393432617188, 'utc_offset_seconds': 10800, 'timezone': 'Africa/Mogadishu', 'timezone_abbreviation': 'GMT+3', 'elevation': 241.0}
# Fetching data for: Suriname - Lat: 3.919305, Lon: -56.027783
# API request for coordinates: Lat=3.919305, Lon=-56.027783
# Received data for Lat=3.919305, Lon=-56.027783: {'latitude': 3.9000015, 'longitude': -56.0, 'generationtime_ms': 0.001430511474609375, 'utc_offset_seconds': -10800, 'timezone': 'America/Paramaribo', 'timezone_abbreviation': 'GMT-3', 'elevation': 157.0}
# Fetching data for: Sao Tome and Principe  - Lat: 0.18636, Lon: 6.613081
# API request for coordinates: Lat=0.18636, Lon=6.613081
# Received data for Lat=0.18636, Lon=6.613081: {'latitude': 0.20000458, 'longitude': 6.600006, 'generationtime_ms': 0.0021457672119140625, 'utc_offset_seconds': 0, 'timezone': 'Africa/Sao_Tome', 'timezone_abbreviation': 'GMT', 'elevation': 152.0}
# Fetching data for: El Salvador - Lat: 13.794185, Lon: -88.89653
# API request for coordinates: Lat=13.794185, Lon=-88.89653
# Received data for Lat=13.794185, Lon=-88.89653: {'latitude': 13.800003, 'longitude': -88.9, 'generationtime_ms': 0.00286102294921875, 'utc_offset_seconds': -21600, 'timezone': 'America/El_Salvador', 'timezone_abbreviation': 'GMT-6', 'elevation': 622.0}
# Fetching data for: Syria - Lat: 34.802075, Lon: 38.996815
# API request for coordinates: Lat=34.802075, Lon=38.996815
# Received data for Lat=34.802075, Lon=38.996815: {'latitude': 34.8, 'longitude': 39.0, 'generationtime_ms': 0.0021457672119140625, 'utc_offset_seconds': 10800, 'timezone': 'Asia/Damascus', 'timezone_abbreviation': 'GMT+3', 'elevation': 445.0}
# Fetching data for: Swaziland - Lat: -26.522503, Lon: 31.465866
# API request for coordinates: Lat=-26.522503, Lon=31.465866
# Received data for Lat=-26.522503, Lon=31.465866: {'latitude': -26.5, 'longitude': 31.5, 'generationtime_ms': 0.004291534423828125, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Mbabane', 'timezone_abbreviation': 'GMT+2', 'elevation': 491.0}
# Fetching data for: Turks and Caicos Islands - Lat: 21.694025, Lon: -71.797928
# API request for coordinates: Lat=21.694025, Lon=-71.797928
# Received data for Lat=21.694025, Lon=-71.797928: {'latitude': 21.700005, 'longitude': -71.799995, 'generationtime_ms': 0.0017881393432617188, 'utc_offset_seconds': -18000, 'timezone': 'America/Grand_Turk', 'timezone_abbreviation': 'GMT-5', 'elevation': 0.0}
# Fetching data for: Chad - Lat: 15.454166, Lon: 18.732207
# API request for coordinates: Lat=15.454166, Lon=18.732207
# Received data for Lat=15.454166, Lon=18.732207: {'latitude': 15.5, 'longitude': 18.699997, 'generationtime_ms': 0.0016689300537109375, 'utc_offset_seconds': 3600, 'timezone': 'Africa/Ndjamena', 'timezone_abbreviation': 'GMT+1', 'elevation': 332.0}
# Fetching data for: French Southern Territories - Lat: -49.280366, Lon: 69.348557
# API request for coordinates: Lat=-49.280366, Lon=69.348557
# Received data for Lat=-49.280366, Lon=69.348557: {'latitude': -49.3, 'longitude': 69.3, 'generationtime_ms': 0.00667572021484375, 'utc_offset_seconds': 18000, 'timezone': 'Indian/Kerguelen', 'timezone_abbreviation': 'GMT+5', 'elevation': 265.0}
# Fetching data for: Togo - Lat: 8.619543, Lon: 0.824782
# API request for coordinates: Lat=8.619543, Lon=0.824782
# Received data for Lat=8.619543, Lon=0.824782: {'latitude': 8.599998, 'longitude': 0.80000305, 'generationtime_ms': 0.0015497207641601562, 'utc_offset_seconds': 0, 'timezone': 'Africa/Lome', 'timezone_abbreviation': 'GMT', 'elevation': 480.0}
# Fetching data for: Thailand - Lat: 15.870032, Lon: 100.992541
# API request for coordinates: Lat=15.870032, Lon=100.992541
# Received data for Lat=15.870032, Lon=100.992541: {'latitude': 15.900002, 'longitude': 101.0, 'generationtime_ms': 0.0029802322387695312, 'utc_offset_seconds': 25200, 'timezone': 'Asia/Bangkok', 'timezone_abbreviation': 'GMT+7', 'elevation': 92.0}
# Fetching data for: Tajikistan - Lat: 38.861034, Lon: 71.276093
# API request for coordinates: Lat=38.861034, Lon=71.276093
# Received data for Lat=38.861034, Lon=71.276093: {'latitude': 38.90001, 'longitude': 71.3, 'generationtime_ms': 0.0040531158447265625, 'utc_offset_seconds': 18000, 'timezone': 'Asia/Dushanbe', 'timezone_abbreviation': 'GMT+5', 'elevation': 3840.0}
# Fetching data for: Tokelau - Lat: -8.967363, Lon: -171.855881
# API request for coordinates: Lat=-8.967363, Lon=-171.855881
# Received data for Lat=-8.967363, Lon=-171.855881: {'latitude': -9.0, 'longitude': -171.9, 'generationtime_ms': 0.0026226043701171875, 'utc_offset_seconds': 46800, 'timezone': 'Pacific/Fakaofo', 'timezone_abbreviation': 'GMT+13', 'elevation': 0.0}
# Fetching data for: Timor-Leste - Lat: -8.874217, Lon: 125.727539
# API request for coordinates: Lat=-8.874217, Lon=125.727539
# Received data for Lat=-8.874217, Lon=125.727539: {'latitude': -8.900002, 'longitude': 125.70001, 'generationtime_ms': 0.0016689300537109375, 'utc_offset_seconds': 32400, 'timezone': 'Asia/Dili', 'timezone_abbreviation': 'GMT+9', 'elevation': 712.0}
# Fetching data for: Turkmenistan - Lat: 38.969719, Lon: 59.556278
# API request for coordinates: Lat=38.969719, Lon=59.556278
# Received data for Lat=38.969719, Lon=59.556278: {'latitude': 39.0, 'longitude': 59.600006, 'generationtime_ms': 0.0026226043701171875, 'utc_offset_seconds': 18000, 'timezone': 'Asia/Ashgabat', 'timezone_abbreviation': 'GMT+5', 'elevation': 112.0}
# Fetching data for: Tunisia - Lat: 33.886917, Lon: 9.537499
# API request for coordinates: Lat=33.886917, Lon=9.537499
# Received data for Lat=33.886917, Lon=9.537499: {'latitude': 33.9, 'longitude': 9.5, 'generationtime_ms': 0.0017881393432617188, 'utc_offset_seconds': 3600, 'timezone': 'Africa/Tunis', 'timezone_abbreviation': 'GMT+1', 'elevation': 45.0}
# Fetching data for: Tonga - Lat: -21.178986, Lon: -175.198242
# API request for coordinates: Lat=-21.178986, Lon=-175.198242
# Received data for Lat=-21.178986, Lon=-175.198242: {'latitude': -21.199997, 'longitude': -175.2, 'generationtime_ms': 0.0032186508178710938, 'utc_offset_seconds': 46800, 'timezone': 'Pacific/Tongatapu', 'timezone_abbreviation': 'GMT+13', 'elevation': 0.0}
# Fetching data for: Turkey - Lat: 38.963745, Lon: 35.243322
# API request for coordinates: Lat=38.963745, Lon=35.243322
# Received data for Lat=38.963745, Lon=35.243322: {'latitude': 39.0, 'longitude': 35.2, 'generationtime_ms': 0.0019073486328125, 'utc_offset_seconds': 10800, 'timezone': 'Europe/Istanbul', 'timezone_abbreviation': 'GMT+3', 'elevation': 1221.0}
# Fetching data for: Trinidad and Tobago - Lat: 10.691803, Lon: -61.222503
# API request for coordinates: Lat=10.691803, Lon=-61.222503
# Received data for Lat=10.691803, Lon=-61.222503: {'latitude': 10.700005, 'longitude': -61.199997, 'generationtime_ms': 0.0022649765014648438, 'utc_offset_seconds': -14400, 'timezone': 'Etc/GMT+4', 'timezone_abbreviation': 'GMT-4', 'elevation': 223.0}
# Fetching data for: Tuvalu - Lat: -7.109535, Lon: 177.64933
# API request for coordinates: Lat=-7.109535, Lon=177.64933
# Received data for Lat=-7.109535, Lon=177.64933: {'latitude': -7.0999985, 'longitude': 177.6, 'generationtime_ms': 0.0040531158447265625, 'utc_offset_seconds': 43200, 'timezone': 'Etc/GMT-12', 'timezone_abbreviation': 'GMT+12', 'elevation': 0.0}
# Fetching data for: Taiwan - Lat: 23.69781, Lon: 120.960515
# API request for coordinates: Lat=23.69781, Lon=120.960515
# Received data for Lat=23.69781, Lon=120.960515: {'latitude': 23.700005, 'longitude': 121.0, 'generationtime_ms': 0.002384185791015625, 'utc_offset_seconds': 28800, 'timezone': 'Asia/Taipei', 'timezone_abbreviation': 'GMT+8', 'elevation': 2768.0}
# Fetching data for: Tanzania - Lat: -6.369028, Lon: 34.888822
# API request for coordinates: Lat=-6.369028, Lon=34.888822
# Received data for Lat=-6.369028, Lon=34.888822: {'latitude': -6.4000015, 'longitude': 34.90001, 'generationtime_ms': 0.0032186508178710938, 'utc_offset_seconds': 10800, 'timezone': 'Africa/Dar_es_Salaam', 'timezone_abbreviation': 'GMT+3', 'elevation': 1166.0}
# Fetching data for: Ukraine - Lat: 48.379433, Lon: 31.16558
# API request for coordinates: Lat=48.379433, Lon=31.16558
# Received data for Lat=48.379433, Lon=31.16558: {'latitude': 48.4, 'longitude': 31.2, 'generationtime_ms': 0.0027418136596679688, 'utc_offset_seconds': 7200, 'timezone': 'Europe/Kiev', 'timezone_abbreviation': 'GMT+2', 'elevation': 200.0}
# Fetching data for: Uganda - Lat: 1.373333, Lon: 32.290275
# API request for coordinates: Lat=1.373333, Lon=32.290275
# Received data for Lat=1.373333, Lon=32.290275: {'latitude': 1.4000015, 'longitude': 32.300003, 'generationtime_ms': 0.009059906005859375, 'utc_offset_seconds': 10800, 'timezone': 'Africa/Kampala', 'timezone_abbreviation': 'GMT+3', 'elevation': 1071.0}
# Fetching data for: United States - Lat: 37.09024, Lon: -95.712891
# API request for coordinates: Lat=37.09024, Lon=-95.712891
# Received data for Lat=37.09024, Lon=-95.712891: {'latitude': 37.1, 'longitude': -95.7, 'generationtime_ms': 0.0020265579223632812, 'utc_offset_seconds': -21600, 'timezone': 'America/Chicago', 'timezone_abbreviation': 'GMT-6', 'elevation': 256.0}
# Fetching data for: Uruguay - Lat: -32.522779, Lon: -55.765835
# API request for coordinates: Lat=-32.522779, Lon=-55.765835
# Received data for Lat=-32.522779, Lon=-55.765835: {'latitude': -32.5, 'longitude': -55.799995, 'generationtime_ms': 0.004410743713378906, 'utc_offset_seconds': -10800, 'timezone': 'America/Montevideo', 'timezone_abbreviation': 'GMT-3', 'elevation': 91.0}
# Fetching data for: Uzbekistan - Lat: 41.377491, Lon: 64.585262
# API request for coordinates: Lat=41.377491, Lon=64.585262
# Received data for Lat=41.377491, Lon=64.585262: {'latitude': 41.40001, 'longitude': 64.600006, 'generationtime_ms': 0.006079673767089844, 'utc_offset_seconds': 18000, 'timezone': 'Asia/Samarkand', 'timezone_abbreviation': 'GMT+5', 'elevation': 361.0}
# Fetching data for: Vatican City - Lat: 41.902916, Lon: 12.453389
# API request for coordinates: Lat=41.902916, Lon=12.453389
# Received data for Lat=41.902916, Lon=12.453389: {'latitude': 41.9, 'longitude': 12.5, 'generationtime_ms': 0.003814697265625, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Vatican', 'timezone_abbreviation': 'GMT+1', 'elevation': 50.0}
# Fetching data for: Saint Vincent and the Grenadines - Lat: 12.984305, Lon: -61.287228
# API request for coordinates: Lat=12.984305, Lon=-61.287228
# Received data for Lat=12.984305, Lon=-61.287228: {'latitude': 13.0, 'longitude': -61.299995, 'generationtime_ms': 0.00476837158203125, 'utc_offset_seconds': -14400, 'timezone': 'America/St_Vincent', 'timezone_abbreviation': 'GMT-4', 'elevation': 0.0}
# Fetching data for: Venezuela - Lat: 6.42375, Lon: -66.58973
# API request for coordinates: Lat=6.42375, Lon=-66.58973
# Received data for Lat=6.42375, Lon=-66.58973: {'latitude': 6.4000015, 'longitude': -66.6, 'generationtime_ms': 0.004649162292480469, 'utc_offset_seconds': -18000, 'timezone': 'America/Bogota', 'timezone_abbreviation': 'GMT-5', 'elevation': 96.0}
# Fetching data for: British Virgin Islands - Lat: 18.420695, Lon: -64.639968
# API request for coordinates: Lat=18.420695, Lon=-64.639968
# Received data for Lat=18.420695, Lon=-64.639968: {'latitude': 18.400002, 'longitude': -64.6, 'generationtime_ms': 0.0021457672119140625, 'utc_offset_seconds': -14400, 'timezone': 'America/Tortola', 'timezone_abbreviation': 'GMT-4', 'elevation': 304.0}
# Fetching data for: U.S. Virgin Islands - Lat: 18.335765, Lon: -64.896335
# API request for coordinates: Lat=18.335765, Lon=-64.896335
# Received data for Lat=18.335765, Lon=-64.896335: {'latitude': 18.300003, 'longitude': -64.9, 'generationtime_ms': 0.0035762786865234375, 'utc_offset_seconds': -14400, 'timezone': 'America/St_Thomas', 'timezone_abbreviation': 'GMT-4', 'elevation': 68.0}
# Fetching data for: Vietnam - Lat: 14.058324, Lon: 108.277199
# API request for coordinates: Lat=14.058324, Lon=108.277199
# Received data for Lat=14.058324, Lon=108.277199: {'latitude': 14.099998, 'longitude': 108.30002, 'generationtime_ms': 0.0073909759521484375, 'utc_offset_seconds': 25200, 'timezone': 'Asia/Ho_Chi_Minh', 'timezone_abbreviation': 'GMT+7', 'elevation': 725.0}
# Fetching data for: Vanuatu - Lat: -15.376706, Lon: 166.959158
# API request for coordinates: Lat=-15.376706, Lon=166.959158
# Received data for Lat=-15.376706, Lon=166.959158: {'latitude': -15.400002, 'longitude': 167.0, 'generationtime_ms': 0.0034570693969726562, 'utc_offset_seconds': 39600, 'timezone': 'Pacific/Efate', 'timezone_abbreviation': 'GMT+11', 'elevation': 647.0}
# Fetching data for: Wallis and Futuna - Lat: -13.768752, Lon: -177.156097
# API request for coordinates: Lat=-13.768752, Lon=-177.156097
# Received data for Lat=-13.768752, Lon=-177.156097: {'latitude': -13.799995, 'longitude': -177.2, 'generationtime_ms': 0.005364418029785156, 'utc_offset_seconds': -43200, 'timezone': 'Etc/GMT+12', 'timezone_abbreviation': 'GMT-12', 'elevation': 0.0}
# Fetching data for: Samoa - Lat: -13.759029, Lon: -172.104629
# API request for coordinates: Lat=-13.759029, Lon=-172.104629
# Received data for Lat=-13.759029, Lon=-172.104629: {'latitude': -13.799995, 'longitude': -172.1, 'generationtime_ms': 0.003814697265625, 'utc_offset_seconds': 46800, 'timezone': 'Pacific/Apia', 'timezone_abbreviation': 'GMT+13', 'elevation': 0.0}
# Fetching data for: Kosovo - Lat: 42.602636, Lon: 20.902977
# API request for coordinates: Lat=42.602636, Lon=20.902977
# Received data for Lat=42.602636, Lon=20.902977: {'latitude': 42.6, 'longitude': 20.900002, 'generationtime_ms': 0.00286102294921875, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Belgrade', 'timezone_abbreviation': 'GMT+1', 'elevation': 587.0}
# Fetching data for: Yemen - Lat: 15.552727, Lon: 48.516388
# API request for coordinates: Lat=15.552727, Lon=48.516388
# Received data for Lat=15.552727, Lon=48.516388: {'latitude': 15.599998, 'longitude': 48.5, 'generationtime_ms': 0.005125999450683594, 'utc_offset_seconds': 10800, 'timezone': 'Asia/Aden', 'timezone_abbreviation': 'GMT+3', 'elevation': 980.0}
# Fetching data for: Mayotte - Lat: -12.8275, Lon: 45.166244
# API request for coordinates: Lat=-12.8275, Lon=45.166244
# Received data for Lat=-12.8275, Lon=45.166244: {'latitude': -12.799995, 'longitude': 45.199997, 'generationtime_ms': 0.0027418136596679688, 'utc_offset_seconds': 10800, 'timezone': 'Indian/Mayotte', 'timezone_abbreviation': 'GMT+3', 'elevation': 200.0}
# Fetching data for: South Africa - Lat: -30.559482, Lon: 22.937506
# API request for coordinates: Lat=-30.559482, Lon=22.937506
# Received data for Lat=-30.559482, Lon=22.937506: {'latitude': -30.599998, 'longitude': 22.90001, 'generationtime_ms': 0.0030994415283203125, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Johannesburg', 'timezone_abbreviation': 'GMT+2', 'elevation': 1106.0}
# Fetching data for: Zambia - Lat: -13.133897, Lon: 27.849332
# API request for coordinates: Lat=-13.133897, Lon=27.849332
# Received data for Lat=-13.133897, Lon=27.849332: {'latitude': -13.099998, 'longitude': 27.800003, 'generationtime_ms': 0.003337860107421875, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Lusaka', 'timezone_abbreviation': 'GMT+2', 'elevation': 1202.0}
# Fetching data for: Zimbabwe - Lat: -19.015438, Lon: 29.154857
# API request for coordinates: Lat=-19.015438, Lon=29.154857
# Received data for Lat=-19.015438, Lon=29.154857: {'latitude': -19.0, 'longitude': 29.199997, 'generationtime_ms': 0.00286102294921875, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Harare', 'timezone_abbreviation': 'GMT+2', 'elevation': 1240.0}

# %%
# Retrieve average air quality from https://air-quality-api.open-meteo.com per country for 2023

def get_air_quality(lat, lon):
    """Fetches air quality data for each countries latitude and longitude."""
    print(f"API request for coordinates: Lat={lat}, Lon={lon}")  # Debugging statement
    url1 = "https://air-quality-api.open-meteo.com/v1/air-quality"
    params = {
        "latitude": lat,
        "longitude": lon,
        "start_date": "2023-01-01",
        "end_date": "2023-12-31",
        "daily": ["pm10", "pm2_5", "no2", "so2", "o3"],  # Sadly, every country has a different timely resolution. How can I solve this issue?
        "timezone": "auto"
    }
    response = requests.get(url1, params=params)
    
    if response.status_code == 200:
        data = response.json()
        print(f"Received data for Lat={lat}, Lon={lon}: {data}")  # Print API response
        daily_data = data.get("daily", {})

        # Ensure pollutant data is available before computing averages
        # pollutants = ["pm10", "pm2_5", "no2", "so2", "o3"]
        # averages = []
        # for pollutant in pollutants:
        #    values = daily_data.get(pollutant, [])
        #    avg_value = sum(values) / len(values) if values else None
        #    averages.append(avg_value)
        # return tuple(averages)
        
        # Calculate annual averages for each pollutant
        avg_pm10 = sum(daily_data["pm10"]) / len(daily_data["pm10"]) if "pm10" in daily_data else None
        avg_pm2_5 = sum(daily_data["pm2_5"]) / len(daily_data["pm2_5"]) if "pm2_5" in daily_data else None
        avg_no2 = sum(daily_data["no2"]) / len(daily_data["no2"]) if "no2" in daily_data else None
        avg_so2 = sum(daily_data["so2"]) / len(daily_data["so2"]) if "so2" in daily_data else None
        avg_o3 = sum(daily_data["o3"]) / len(daily_data["o3"]) if "o3" in daily_data else None
        
        return avg_pm10, avg_pm2_5, avg_no2, avg_so2, avg_o3
        
    else:
        print(f"Error fetching data for lat={lat}, lon={lon}: {response.status_code}")
        return None, None, None, None, None

    # Log Missing or Empty Data:
    if not daily_data:
        print(f"No air quality data for lat={lat}, lon={lon}")
        
# Add air quality data to the countries dataframe
df_countries[['avg_pm10', 'avg_pm2_5', 'avg_no2', 'avg_so2', 'avg_o3']] = df_countries.apply(
    lambda row: get_air_quality(row['latitude'], row['longitude']), axis=1, result_type='expand'
)

# Save results to CSV
df_countries.to_csv("countries_air_quality_2023.csv", index=False)

print("Data collection complete. Results saved to air_quality_2023.csv")
# Out:
# API request for coordinates: Lat=42.546245, Lon=1.601554
# Received data for Lat=42.546245, Lon=1.601554: {'latitude': 42.5, 'longitude': 1.6000004, 'generationtime_ms': 0.0030994415283203125, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Andorra', 'timezone_abbreviation': 'GMT+1', 'elevation': 1943.0}
# API request for coordinates: Lat=23.424076, Lon=53.847818
# Received data for Lat=23.424076, Lon=53.847818: {'latitude': 23.400002, 'longitude': 53.800003, 'generationtime_ms': 0.0022649765014648438, 'utc_offset_seconds': 14400, 'timezone': 'Asia/Dubai', 'timezone_abbreviation': 'GMT+4', 'elevation': 155.0}
# API request for coordinates: Lat=33.93911, Lon=67.709953
# Received data for Lat=33.93911, Lon=67.709953: {'latitude': 33.9, 'longitude': 67.7, 'generationtime_ms': 0.0030994415283203125, 'utc_offset_seconds': 16200, 'timezone': 'Asia/Kabul', 'timezone_abbreviation': 'GMT+4:30', 'elevation': 3777.0}
# API request for coordinates: Lat=17.060816, Lon=-61.796428
# Received data for Lat=17.060816, Lon=-61.796428: {'latitude': 17.099998, 'longitude': -61.799995, 'generationtime_ms': 0.0069141387939453125, 'utc_offset_seconds': -14400, 'timezone': 'America/Antigua', 'timezone_abbreviation': 'GMT-4', 'elevation': 67.0}
# API request for coordinates: Lat=18.220554, Lon=-63.068615
# Received data for Lat=18.220554, Lon=-63.068615: {'latitude': 18.200005, 'longitude': -63.1, 'generationtime_ms': 0.00667572021484375, 'utc_offset_seconds': -14400, 'timezone': 'America/Anguilla', 'timezone_abbreviation': 'GMT-4', 'elevation': 0.0}
# API request for coordinates: Lat=41.153332, Lon=20.168331
# Received data for Lat=41.153332, Lon=20.168331: {'latitude': 41.2, 'longitude': 20.2, 'generationtime_ms': 0.005125999450683594, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Tirane', 'timezone_abbreviation': 'GMT+1', 'elevation': 149.0}
# API request for coordinates: Lat=40.069099, Lon=45.038189
# Received data for Lat=40.069099, Lon=45.038189: {'latitude': 40.1, 'longitude': 45.0, 'generationtime_ms': 0.002384185791015625, 'utc_offset_seconds': 14400, 'timezone': 'Asia/Yerevan', 'timezone_abbreviation': 'GMT+4', 'elevation': 2769.0}
# API request for coordinates: Lat=12.226079, Lon=-69.060087
# Received data for Lat=12.226079, Lon=-69.060087: {'latitude': 12.200005, 'longitude': -69.1, 'generationtime_ms': 0.0059604644775390625, 'utc_offset_seconds': -14400, 'timezone': 'America/Curacao', 'timezone_abbreviation': 'GMT-4', 'elevation': 41.0}
# API request for coordinates: Lat=-11.202692, Lon=17.873887
# Received data for Lat=-11.202692, Lon=17.873887: {'latitude': -11.199997, 'longitude': 17.90001, 'generationtime_ms': 0.00762939453125, 'utc_offset_seconds': 3600, 'timezone': 'Africa/Luanda', 'timezone_abbreviation': 'GMT+1', 'elevation': 1135.0}
# API request for coordinates: Lat=-75.250973, Lon=-0.071389
# Received data for Lat=-75.250973, Lon=-0.071389: {'latitude': -75.3, 'longitude': -0.099990845, 'generationtime_ms': 0.003337860107421875, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Johannesburg', 'timezone_abbreviation': 'GMT+2', 'elevation': 2855.0}
# API request for coordinates: Lat=-38.416097, Lon=-63.616672
# Received data for Lat=-38.416097, Lon=-63.616672: {'latitude': -38.399998, 'longitude': -63.6, 'generationtime_ms': 0.007748603820800781, 'utc_offset_seconds': -10800, 'timezone': 'America/Argentina/Salta', 'timezone_abbreviation': 'GMT-3', 'elevation': 113.0}
# API request for coordinates: Lat=-14.270972, Lon=-170.132217
# Received data for Lat=-14.270972, Lon=-170.132217: {'latitude': -14.299995, 'longitude': -170.1, 'generationtime_ms': 0.006318092346191406, 'utc_offset_seconds': -39600, 'timezone': 'Etc/GMT+11', 'timezone_abbreviation': 'GMT-11', 'elevation': 0.0}
# API request for coordinates: Lat=47.516231, Lon=14.550072
# Received data for Lat=47.516231, Lon=14.550072: {'latitude': 47.5, 'longitude': 14.600002, 'generationtime_ms': 0.004887580871582031, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Vienna', 'timezone_abbreviation': 'GMT+1', 'elevation': 1191.0}
# API request for coordinates: Lat=-25.274398, Lon=133.775136
# Received data for Lat=-25.274398, Lon=133.775136: {'latitude': -25.299995, 'longitude': 133.80002, 'generationtime_ms': 0.008940696716308594, 'utc_offset_seconds': 34200, 'timezone': 'Australia/Darwin', 'timezone_abbreviation': 'GMT+9:30', 'elevation': 396.0}
# API request for coordinates: Lat=12.52111, Lon=-69.968338
# Received data for Lat=12.52111, Lon=-69.968338: {'latitude': 12.5, 'longitude': -70.0, 'generationtime_ms': 0.0064373016357421875, 'utc_offset_seconds': -14400, 'timezone': 'America/Aruba', 'timezone_abbreviation': 'GMT-4', 'elevation': 59.0}
# API request for coordinates: Lat=40.143105, Lon=47.576927
# Received data for Lat=40.143105, Lon=47.576927: {'latitude': 40.100006, 'longitude': 47.600006, 'generationtime_ms': 0.003337860107421875, 'utc_offset_seconds': 14400, 'timezone': 'Asia/Baku', 'timezone_abbreviation': 'GMT+4', 'elevation': -2.0}
# API request for coordinates: Lat=43.915886, Lon=17.679076
# Received data for Lat=43.915886, Lon=17.679076: {'latitude': 43.9, 'longitude': 17.7, 'generationtime_ms': 0.004291534423828125, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Sarajevo', 'timezone_abbreviation': 'GMT+1', 'elevation': 1750.0}
# API request for coordinates: Lat=13.193887, Lon=-59.543198
# Received data for Lat=13.193887, Lon=-59.543198: {'latitude': 13.200005, 'longitude': -59.5, 'generationtime_ms': 0.0035762786865234375, 'utc_offset_seconds': -14400, 'timezone': 'America/Barbados', 'timezone_abbreviation': 'GMT-4', 'elevation': 321.0}
# API request for coordinates: Lat=23.684994, Lon=90.356331
# Received data for Lat=23.684994, Lon=90.356331: {'latitude': 23.700005, 'longitude': 90.399994, 'generationtime_ms': 0.005841255187988281, 'utc_offset_seconds': 21600, 'timezone': 'Asia/Dhaka', 'timezone_abbreviation': 'GMT+6', 'elevation': 3.0}
# API request for coordinates: Lat=50.503887, Lon=4.469936
# Received data for Lat=50.503887, Lon=4.469936: {'latitude': 50.5, 'longitude': 4.5, 'generationtime_ms': 0.005245208740234375, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Brussels', 'timezone_abbreviation': 'GMT+1', 'elevation': 142.0}
# API request for coordinates: Lat=12.238333, Lon=-1.561593
# Received data for Lat=12.238333, Lon=-1.561593: {'latitude': 12.200005, 'longitude': -1.5999908, 'generationtime_ms': 0.0030994415283203125, 'utc_offset_seconds': 0, 'timezone': 'Africa/Ouagadougou', 'timezone_abbreviation': 'GMT', 'elevation': 297.0}
# API request for coordinates: Lat=42.733883, Lon=25.48583
# Received data for Lat=42.733883, Lon=25.48583: {'latitude': 42.7, 'longitude': 25.5, 'generationtime_ms': 0.003933906555175781, 'utc_offset_seconds': 7200, 'timezone': 'Europe/Sofia', 'timezone_abbreviation': 'GMT+2', 'elevation': 1131.0}
# API request for coordinates: Lat=25.930414, Lon=50.637772
# Received data for Lat=25.930414, Lon=50.637772: {'latitude': 25.900002, 'longitude': 50.600006, 'generationtime_ms': 0.004291534423828125, 'utc_offset_seconds': 10800, 'timezone': 'Asia/Bahrain', 'timezone_abbreviation': 'GMT+3', 'elevation': 0.0}
# API request for coordinates: Lat=-3.373056, Lon=29.918886
# Received data for Lat=-3.373056, Lon=29.918886: {'latitude': -3.4000015, 'longitude': 29.90001, 'generationtime_ms': 0.0057220458984375, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Bujumbura', 'timezone_abbreviation': 'GMT+2', 'elevation': 1711.0}
# API request for coordinates: Lat=9.30769, Lon=2.315834
# Received data for Lat=9.30769, Lon=2.315834: {'latitude': 9.300003, 'longitude': 2.300003, 'generationtime_ms': 0.006318092346191406, 'utc_offset_seconds': 3600, 'timezone': 'Africa/Porto-Novo', 'timezone_abbreviation': 'GMT+1', 'elevation': 340.0}
# API request for coordinates: Lat=32.321384, Lon=-64.75737
# Received data for Lat=32.321384, Lon=-64.75737: {'latitude': 32.300003, 'longitude': -64.799995, 'generationtime_ms': 0.0027418136596679688, 'utc_offset_seconds': -14400, 'timezone': 'Atlantic/Bermuda', 'timezone_abbreviation': 'GMT-4', 'elevation': 0.0}
# API request for coordinates: Lat=4.535277, Lon=114.727669
# Received data for Lat=4.535277, Lon=114.727669: {'latitude': 4.5, 'longitude': 114.70001, 'generationtime_ms': 0.003933906555175781, 'utc_offset_seconds': 28800, 'timezone': 'Asia/Brunei', 'timezone_abbreviation': 'GMT+8', 'elevation': 61.0}
# API request for coordinates: Lat=-16.290154, Lon=-63.588653
# Received data for Lat=-16.290154, Lon=-63.588653: {'latitude': -16.299995, 'longitude': -63.6, 'generationtime_ms': 0.004887580871582031, 'utc_offset_seconds': -14400, 'timezone': 'America/La_Paz', 'timezone_abbreviation': 'GMT-4', 'elevation': 200.0}
# API request for coordinates: Lat=-14.235004, Lon=-51.92528
# Received data for Lat=-14.235004, Lon=-51.92528: {'latitude': -14.199997, 'longitude': -51.899994, 'generationtime_ms': 0.0032186508178710938, 'utc_offset_seconds': -14400, 'timezone': 'America/Cuiaba', 'timezone_abbreviation': 'GMT-4', 'elevation': 259.0}
# API request for coordinates: Lat=25.03428, Lon=-77.39628
# Received data for Lat=25.03428, Lon=-77.39628: {'latitude': 25.0, 'longitude': -77.4, 'generationtime_ms': 0.0027418136596679688, 'utc_offset_seconds': -18000, 'timezone': 'America/Nassau', 'timezone_abbreviation': 'GMT-5', 'elevation': 5.0}
# API request for coordinates: Lat=27.514162, Lon=90.433601
# Received data for Lat=27.514162, Lon=90.433601: {'latitude': 27.5, 'longitude': 90.399994, 'generationtime_ms': 0.007271766662597656, 'utc_offset_seconds': 21600, 'timezone': 'Asia/Thimphu', 'timezone_abbreviation': 'GMT+6', 'elevation': 2583.0}
# API request for coordinates: Lat=-54.423199, Lon=3.413194
# Received data for Lat=-54.423199, Lon=3.413194: {'latitude': -54.399998, 'longitude': 3.4000092, 'generationtime_ms': 0.0017881393432617188, 'utc_offset_seconds': 0, 'timezone': 'Etc/GMT', 'timezone_abbreviation': 'GMT', 'elevation': 222.0}
# API request for coordinates: Lat=-22.328474, Lon=24.684866
# Received data for Lat=-22.328474, Lon=24.684866: {'latitude': -22.299995, 'longitude': 24.699997, 'generationtime_ms': 0.0027418136596679688, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Gaborone', 'timezone_abbreviation': 'GMT+2', 'elevation': 1015.0}
# API request for coordinates: Lat=53.709807, Lon=27.953389
# Received data for Lat=53.709807, Lon=27.953389: {'latitude': 53.7, 'longitude': 28.0, 'generationtime_ms': 0.0035762786865234375, 'utc_offset_seconds': 10800, 'timezone': 'Europe/Minsk', 'timezone_abbreviation': 'GMT+3', 'elevation': 190.0}
# API request for coordinates: Lat=17.189877, Lon=-88.49765
# Received data for Lat=17.189877, Lon=-88.49765: {'latitude': 17.200005, 'longitude': -88.5, 'generationtime_ms': 0.004291534423828125, 'utc_offset_seconds': -21600, 'timezone': 'America/Belize', 'timezone_abbreviation': 'GMT-6', 'elevation': 37.0}
# API request for coordinates: Lat=56.130366, Lon=-106.346771
# Received data for Lat=56.130366, Lon=-106.346771: {'latitude': 56.100006, 'longitude': -106.299995, 'generationtime_ms': 0.005125999450683594, 'utc_offset_seconds': -21600, 'timezone': 'America/Regina', 'timezone_abbreviation': 'GMT-6', 'elevation': 478.0}
# API request for coordinates: Lat=-12.164165, Lon=96.870956
# Received data for Lat=-12.164165, Lon=96.870956: {'latitude': -12.199997, 'longitude': 96.899994, 'generationtime_ms': 0.0021457672119140625, 'utc_offset_seconds': 23400, 'timezone': 'Indian/Cocos', 'timezone_abbreviation': 'GMT+6:30', 'elevation': 0.0}
# API request for coordinates: Lat=-4.038333, Lon=21.758664
# Received data for Lat=-4.038333, Lon=21.758664: {'latitude': -4.0, 'longitude': 21.800003, 'generationtime_ms': 0.0035762786865234375, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Lubumbashi', 'timezone_abbreviation': 'GMT+2', 'elevation': 420.0}
# API request for coordinates: Lat=6.611111, Lon=20.939444
# Received data for Lat=6.611111, Lon=20.939444: {'latitude': 6.5999985, 'longitude': 20.90001, 'generationtime_ms': 0.004410743713378906, 'utc_offset_seconds': 3600, 'timezone': 'Africa/Bangui', 'timezone_abbreviation': 'GMT+1', 'elevation': 621.0}
# API request for coordinates: Lat=-0.228021, Lon=15.827659
# Received data for Lat=-0.228021, Lon=15.827659: {'latitude': -0.19999695, 'longitude': 15.800003, 'generationtime_ms': 0.0017881393432617188, 'utc_offset_seconds': 3600, 'timezone': 'Africa/Brazzaville', 'timezone_abbreviation': 'GMT+1', 'elevation': 331.0}
# API request for coordinates: Lat=46.818188, Lon=8.227512
# Received data for Lat=46.818188, Lon=8.227512: {'latitude': 46.800003, 'longitude': 8.200001, 'generationtime_ms': 0.002384185791015625, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Zurich', 'timezone_abbreviation': 'GMT+1', 'elevation': 1507.0}
# API request for coordinates: Lat=7.539989, Lon=-5.54708
# Received data for Lat=7.539989, Lon=-5.54708: {'latitude': 7.5, 'longitude': -5.5, 'generationtime_ms': 0.0054836273193359375, 'utc_offset_seconds': 0, 'timezone': 'Africa/Abidjan', 'timezone_abbreviation': 'GMT', 'elevation': 237.0}
# API request for coordinates: Lat=-21.236736, Lon=-159.777671
# Received data for Lat=-21.236736, Lon=-159.777671: {'latitude': -21.199997, 'longitude': -159.8, 'generationtime_ms': 0.0026226043701171875, 'utc_offset_seconds': -36000, 'timezone': 'Pacific/Rarotonga', 'timezone_abbreviation': 'GMT-10', 'elevation': 306.0}
# API request for coordinates: Lat=-35.675147, Lon=-71.542969
# Received data for Lat=-35.675147, Lon=-71.542969: {'latitude': -35.7, 'longitude': -71.5, 'generationtime_ms': 0.0015497207641601562, 'utc_offset_seconds': -10800, 'timezone': 'America/Santiago', 'timezone_abbreviation': 'GMT-3', 'elevation': 187.0}
# API request for coordinates: Lat=7.369722, Lon=12.354722
# Received data for Lat=7.369722, Lon=12.354722: {'latitude': 7.4000015, 'longitude': 12.400009, 'generationtime_ms': 0.0022649765014648438, 'utc_offset_seconds': 3600, 'timezone': 'Africa/Douala', 'timezone_abbreviation': 'GMT+1', 'elevation': 1299.0}
# API request for coordinates: Lat=35.86166, Lon=104.195397
# Received data for Lat=35.86166, Lon=104.195397: {'latitude': 35.9, 'longitude': 104.20001, 'generationtime_ms': 0.0017881393432617188, 'utc_offset_seconds': 28800, 'timezone': 'Asia/Shanghai', 'timezone_abbreviation': 'GMT+8', 'elevation': 1836.0}
# API request for coordinates: Lat=4.570868, Lon=-74.297333
# Received data for Lat=4.570868, Lon=-74.297333: {'latitude': 4.5999985, 'longitude': -74.299995, 'generationtime_ms': 0.0019073486328125, 'utc_offset_seconds': -18000, 'timezone': 'America/Bogota', 'timezone_abbreviation': 'GMT-5', 'elevation': 2497.0}
# API request for coordinates: Lat=9.748917, Lon=-83.753428
# Received data for Lat=9.748917, Lon=-83.753428: {'latitude': 9.700005, 'longitude': -83.799995, 'generationtime_ms': 0.0016689300537109375, 'utc_offset_seconds': -21600, 'timezone': 'America/Costa_Rica', 'timezone_abbreviation': 'GMT-6', 'elevation': 1391.0}
# API request for coordinates: Lat=21.521757, Lon=-77.781167
# Received data for Lat=21.521757, Lon=-77.781167: {'latitude': 21.5, 'longitude': -77.799995, 'generationtime_ms': 0.0059604644775390625, 'utc_offset_seconds': -18000, 'timezone': 'America/Havana', 'timezone_abbreviation': 'GMT-5', 'elevation': 71.0}
# API request for coordinates: Lat=16.002082, Lon=-24.013197
# Received data for Lat=16.002082, Lon=-24.013197: {'latitude': 16.0, 'longitude': -24.0, 'generationtime_ms': 0.00476837158203125, 'utc_offset_seconds': -3600, 'timezone': 'Atlantic/Cape_Verde', 'timezone_abbreviation': 'GMT-1', 'elevation': 0.0}
# API request for coordinates: Lat=-10.447525, Lon=105.690449
# Received data for Lat=-10.447525, Lon=105.690449: {'latitude': -10.400002, 'longitude': 105.70001, 'generationtime_ms': 0.0027418136596679688, 'utc_offset_seconds': 25200, 'timezone': 'Indian/Christmas', 'timezone_abbreviation': 'GMT+7', 'elevation': 270.0}
# API request for coordinates: Lat=35.126413, Lon=33.429859
# Received data for Lat=35.126413, Lon=33.429859: {'latitude': 35.1, 'longitude': 33.4, 'generationtime_ms': 0.0026226043701171875, 'utc_offset_seconds': 7200, 'timezone': 'Asia/Nicosia', 'timezone_abbreviation': 'GMT+2', 'elevation': 143.0}
# API request for coordinates: Lat=49.817492, Lon=15.472962
# Received data for Lat=49.817492, Lon=15.472962: {'latitude': 49.800003, 'longitude': 15.5, 'generationtime_ms': 0.003814697265625, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Prague', 'timezone_abbreviation': 'GMT+1', 'elevation': 373.0}
# API request for coordinates: Lat=51.165691, Lon=10.451526
# Received data for Lat=51.165691, Lon=10.451526: {'latitude': 51.2, 'longitude': 10.5, 'generationtime_ms': 0.001430511474609375, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Berlin', 'timezone_abbreviation': 'GMT+1', 'elevation': 203.0}
# API request for coordinates: Lat=11.825138, Lon=42.590275
# Received data for Lat=11.825138, Lon=42.590275: {'latitude': 11.800003, 'longitude': 42.600006, 'generationtime_ms': 0.0054836273193359375, 'utc_offset_seconds': 10800, 'timezone': 'Africa/Djibouti', 'timezone_abbreviation': 'GMT+3', 'elevation': 1289.0}
# API request for coordinates: Lat=56.26392, Lon=9.501785
# Received data for Lat=56.26392, Lon=9.501785: {'latitude': 56.300003, 'longitude': 9.5, 'generationtime_ms': 0.005364418029785156, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Copenhagen', 'timezone_abbreviation': 'GMT+1', 'elevation': 50.0}
# API request for coordinates: Lat=15.414999, Lon=-61.370976
# Received data for Lat=15.414999, Lon=-61.370976: {'latitude': 15.400002, 'longitude': -61.4, 'generationtime_ms': 0.0029802322387695312, 'utc_offset_seconds': -14400, 'timezone': 'America/Dominica', 'timezone_abbreviation': 'GMT-4', 'elevation': 287.0}
# API request for coordinates: Lat=18.735693, Lon=-70.162651
# Received data for Lat=18.735693, Lon=-70.162651: {'latitude': 18.700005, 'longitude': -70.2, 'generationtime_ms': 0.0021457672119140625, 'utc_offset_seconds': -14400, 'timezone': 'America/Santo_Domingo', 'timezone_abbreviation': 'GMT-4', 'elevation': 908.0}
# API request for coordinates: Lat=28.033886, Lon=1.659626
# Received data for Lat=28.033886, Lon=1.659626: {'latitude': 28.0, 'longitude': 1.699997, 'generationtime_ms': 0.003933906555175781, 'utc_offset_seconds': 3600, 'timezone': 'Africa/Algiers', 'timezone_abbreviation': 'GMT+1', 'elevation': 549.0}
# API request for coordinates: Lat=-1.831239, Lon=-78.183406
# Received data for Lat=-1.831239, Lon=-78.183406: {'latitude': -1.7999954, 'longitude': -78.2, 'generationtime_ms': 0.002384185791015625, 'utc_offset_seconds': -18000, 'timezone': 'America/Guayaquil', 'timezone_abbreviation': 'GMT-5', 'elevation': 1354.0}
# API request for coordinates: Lat=58.595272, Lon=25.013607
# Received data for Lat=58.595272, Lon=25.013607: {'latitude': 58.6, 'longitude': 25.0, 'generationtime_ms': 0.0025033950805664062, 'utc_offset_seconds': 7200, 'timezone': 'Europe/Tallinn', 'timezone_abbreviation': 'GMT+2', 'elevation': 37.0}
# API request for coordinates: Lat=26.820553, Lon=30.802498
# Received data for Lat=26.820553, Lon=30.802498: {'latitude': 26.800003, 'longitude': 30.800003, 'generationtime_ms': 0.0021457672119140625, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Cairo', 'timezone_abbreviation': 'GMT+2', 'elevation': 288.0}
# API request for coordinates: Lat=24.215527, Lon=-12.885834
# Received data for Lat=24.215527, Lon=-12.885834: {'latitude': 24.200005, 'longitude': -12.899994, 'generationtime_ms': 0.009655952453613281, 'utc_offset_seconds': 0, 'timezone': 'Africa/El_Aaiun', 'timezone_abbreviation': 'GMT', 'elevation': 215.0}
# API request for coordinates: Lat=15.179384, Lon=39.782334
# Received data for Lat=15.179384, Lon=39.782334: {'latitude': 15.200005, 'longitude': 39.800003, 'generationtime_ms': 0.0040531158447265625, 'utc_offset_seconds': 10800, 'timezone': 'Africa/Asmara', 'timezone_abbreviation': 'GMT+3', 'elevation': 0.0}
# API request for coordinates: Lat=40.463667, Lon=-3.74922
# Received data for Lat=40.463667, Lon=-3.74922: {'latitude': 40.5, 'longitude': -3.6999989, 'generationtime_ms': 0.0040531158447265625, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Madrid', 'timezone_abbreviation': 'GMT+1', 'elevation': 591.0}
# API request for coordinates: Lat=9.145, Lon=40.489673
# Received data for Lat=9.145, Lon=40.489673: {'latitude': 9.099998, 'longitude': 40.5, 'generationtime_ms': 0.0017881393432617188, 'utc_offset_seconds': 10800, 'timezone': 'Africa/Addis_Ababa', 'timezone_abbreviation': 'GMT+3', 'elevation': 1355.0}
# API request for coordinates: Lat=61.92411, Lon=25.748151
# Received data for Lat=61.92411, Lon=25.748151: {'latitude': 61.9, 'longitude': 25.7, 'generationtime_ms': 0.0015497207641601562, 'utc_offset_seconds': 7200, 'timezone': 'Europe/Helsinki', 'timezone_abbreviation': 'GMT+2', 'elevation': 175.0}
# API request for coordinates: Lat=-16.578193, Lon=179.414413
# Received data for Lat=-16.578193, Lon=179.414413: {'latitude': -16.599998, 'longitude': 179.4, 'generationtime_ms': 0.002384185791015625, 'utc_offset_seconds': 43200, 'timezone': 'Pacific/Fiji', 'timezone_abbreviation': 'GMT+12', 'elevation': 546.0}
# API request for coordinates: Lat=-51.796253, Lon=-59.523613
# Received data for Lat=-51.796253, Lon=-59.523613: {'latitude': -51.8, 'longitude': -59.5, 'generationtime_ms': 0.0029802322387695312, 'utc_offset_seconds': -10800, 'timezone': 'Atlantic/Stanley', 'timezone_abbreviation': 'GMT-3', 'elevation': 0.0}
# API request for coordinates: Lat=7.425554, Lon=150.550812
# Received data for Lat=7.425554, Lon=150.550812: {'latitude': 7.4000015, 'longitude': 150.6, 'generationtime_ms': 0.0029802322387695312, 'utc_offset_seconds': 36000, 'timezone': 'Etc/GMT-10', 'timezone_abbreviation': 'GMT+10', 'elevation': 0.0}
# API request for coordinates: Lat=61.892635, Lon=-6.911806
# Received data for Lat=61.892635, Lon=-6.911806: {'latitude': 61.9, 'longitude': -6.8999996, 'generationtime_ms': 0.0020265579223632812, 'utc_offset_seconds': 0, 'timezone': 'Atlantic/Faroe', 'timezone_abbreviation': 'GMT', 'elevation': 218.0}
# API request for coordinates: Lat=46.227638, Lon=2.213749
# Received data for Lat=46.227638, Lon=2.213749: {'latitude': 46.2, 'longitude': 2.2000008, 'generationtime_ms': 0.0050067901611328125, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Paris', 'timezone_abbreviation': 'GMT+1', 'elevation': 427.0}
# API request for coordinates: Lat=-0.803689, Lon=11.609444
# Received data for Lat=-0.803689, Lon=11.609444: {'latitude': -0.7999954, 'longitude': 11.600006, 'generationtime_ms': 0.0017881393432617188, 'utc_offset_seconds': 3600, 'timezone': 'Africa/Libreville', 'timezone_abbreviation': 'GMT+1', 'elevation': 519.0}
# API request for coordinates: Lat=55.378051, Lon=-3.435973
# Received data for Lat=55.378051, Lon=-3.435973: {'latitude': 55.4, 'longitude': -3.3999996, 'generationtime_ms': 0.0036954879760742188, 'utc_offset_seconds': 0, 'timezone': 'Europe/London', 'timezone_abbreviation': 'GMT', 'elevation': 370.0}
# API request for coordinates: Lat=12.262776, Lon=-61.604171
# Received data for Lat=12.262776, Lon=-61.604171: {'latitude': 12.300003, 'longitude': -61.6, 'generationtime_ms': 0.005245208740234375, 'utc_offset_seconds': -14400, 'timezone': 'America/Grenada', 'timezone_abbreviation': 'GMT-4', 'elevation': 0.0}
# API request for coordinates: Lat=42.315407, Lon=43.356892
# Received data for Lat=42.315407, Lon=43.356892: {'latitude': 42.3, 'longitude': 43.4, 'generationtime_ms': 0.005364418029785156, 'utc_offset_seconds': 14400, 'timezone': 'Asia/Tbilisi', 'timezone_abbreviation': 'GMT+4', 'elevation': 499.0}
# API request for coordinates: Lat=3.933889, Lon=-53.125782
# Received data for Lat=3.933889, Lon=-53.125782: {'latitude': 3.9000015, 'longitude': -53.1, 'generationtime_ms': 0.0050067901611328125, 'utc_offset_seconds': -10800, 'timezone': 'America/Cayenne', 'timezone_abbreviation': 'GMT-3', 'elevation': 278.0}
# API request for coordinates: Lat=49.465691, Lon=-2.585278
# Received data for Lat=49.465691, Lon=-2.585278: {'latitude': 49.5, 'longitude': -2.6000004, 'generationtime_ms': 0.0059604644775390625, 'utc_offset_seconds': 0, 'timezone': 'Europe/Guernsey', 'timezone_abbreviation': 'GMT', 'elevation': 54.0}
# API request for coordinates: Lat=7.946527, Lon=-1.023194
# Received data for Lat=7.946527, Lon=-1.023194: {'latitude': 7.9000015, 'longitude': -1.0, 'generationtime_ms': 0.006318092346191406, 'utc_offset_seconds': 0, 'timezone': 'Africa/Accra', 'timezone_abbreviation': 'GMT', 'elevation': 124.0}
# API request for coordinates: Lat=36.137741, Lon=-5.345374
# Received data for Lat=36.137741, Lon=-5.345374: {'latitude': 36.1, 'longitude': -5.299999, 'generationtime_ms': 0.0010728836059570312, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Gibraltar', 'timezone_abbreviation': 'GMT+1', 'elevation': 271.0}
# API request for coordinates: Lat=71.706936, Lon=-42.604303
# Received data for Lat=71.706936, Lon=-42.604303: {'latitude': 71.7, 'longitude': -42.59999, 'generationtime_ms': 0.006079673767089844, 'utc_offset_seconds': -7200, 'timezone': 'America/Godthab', 'timezone_abbreviation': 'GMT-2', 'elevation': 2892.0}
# API request for coordinates: Lat=13.443182, Lon=-15.310139
# Received data for Lat=13.443182, Lon=-15.310139: {'latitude': 13.400002, 'longitude': -15.300003, 'generationtime_ms': 0.003933906555175781, 'utc_offset_seconds': 0, 'timezone': 'Africa/Banjul', 'timezone_abbreviation': 'GMT', 'elevation': 15.0}
# API request for coordinates: Lat=9.945587, Lon=-9.696645
# Received data for Lat=9.945587, Lon=-9.696645: {'latitude': 9.900002, 'longitude': -9.699997, 'generationtime_ms': 0.006794929504394531, 'utc_offset_seconds': 0, 'timezone': 'Africa/Conakry', 'timezone_abbreviation': 'GMT', 'elevation': 412.0}
# API request for coordinates: Lat=16.995971, Lon=-62.067641
# Received data for Lat=16.995971, Lon=-62.067641: {'latitude': 17.0, 'longitude': -62.1, 'generationtime_ms': 0.0034570693969726562, 'utc_offset_seconds': -14400, 'timezone': 'America/Antigua', 'timezone_abbreviation': 'GMT-4', 'elevation': 0.0}
# API request for coordinates: Lat=1.650801, Lon=10.267895
# Received data for Lat=1.650801, Lon=10.267895: {'latitude': 1.7000046, 'longitude': 10.300003, 'generationtime_ms': 0.0027418136596679688, 'utc_offset_seconds': 3600, 'timezone': 'Africa/Malabo', 'timezone_abbreviation': 'GMT+1', 'elevation': 925.0}
# API request for coordinates: Lat=39.074208, Lon=21.824312
# Received data for Lat=39.074208, Lon=21.824312: {'latitude': 39.1, 'longitude': 21.8, 'generationtime_ms': 0.004649162292480469, 'utc_offset_seconds': 7200, 'timezone': 'Europe/Athens', 'timezone_abbreviation': 'GMT+2', 'elevation': 864.0}
# API request for coordinates: Lat=-54.429579, Lon=-36.587909
# Received data for Lat=-54.429579, Lon=-36.587909: {'latitude': -54.399998, 'longitude': -36.59999, 'generationtime_ms': 0.0022649765014648438, 'utc_offset_seconds': -7200, 'timezone': 'Atlantic/South_Georgia', 'timezone_abbreviation': 'GMT-2', 'elevation': 2137.0}
# API request for coordinates: Lat=15.783471, Lon=-90.230759
# Received data for Lat=15.783471, Lon=-90.230759: {'latitude': 15.800003, 'longitude': -90.2, 'generationtime_ms': 0.005841255187988281, 'utc_offset_seconds': -21600, 'timezone': 'America/Guatemala', 'timezone_abbreviation': 'GMT-6', 'elevation': 369.0}
# API request for coordinates: Lat=13.444304, Lon=144.793731
# Received data for Lat=13.444304, Lon=144.793731: {'latitude': 13.400002, 'longitude': 144.80002, 'generationtime_ms': 0.0026226043701171875, 'utc_offset_seconds': 36000, 'timezone': 'Pacific/Guam', 'timezone_abbreviation': 'GMT+10', 'elevation': 47.0}
# API request for coordinates: Lat=11.803749, Lon=-15.180413
# Received data for Lat=11.803749, Lon=-15.180413: {'latitude': 11.800003, 'longitude': -15.199997, 'generationtime_ms': 0.0021457672119140625, 'utc_offset_seconds': 0, 'timezone': 'Africa/Bissau', 'timezone_abbreviation': 'GMT', 'elevation': 11.0}
# API request for coordinates: Lat=4.860416, Lon=-58.93018
# Received data for Lat=4.860416, Lon=-58.93018: {'latitude': 4.9000015, 'longitude': -58.9, 'generationtime_ms': 0.0040531158447265625, 'utc_offset_seconds': -14400, 'timezone': 'America/Guyana', 'timezone_abbreviation': 'GMT-4', 'elevation': 324.0}
# API request for coordinates: Lat=31.354676, Lon=34.308825
# Received data for Lat=31.354676, Lon=34.308825: {'latitude': 31.4, 'longitude': 34.3, 'generationtime_ms': 0.003814697265625, 'utc_offset_seconds': 7200, 'timezone': 'Asia/Gaza', 'timezone_abbreviation': 'GMT+2', 'elevation': 28.0}
# API request for coordinates: Lat=22.396428, Lon=114.109497
# Received data for Lat=22.396428, Lon=114.109497: {'latitude': 22.400002, 'longitude': 114.100006, 'generationtime_ms': 0.004291534423828125, 'utc_offset_seconds': 28800, 'timezone': 'Asia/Hong_Kong', 'timezone_abbreviation': 'GMT+8', 'elevation': 329.0}
# API request for coordinates: Lat=-53.08181, Lon=73.504158
# Received data for Lat=-53.08181, Lon=73.504158: {'latitude': -53.1, 'longitude': 73.5, 'generationtime_ms': 0.0036954879760742188, 'utc_offset_seconds': 18000, 'timezone': 'Etc/GMT-5', 'timezone_abbreviation': 'GMT+5', 'elevation': 2244.0}
# API request for coordinates: Lat=15.199999, Lon=-86.241905
# Received data for Lat=15.199999, Lon=-86.241905: {'latitude': 15.200005, 'longitude': -86.2, 'generationtime_ms': 0.006079673767089844, 'utc_offset_seconds': -21600, 'timezone': 'America/Tegucigalpa', 'timezone_abbreviation': 'GMT-6', 'elevation': 910.0}
# API request for coordinates: Lat=45.1, Lon=15.2
# Received data for Lat=45.1, Lon=15.2: {'latitude': 45.1, 'longitude': 15.200001, 'generationtime_ms': 0.0050067901611328125, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Zagreb', 'timezone_abbreviation': 'GMT+1', 'elevation': 909.0}
# API request for coordinates: Lat=18.971187, Lon=-72.285215
# Received data for Lat=18.971187, Lon=-72.285215: {'latitude': 19.0, 'longitude': -72.299995, 'generationtime_ms': 0.003933906555175781, 'utc_offset_seconds': -18000, 'timezone': 'America/Port-au-Prince', 'timezone_abbreviation': 'GMT-5', 'elevation': 352.0}
# API request for coordinates: Lat=47.162494, Lon=19.503304
# Received data for Lat=47.162494, Lon=19.503304: {'latitude': 47.2, 'longitude': 19.5, 'generationtime_ms': 0.0020265579223632812, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Budapest', 'timezone_abbreviation': 'GMT+1', 'elevation': 134.0}
# API request for coordinates: Lat=-0.789275, Lon=113.921327
# Received data for Lat=-0.789275, Lon=113.921327: {'latitude': -0.7999954, 'longitude': 113.899994, 'generationtime_ms': 0.006318092346191406, 'utc_offset_seconds': 25200, 'timezone': 'Asia/Pontianak', 'timezone_abbreviation': 'GMT+7', 'elevation': 104.0}
# API request for coordinates: Lat=53.41291, Lon=-8.24389
# Received data for Lat=53.41291, Lon=-8.24389: {'latitude': 53.4, 'longitude': -8.199999, 'generationtime_ms': 0.008463859558105469, 'utc_offset_seconds': 0, 'timezone': 'Europe/Dublin', 'timezone_abbreviation': 'GMT', 'elevation': 39.0}
# API request for coordinates: Lat=31.046051, Lon=34.851612
# Received data for Lat=31.046051, Lon=34.851612: {'latitude': 31.0, 'longitude': 34.9, 'generationtime_ms': 0.0054836273193359375, 'utc_offset_seconds': 7200, 'timezone': 'Asia/Jerusalem', 'timezone_abbreviation': 'GMT+2', 'elevation': 456.0}
# API request for coordinates: Lat=54.236107, Lon=-4.548056
# Received data for Lat=54.236107, Lon=-4.548056: {'latitude': 54.2, 'longitude': -4.5, 'generationtime_ms': 0.0040531158447265625, 'utc_offset_seconds': 0, 'timezone': 'Europe/Isle_of_Man', 'timezone_abbreviation': 'GMT', 'elevation': 372.0}
# API request for coordinates: Lat=20.593684, Lon=78.96288
# Received data for Lat=20.593684, Lon=78.96288: {'latitude': 20.599998, 'longitude': 79.0, 'generationtime_ms': 0.0050067901611328125, 'utc_offset_seconds': 19800, 'timezone': 'Asia/Kolkata', 'timezone_abbreviation': 'GMT+5:30', 'elevation': 245.0}
# API request for coordinates: Lat=-6.343194, Lon=71.876519
# Received data for Lat=-6.343194, Lon=71.876519: {'latitude': -6.2999954, 'longitude': 71.90001, 'generationtime_ms': 0.0057220458984375, 'utc_offset_seconds': 18000, 'timezone': 'Etc/GMT-5', 'timezone_abbreviation': 'GMT+5', 'elevation': 0.0}
# API request for coordinates: Lat=33.223191, Lon=43.679291
# Received data for Lat=33.223191, Lon=43.679291: {'latitude': 33.2, 'longitude': 43.700005, 'generationtime_ms': 0.0064373016357421875, 'utc_offset_seconds': 10800, 'timezone': 'Asia/Baghdad', 'timezone_abbreviation': 'GMT+3', 'elevation': 73.0}
# API request for coordinates: Lat=32.427908, Lon=53.688046
# Received data for Lat=32.427908, Lon=53.688046: {'latitude': 32.4, 'longitude': 53.699997, 'generationtime_ms': 0.0021457672119140625, 'utc_offset_seconds': 12600, 'timezone': 'Asia/Tehran', 'timezone_abbreviation': 'GMT+3:30', 'elevation': 1142.0}
# API request for coordinates: Lat=64.963051, Lon=-19.020835
# Received data for Lat=64.963051, Lon=-19.020835: {'latitude': 65.0, 'longitude': -19.0, 'generationtime_ms': 0.0017881393432617188, 'utc_offset_seconds': 0, 'timezone': 'Atlantic/Reykjavik', 'timezone_abbreviation': 'GMT', 'elevation': 816.0}
# API request for coordinates: Lat=41.87194, Lon=12.56738
# Received data for Lat=41.87194, Lon=12.56738: {'latitude': 41.9, 'longitude': 12.600002, 'generationtime_ms': 0.003814697265625, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Rome', 'timezone_abbreviation': 'GMT+1', 'elevation': 47.0}
# API request for coordinates: Lat=49.214439, Lon=-2.13125
# Received data for Lat=49.214439, Lon=-2.13125: {'latitude': 49.2, 'longitude': -2.1000004, 'generationtime_ms': 0.0026226043701171875, 'utc_offset_seconds': 0, 'timezone': 'Europe/Jersey', 'timezone_abbreviation': 'GMT', 'elevation': 62.0}
# API request for coordinates: Lat=18.109581, Lon=-77.297508
# Received data for Lat=18.109581, Lon=-77.297508: {'latitude': 18.099998, 'longitude': -77.299995, 'generationtime_ms': 0.0040531158447265625, 'utc_offset_seconds': -18000, 'timezone': 'America/Jamaica', 'timezone_abbreviation': 'GMT-5', 'elevation': 207.0}
# API request for coordinates: Lat=30.585164, Lon=36.238414
# Received data for Lat=30.585164, Lon=36.238414: {'latitude': 30.6, 'longitude': 36.2, 'generationtime_ms': 0.0073909759521484375, 'utc_offset_seconds': 10800, 'timezone': 'Asia/Amman', 'timezone_abbreviation': 'GMT+3', 'elevation': 910.0}
# API request for coordinates: Lat=36.204824, Lon=138.252924
# Received data for Lat=36.204824, Lon=138.252924: {'latitude': 36.200005, 'longitude': 138.30002, 'generationtime_ms': 0.003933906555175781, 'utc_offset_seconds': 32400, 'timezone': 'Asia/Tokyo', 'timezone_abbreviation': 'GMT+9', 'elevation': 1006.0}
# API request for coordinates: Lat=-0.023559, Lon=37.906193
# Received data for Lat=-0.023559, Lon=37.906193: {'latitude': 0.0, 'longitude': 37.90001, 'generationtime_ms': 0.0020265579223632812, 'utc_offset_seconds': 10800, 'timezone': 'Africa/Nairobi', 'timezone_abbreviation': 'GMT+3', 'elevation': 821.0}
# API request for coordinates: Lat=41.20438, Lon=74.766098
# Received data for Lat=41.20438, Lon=74.766098: {'latitude': 41.199997, 'longitude': 74.8, 'generationtime_ms': 0.006079673767089844, 'utc_offset_seconds': 21600, 'timezone': 'Asia/Bishkek', 'timezone_abbreviation': 'GMT+6', 'elevation': 2118.0}
# API request for coordinates: Lat=12.565679, Lon=104.990963
# Received data for Lat=12.565679, Lon=104.990963: {'latitude': 12.599998, 'longitude': 105.0, 'generationtime_ms': 0.008106231689453125, 'utc_offset_seconds': 25200, 'timezone': 'Asia/Phnom_Penh', 'timezone_abbreviation': 'GMT+7', 'elevation': 9.0}
# API request for coordinates: Lat=-3.370417, Lon=-168.734039
# Received data for Lat=-3.370417, Lon=-168.734039: {'latitude': -3.4000015, 'longitude': -168.7, 'generationtime_ms': 0.00476837158203125, 'utc_offset_seconds': -39600, 'timezone': 'Etc/GMT+11', 'timezone_abbreviation': 'GMT-11', 'elevation': 0.0}
# API request for coordinates: Lat=-11.875001, Lon=43.872219
# Received data for Lat=-11.875001, Lon=43.872219: {'latitude': -11.900002, 'longitude': 43.90001, 'generationtime_ms': 0.00476837158203125, 'utc_offset_seconds': 10800, 'timezone': 'Indian/Comoro', 'timezone_abbreviation': 'GMT+3', 'elevation': 0.0}
# API request for coordinates: Lat=17.357822, Lon=-62.782998
# Received data for Lat=17.357822, Lon=-62.782998: {'latitude': 17.400002, 'longitude': -62.799995, 'generationtime_ms': 0.00858306884765625, 'utc_offset_seconds': -14400, 'timezone': 'America/St_Kitts', 'timezone_abbreviation': 'GMT-4', 'elevation': 719.0}
# API request for coordinates: Lat=40.339852, Lon=127.510093
# Received data for Lat=40.339852, Lon=127.510093: {'latitude': 40.300003, 'longitude': 127.5, 'generationtime_ms': 0.0034570693969726562, 'utc_offset_seconds': 32400, 'timezone': 'Asia/Pyongyang', 'timezone_abbreviation': 'GMT+9', 'elevation': 841.0}
# API request for coordinates: Lat=35.907757, Lon=127.766922
# Received data for Lat=35.907757, Lon=127.766922: {'latitude': 35.9, 'longitude': 127.80002, 'generationtime_ms': 0.004410743713378906, 'utc_offset_seconds': 32400, 'timezone': 'Asia/Seoul', 'timezone_abbreviation': 'GMT+9', 'elevation': 576.0}
# API request for coordinates: Lat=29.31166, Lon=47.481766
# Received data for Lat=29.31166, Lon=47.481766: {'latitude': 29.300003, 'longitude': 47.5, 'generationtime_ms': 0.005364418029785156, 'utc_offset_seconds': 10800, 'timezone': 'Asia/Kuwait', 'timezone_abbreviation': 'GMT+3', 'elevation': 151.0}
# API request for coordinates: Lat=19.513469, Lon=-80.566956
# Received data for Lat=19.513469, Lon=-80.566956: {'latitude': 19.5, 'longitude': -80.6, 'generationtime_ms': 0.004887580871582031, 'utc_offset_seconds': -18000, 'timezone': 'Etc/GMT+5', 'timezone_abbreviation': 'GMT-5', 'elevation': 0.0}
# API request for coordinates: Lat=48.019573, Lon=66.923684
# Received data for Lat=48.019573, Lon=66.923684: {'latitude': 48.0, 'longitude': 66.90001, 'generationtime_ms': 0.0026226043701171875, 'utc_offset_seconds': 21600, 'timezone': 'Asia/Almaty', 'timezone_abbreviation': 'GMT+6', 'elevation': 480.0}
# API request for coordinates: Lat=19.85627, Lon=102.495496
# Received data for Lat=19.85627, Lon=102.495496: {'latitude': 19.900002, 'longitude': 102.5, 'generationtime_ms': 0.0020265579223632812, 'utc_offset_seconds': 25200, 'timezone': 'Asia/Vientiane', 'timezone_abbreviation': 'GMT+7', 'elevation': 795.0}
# API request for coordinates: Lat=33.854721, Lon=35.862285
# Received data for Lat=33.854721, Lon=35.862285: {'latitude': 33.9, 'longitude': 35.9, 'generationtime_ms': 0.002384185791015625, 'utc_offset_seconds': 7200, 'timezone': 'Asia/Beirut', 'timezone_abbreviation': 'GMT+2', 'elevation': 1190.0}
# API request for coordinates: Lat=13.909444, Lon=-60.978893
# Received data for Lat=13.909444, Lon=-60.978893: {'latitude': 13.900002, 'longitude': -61.0, 'generationtime_ms': 0.0030994415283203125, 'utc_offset_seconds': -14400, 'timezone': 'America/St_Lucia', 'timezone_abbreviation': 'GMT-4', 'elevation': 297.0}
# API request for coordinates: Lat=47.166, Lon=9.555373
# Received data for Lat=47.166, Lon=9.555373: {'latitude': 47.2, 'longitude': 9.600002, 'generationtime_ms': 0.012159347534179688, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Vaduz', 'timezone_abbreviation': 'GMT+1', 'elevation': 1756.0}
# API request for coordinates: Lat=7.873054, Lon=80.771797
# Received data for Lat=7.873054, Lon=80.771797: {'latitude': 7.9000015, 'longitude': 80.80002, 'generationtime_ms': 0.005841255187988281, 'utc_offset_seconds': 19800, 'timezone': 'Asia/Colombo', 'timezone_abbreviation': 'GMT+5:30', 'elevation': 232.0}
# API request for coordinates: Lat=6.428055, Lon=-9.429499
# Received data for Lat=6.428055, Lon=-9.429499: {'latitude': 6.4000015, 'longitude': -9.399994, 'generationtime_ms': 0.005602836608886719, 'utc_offset_seconds': 0, 'timezone': 'Africa/Monrovia', 'timezone_abbreviation': 'GMT', 'elevation': 240.0}
# API request for coordinates: Lat=-29.609988, Lon=28.233608
# Received data for Lat=-29.609988, Lon=28.233608: {'latitude': -29.599998, 'longitude': 28.199997, 'generationtime_ms': 0.005245208740234375, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Maseru', 'timezone_abbreviation': 'GMT+2', 'elevation': 2247.0}
# API request for coordinates: Lat=55.169438, Lon=23.881275
# Received data for Lat=55.169438, Lon=23.881275: {'latitude': 55.2, 'longitude': 23.900002, 'generationtime_ms': 0.004291534423828125, 'utc_offset_seconds': 7200, 'timezone': 'Europe/Vilnius', 'timezone_abbreviation': 'GMT+2', 'elevation': 36.0}
# API request for coordinates: Lat=49.815273, Lon=6.129583
# Received data for Lat=49.815273, Lon=6.129583: {'latitude': 49.800003, 'longitude': 6.1000004, 'generationtime_ms': 0.0036954879760742188, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Luxembourg', 'timezone_abbreviation': 'GMT+1', 'elevation': 311.0}
# API request for coordinates: Lat=56.879635, Lon=24.603189
# Received data for Lat=56.879635, Lon=24.603189: {'latitude': 56.9, 'longitude': 24.600002, 'generationtime_ms': 0.003337860107421875, 'utc_offset_seconds': 7200, 'timezone': 'Europe/Riga', 'timezone_abbreviation': 'GMT+2', 'elevation': 31.0}
# API request for coordinates: Lat=26.3351, Lon=17.228331
# Received data for Lat=26.3351, Lon=17.228331: {'latitude': 26.300003, 'longitude': 17.199997, 'generationtime_ms': 0.0064373016357421875, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Tripoli', 'timezone_abbreviation': 'GMT+2', 'elevation': 552.0}
# API request for coordinates: Lat=31.791702, Lon=-7.09262
# Received data for Lat=31.791702, Lon=-7.09262: {'latitude': 31.8, 'longitude': -7.1000004, 'generationtime_ms': 0.004291534423828125, 'utc_offset_seconds': 0, 'timezone': 'Africa/Casablanca', 'timezone_abbreviation': 'GMT', 'elevation': 730.0}
# API request for coordinates: Lat=43.750298, Lon=7.412841
# Received data for Lat=43.750298, Lon=7.412841: {'latitude': 43.8, 'longitude': 7.4000015, 'generationtime_ms': 0.0013113021850585938, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Paris', 'timezone_abbreviation': 'GMT+1', 'elevation': 439.0}
# API request for coordinates: Lat=47.411631, Lon=28.369885
# Received data for Lat=47.411631, Lon=28.369885: {'latitude': 47.4, 'longitude': 28.400002, 'generationtime_ms': 0.0050067901611328125, 'utc_offset_seconds': 7200, 'timezone': 'Europe/Chisinau', 'timezone_abbreviation': 'GMT+2', 'elevation': 99.0}
# API request for coordinates: Lat=42.708678, Lon=19.37439
# Received data for Lat=42.708678, Lon=19.37439: {'latitude': 42.7, 'longitude': 19.400002, 'generationtime_ms': 0.0064373016357421875, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Podgorica', 'timezone_abbreviation': 'GMT+1', 'elevation': 256.0}
# API request for coordinates: Lat=-18.766947, Lon=46.869107
# Received data for Lat=-18.766947, Lon=46.869107: {'latitude': -18.799995, 'longitude': 46.90001, 'generationtime_ms': 0.004291534423828125, 'utc_offset_seconds': 10800, 'timezone': 'Indian/Antananarivo', 'timezone_abbreviation': 'GMT+3', 'elevation': 1345.0}
# API request for coordinates: Lat=7.131474, Lon=171.184478
# Received data for Lat=7.131474, Lon=171.184478: {'latitude': 7.0999985, 'longitude': 171.20001, 'generationtime_ms': 0.00476837158203125, 'utc_offset_seconds': 43200, 'timezone': 'Pacific/Majuro', 'timezone_abbreviation': 'GMT+12', 'elevation': 0.0}
# API request for coordinates: Lat=41.608635, Lon=21.745275
# Received data for Lat=41.608635, Lon=21.745275: {'latitude': 41.6, 'longitude': 21.7, 'generationtime_ms': 0.0045299530029296875, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Skopje', 'timezone_abbreviation': 'GMT+1', 'elevation': 290.0}
# API request for coordinates: Lat=17.570692, Lon=-3.996166
# Received data for Lat=17.570692, Lon=-3.996166: {'latitude': 17.599998, 'longitude': -4.0, 'generationtime_ms': 0.004291534423828125, 'utc_offset_seconds': 0, 'timezone': 'Africa/Bamako', 'timezone_abbreviation': 'GMT', 'elevation': 280.0}
# API request for coordinates: Lat=21.913965, Lon=95.956223
# Received data for Lat=21.913965, Lon=95.956223: {'latitude': 21.900002, 'longitude': 96.0, 'generationtime_ms': 0.004649162292480469, 'utc_offset_seconds': 23400, 'timezone': 'Asia/Yangon', 'timezone_abbreviation': 'GMT+6:30', 'elevation': 69.0}
# API request for coordinates: Lat=46.862496, Lon=103.846656
# Received data for Lat=46.862496, Lon=103.846656: {'latitude': 46.90001, 'longitude': 103.80002, 'generationtime_ms': 0.0019073486328125, 'utc_offset_seconds': 28800, 'timezone': 'Asia/Ulaanbaatar', 'timezone_abbreviation': 'GMT+8', 'elevation': 1679.0}
# API request for coordinates: Lat=22.198745, Lon=113.543873
# Received data for Lat=22.198745, Lon=113.543873: {'latitude': 22.200005, 'longitude': 113.5, 'generationtime_ms': 0.0025033950805664062, 'utc_offset_seconds': 28800, 'timezone': 'Asia/Macau', 'timezone_abbreviation': 'GMT+8', 'elevation': 31.0}
# API request for coordinates: Lat=17.33083, Lon=145.38469
# Received data for Lat=17.33083, Lon=145.38469: {'latitude': 17.300003, 'longitude': 145.4, 'generationtime_ms': 0.00476837158203125, 'utc_offset_seconds': 36000, 'timezone': 'Etc/GMT-10', 'timezone_abbreviation': 'GMT+10', 'elevation': 0.0}
# API request for coordinates: Lat=14.641528, Lon=-61.024174
# Received data for Lat=14.641528, Lon=-61.024174: {'latitude': 14.599998, 'longitude': -61.0, 'generationtime_ms': 0.0021457672119140625, 'utc_offset_seconds': -14400, 'timezone': 'America/Martinique', 'timezone_abbreviation': 'GMT-4', 'elevation': 100.0}
# API request for coordinates: Lat=21.00789, Lon=-10.940835
# Received data for Lat=21.00789, Lon=-10.940835: {'latitude': 21.0, 'longitude': -10.899994, 'generationtime_ms': 0.00858306884765625, 'utc_offset_seconds': 0, 'timezone': 'Africa/Nouakchott', 'timezone_abbreviation': 'GMT', 'elevation': 416.0}
# API request for coordinates: Lat=16.742498, Lon=-62.187366
# Received data for Lat=16.742498, Lon=-62.187366: {'latitude': 16.700005, 'longitude': -62.199997, 'generationtime_ms': 0.004172325134277344, 'utc_offset_seconds': -14400, 'timezone': 'America/Montserrat', 'timezone_abbreviation': 'GMT-4', 'elevation': 309.0}
# API request for coordinates: Lat=35.937496, Lon=14.375416
# Received data for Lat=35.937496, Lon=14.375416: {'latitude': 35.9, 'longitude': 14.400002, 'generationtime_ms': 0.004410743713378906, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Malta', 'timezone_abbreviation': 'GMT+1', 'elevation': 39.0}
# API request for coordinates: Lat=-20.348404, Lon=57.552152
# Received data for Lat=-20.348404, Lon=57.552152: {'latitude': -20.299995, 'longitude': 57.600006, 'generationtime_ms': 0.0017881393432617188, 'utc_offset_seconds': 14400, 'timezone': 'Indian/Mauritius', 'timezone_abbreviation': 'GMT+4', 'elevation': 566.0}
# API request for coordinates: Lat=3.202778, Lon=73.22068
# Received data for Lat=3.202778, Lon=73.22068: {'latitude': 3.2000046, 'longitude': 73.2, 'generationtime_ms': 0.0045299530029296875, 'utc_offset_seconds': 18000, 'timezone': 'Indian/Maldives', 'timezone_abbreviation': 'GMT+5', 'elevation': 0.0}
# API request for coordinates: Lat=-13.254308, Lon=34.301525
# Received data for Lat=-13.254308, Lon=34.301525: {'latitude': -13.299995, 'longitude': 34.300003, 'generationtime_ms': 0.0019073486328125, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Blantyre', 'timezone_abbreviation': 'GMT+2', 'elevation': 482.0}
# API request for coordinates: Lat=23.634501, Lon=-102.552784
# Received data for Lat=23.634501, Lon=-102.552784: {'latitude': 23.599998, 'longitude': -102.6, 'generationtime_ms': 0.0020265579223632812, 'utc_offset_seconds': -21600, 'timezone': 'America/Mexico_City', 'timezone_abbreviation': 'GMT-6', 'elevation': 1976.0}
# API request for coordinates: Lat=4.210484, Lon=101.975766
# Received data for Lat=4.210484, Lon=101.975766: {'latitude': 4.2000046, 'longitude': 102.0, 'generationtime_ms': 0.004649162292480469, 'utc_offset_seconds': 28800, 'timezone': 'Asia/Kuala_Lumpur', 'timezone_abbreviation': 'GMT+8', 'elevation': 159.0}
# API request for coordinates: Lat=-18.665695, Lon=35.529562
# Received data for Lat=-18.665695, Lon=35.529562: {'latitude': -18.699997, 'longitude': 35.5, 'generationtime_ms': 0.0034570693969726562, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Maputo', 'timezone_abbreviation': 'GMT+2', 'elevation': 50.0}
# API request for coordinates: Lat=-22.95764, Lon=18.49041
# ...
# API request for coordinates: Lat=12.862807, Lon=30.217636
# Received data for Lat=12.862807, Lon=30.217636: {'latitude': 12.900002, 'longitude': 30.199997, 'generationtime_ms': 0.0035762786865234375, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Khartoum', 'timezone_abbreviation': 'GMT+2', 'elevation': 533.0}
# API request for coordinates: Lat=60.128161, Lon=18.643501
# Received data for Lat=60.128161, Lon=18.643501: {'latitude': 60.1, 'longitude': 18.600002, 'generationtime_ms': 0.0059604644775390625, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Stockholm', 'timezone_abbreviation': 'GMT+1', 'elevation': 9.0}
# API request for coordinates: Lat=1.352083, Lon=103.819836
# Received data for Lat=1.352083, Lon=103.819836: {'latitude': 1.4000015, 'longitude': 103.80002, 'generationtime_ms': 0.002384185791015625, 'utc_offset_seconds': 28800, 'timezone': 'Asia/Singapore', 'timezone_abbreviation': 'GMT+8', 'elevation': 46.0}
# API request for coordinates: Lat=-24.143474, Lon=-10.030696
# Received data for Lat=-24.143474, Lon=-10.030696: {'latitude': -24.099998, 'longitude': -10.0, 'generationtime_ms': 0.0036954879760742188, 'utc_offset_seconds': -3600, 'timezone': 'Etc/GMT+1', 'timezone_abbreviation': 'GMT-1', 'elevation': 0.0}
# API request for coordinates: Lat=46.151241, Lon=14.995463
# Received data for Lat=46.151241, Lon=14.995463: {'latitude': 46.2, 'longitude': 15.0, 'generationtime_ms': 0.0030994415283203125, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Ljubljana', 'timezone_abbreviation': 'GMT+1', 'elevation': 358.0}
# API request for coordinates: Lat=77.553604, Lon=23.670272
# Received data for Lat=77.553604, Lon=23.670272: {'latitude': 77.600006, 'longitude': 23.699997, 'generationtime_ms': 0.003337860107421875, 'utc_offset_seconds': 3600, 'timezone': 'Arctic/Longyearbyen', 'timezone_abbreviation': 'GMT+1', 'elevation': 244.0}
# API request for coordinates: Lat=48.669026, Lon=19.699024
# Received data for Lat=48.669026, Lon=19.699024: {'latitude': 48.7, 'longitude': 19.7, 'generationtime_ms': 0.0029802322387695312, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Bratislava', 'timezone_abbreviation': 'GMT+1', 'elevation': 990.0}
# API request for coordinates: Lat=8.460555, Lon=-11.779889
# Received data for Lat=8.460555, Lon=-11.779889: {'latitude': 8.5, 'longitude': -11.800003, 'generationtime_ms': 0.0015497207641601562, 'utc_offset_seconds': 0, 'timezone': 'Africa/Freetown', 'timezone_abbreviation': 'GMT', 'elevation': 170.0}
# API request for coordinates: Lat=43.94236, Lon=12.457777
# Received data for Lat=43.94236, Lon=12.457777: {'latitude': 43.9, 'longitude': 12.5, 'generationtime_ms': 0.0073909759521484375, 'utc_offset_seconds': 3600, 'timezone': 'Europe/San_Marino', 'timezone_abbreviation': 'GMT+1', 'elevation': 390.0}
# API request for coordinates: Lat=14.497401, Lon=-14.452362
# Received data for Lat=14.497401, Lon=-14.452362: {'latitude': 14.5, 'longitude': -14.5, 'generationtime_ms': 0.0057220458984375, 'utc_offset_seconds': 0, 'timezone': 'Africa/Dakar', 'timezone_abbreviation': 'GMT', 'elevation': 48.0}
# API request for coordinates: Lat=5.152149, Lon=46.199616
# Received data for Lat=5.152149, Lon=46.199616: {'latitude': 5.2000046, 'longitude': 46.199997, 'generationtime_ms': 0.004410743713378906, 'utc_offset_seconds': 10800, 'timezone': 'Africa/Mogadishu', 'timezone_abbreviation': 'GMT+3', 'elevation': 241.0}
# API request for coordinates: Lat=3.919305, Lon=-56.027783
# Received data for Lat=3.919305, Lon=-56.027783: {'latitude': 3.9000015, 'longitude': -56.0, 'generationtime_ms': 0.0029802322387695312, 'utc_offset_seconds': -10800, 'timezone': 'America/Paramaribo', 'timezone_abbreviation': 'GMT-3', 'elevation': 157.0}
# API request for coordinates: Lat=0.18636, Lon=6.613081
# Received data for Lat=0.18636, Lon=6.613081: {'latitude': 0.20000458, 'longitude': 6.600006, 'generationtime_ms': 0.0057220458984375, 'utc_offset_seconds': 0, 'timezone': 'Africa/Sao_Tome', 'timezone_abbreviation': 'GMT', 'elevation': 152.0}
# API request for coordinates: Lat=13.794185, Lon=-88.89653
# Received data for Lat=13.794185, Lon=-88.89653: {'latitude': 13.800003, 'longitude': -88.9, 'generationtime_ms': 0.00858306884765625, 'utc_offset_seconds': -21600, 'timezone': 'America/El_Salvador', 'timezone_abbreviation': 'GMT-6', 'elevation': 622.0}
# API request for coordinates: Lat=34.802075, Lon=38.996815
# Received data for Lat=34.802075, Lon=38.996815: {'latitude': 34.8, 'longitude': 39.0, 'generationtime_ms': 0.001430511474609375, 'utc_offset_seconds': 10800, 'timezone': 'Asia/Damascus', 'timezone_abbreviation': 'GMT+3', 'elevation': 445.0}
# API request for coordinates: Lat=-26.522503, Lon=31.465866
# Received data for Lat=-26.522503, Lon=31.465866: {'latitude': -26.5, 'longitude': 31.5, 'generationtime_ms': 0.0021457672119140625, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Mbabane', 'timezone_abbreviation': 'GMT+2', 'elevation': 491.0}
# API request for coordinates: Lat=21.694025, Lon=-71.797928
# Received data for Lat=21.694025, Lon=-71.797928: {'latitude': 21.700005, 'longitude': -71.799995, 'generationtime_ms': 0.0057220458984375, 'utc_offset_seconds': -18000, 'timezone': 'America/Grand_Turk', 'timezone_abbreviation': 'GMT-5', 'elevation': 0.0}
# API request for coordinates: Lat=15.454166, Lon=18.732207
# Received data for Lat=15.454166, Lon=18.732207: {'latitude': 15.5, 'longitude': 18.699997, 'generationtime_ms': 0.0027418136596679688, 'utc_offset_seconds': 3600, 'timezone': 'Africa/Ndjamena', 'timezone_abbreviation': 'GMT+1', 'elevation': 332.0}
# API request for coordinates: Lat=-49.280366, Lon=69.348557
# Received data for Lat=-49.280366, Lon=69.348557: {'latitude': -49.3, 'longitude': 69.3, 'generationtime_ms': 0.008225440979003906, 'utc_offset_seconds': 18000, 'timezone': 'Indian/Kerguelen', 'timezone_abbreviation': 'GMT+5', 'elevation': 265.0}
# API request for coordinates: Lat=8.619543, Lon=0.824782
# Received data for Lat=8.619543, Lon=0.824782: {'latitude': 8.599998, 'longitude': 0.80000305, 'generationtime_ms': 0.0026226043701171875, 'utc_offset_seconds': 0, 'timezone': 'Africa/Lome', 'timezone_abbreviation': 'GMT', 'elevation': 480.0}
# API request for coordinates: Lat=15.870032, Lon=100.992541
# Received data for Lat=15.870032, Lon=100.992541: {'latitude': 15.900002, 'longitude': 101.0, 'generationtime_ms': 0.0045299530029296875, 'utc_offset_seconds': 25200, 'timezone': 'Asia/Bangkok', 'timezone_abbreviation': 'GMT+7', 'elevation': 92.0}
# API request for coordinates: Lat=38.861034, Lon=71.276093
# Received data for Lat=38.861034, Lon=71.276093: {'latitude': 38.90001, 'longitude': 71.3, 'generationtime_ms': 0.005841255187988281, 'utc_offset_seconds': 18000, 'timezone': 'Asia/Dushanbe', 'timezone_abbreviation': 'GMT+5', 'elevation': 3840.0}
# API request for coordinates: Lat=-8.967363, Lon=-171.855881
# Received data for Lat=-8.967363, Lon=-171.855881: {'latitude': -9.0, 'longitude': -171.9, 'generationtime_ms': 0.0019073486328125, 'utc_offset_seconds': 46800, 'timezone': 'Pacific/Fakaofo', 'timezone_abbreviation': 'GMT+13', 'elevation': 0.0}
# API request for coordinates: Lat=-8.874217, Lon=125.727539
# Received data for Lat=-8.874217, Lon=125.727539: {'latitude': -8.900002, 'longitude': 125.70001, 'generationtime_ms': 0.0022649765014648438, 'utc_offset_seconds': 32400, 'timezone': 'Asia/Dili', 'timezone_abbreviation': 'GMT+9', 'elevation': 712.0}
# API request for coordinates: Lat=38.969719, Lon=59.556278
# Received data for Lat=38.969719, Lon=59.556278: {'latitude': 39.0, 'longitude': 59.600006, 'generationtime_ms': 0.005245208740234375, 'utc_offset_seconds': 18000, 'timezone': 'Asia/Ashgabat', 'timezone_abbreviation': 'GMT+5', 'elevation': 112.0}
# API request for coordinates: Lat=33.886917, Lon=9.537499
# Received data for Lat=33.886917, Lon=9.537499: {'latitude': 33.9, 'longitude': 9.5, 'generationtime_ms': 0.005364418029785156, 'utc_offset_seconds': 3600, 'timezone': 'Africa/Tunis', 'timezone_abbreviation': 'GMT+1', 'elevation': 45.0}
# API request for coordinates: Lat=-21.178986, Lon=-175.198242
# Received data for Lat=-21.178986, Lon=-175.198242: {'latitude': -21.199997, 'longitude': -175.2, 'generationtime_ms': 0.004410743713378906, 'utc_offset_seconds': 46800, 'timezone': 'Pacific/Tongatapu', 'timezone_abbreviation': 'GMT+13', 'elevation': 0.0}
# API request for coordinates: Lat=38.963745, Lon=35.243322
# Received data for Lat=38.963745, Lon=35.243322: {'latitude': 39.0, 'longitude': 35.2, 'generationtime_ms': 0.0032186508178710938, 'utc_offset_seconds': 10800, 'timezone': 'Europe/Istanbul', 'timezone_abbreviation': 'GMT+3', 'elevation': 1221.0}
# API request for coordinates: Lat=10.691803, Lon=-61.222503
# Received data for Lat=10.691803, Lon=-61.222503: {'latitude': 10.700005, 'longitude': -61.199997, 'generationtime_ms': 0.003814697265625, 'utc_offset_seconds': -14400, 'timezone': 'Etc/GMT+4', 'timezone_abbreviation': 'GMT-4', 'elevation': 223.0}
# API request for coordinates: Lat=-7.109535, Lon=177.64933
# Received data for Lat=-7.109535, Lon=177.64933: {'latitude': -7.0999985, 'longitude': 177.6, 'generationtime_ms': 0.0026226043701171875, 'utc_offset_seconds': 43200, 'timezone': 'Etc/GMT-12', 'timezone_abbreviation': 'GMT+12', 'elevation': 0.0}
# API request for coordinates: Lat=23.69781, Lon=120.960515
# Received data for Lat=23.69781, Lon=120.960515: {'latitude': 23.700005, 'longitude': 121.0, 'generationtime_ms': 0.0030994415283203125, 'utc_offset_seconds': 28800, 'timezone': 'Asia/Taipei', 'timezone_abbreviation': 'GMT+8', 'elevation': 2768.0}
# API request for coordinates: Lat=-6.369028, Lon=34.888822
# Received data for Lat=-6.369028, Lon=34.888822: {'latitude': -6.4000015, 'longitude': 34.90001, 'generationtime_ms': 0.0020265579223632812, 'utc_offset_seconds': 10800, 'timezone': 'Africa/Dar_es_Salaam', 'timezone_abbreviation': 'GMT+3', 'elevation': 1166.0}
# API request for coordinates: Lat=48.379433, Lon=31.16558
# Received data for Lat=48.379433, Lon=31.16558: {'latitude': 48.4, 'longitude': 31.2, 'generationtime_ms': 0.0008344650268554688, 'utc_offset_seconds': 7200, 'timezone': 'Europe/Kiev', 'timezone_abbreviation': 'GMT+2', 'elevation': 200.0}
# API request for coordinates: Lat=1.373333, Lon=32.290275
# Received data for Lat=1.373333, Lon=32.290275: {'latitude': 1.4000015, 'longitude': 32.300003, 'generationtime_ms': 0.003814697265625, 'utc_offset_seconds': 10800, 'timezone': 'Africa/Kampala', 'timezone_abbreviation': 'GMT+3', 'elevation': 1071.0}
# API request for coordinates: Lat=37.09024, Lon=-95.712891
# Received data for Lat=37.09024, Lon=-95.712891: {'latitude': 37.1, 'longitude': -95.7, 'generationtime_ms': 0.009298324584960938, 'utc_offset_seconds': -21600, 'timezone': 'America/Chicago', 'timezone_abbreviation': 'GMT-6', 'elevation': 256.0}
# API request for coordinates: Lat=-32.522779, Lon=-55.765835
# Received data for Lat=-32.522779, Lon=-55.765835: {'latitude': -32.5, 'longitude': -55.799995, 'generationtime_ms': 0.0025033950805664062, 'utc_offset_seconds': -10800, 'timezone': 'America/Montevideo', 'timezone_abbreviation': 'GMT-3', 'elevation': 91.0}
# API request for coordinates: Lat=41.377491, Lon=64.585262
# Received data for Lat=41.377491, Lon=64.585262: {'latitude': 41.40001, 'longitude': 64.600006, 'generationtime_ms': 0.0030994415283203125, 'utc_offset_seconds': 18000, 'timezone': 'Asia/Samarkand', 'timezone_abbreviation': 'GMT+5', 'elevation': 361.0}
# API request for coordinates: Lat=41.902916, Lon=12.453389
# Received data for Lat=41.902916, Lon=12.453389: {'latitude': 41.9, 'longitude': 12.5, 'generationtime_ms': 0.0027418136596679688, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Vatican', 'timezone_abbreviation': 'GMT+1', 'elevation': 50.0}
# API request for coordinates: Lat=12.984305, Lon=-61.287228
# Received data for Lat=12.984305, Lon=-61.287228: {'latitude': 13.0, 'longitude': -61.299995, 'generationtime_ms': 0.0020265579223632812, 'utc_offset_seconds': -14400, 'timezone': 'America/St_Vincent', 'timezone_abbreviation': 'GMT-4', 'elevation': 0.0}
# API request for coordinates: Lat=6.42375, Lon=-66.58973
# Received data for Lat=6.42375, Lon=-66.58973: {'latitude': 6.4000015, 'longitude': -66.6, 'generationtime_ms': 0.0019073486328125, 'utc_offset_seconds': -18000, 'timezone': 'America/Bogota', 'timezone_abbreviation': 'GMT-5', 'elevation': 96.0}
# API request for coordinates: Lat=18.420695, Lon=-64.639968
# Received data for Lat=18.420695, Lon=-64.639968: {'latitude': 18.400002, 'longitude': -64.6, 'generationtime_ms': 0.0019073486328125, 'utc_offset_seconds': -14400, 'timezone': 'America/Tortola', 'timezone_abbreviation': 'GMT-4', 'elevation': 304.0}
# API request for coordinates: Lat=18.335765, Lon=-64.896335
# Received data for Lat=18.335765, Lon=-64.896335: {'latitude': 18.300003, 'longitude': -64.9, 'generationtime_ms': 0.005841255187988281, 'utc_offset_seconds': -14400, 'timezone': 'America/St_Thomas', 'timezone_abbreviation': 'GMT-4', 'elevation': 68.0}
# API request for coordinates: Lat=14.058324, Lon=108.277199
# Received data for Lat=14.058324, Lon=108.277199: {'latitude': 14.099998, 'longitude': 108.30002, 'generationtime_ms': 0.0022649765014648438, 'utc_offset_seconds': 25200, 'timezone': 'Asia/Ho_Chi_Minh', 'timezone_abbreviation': 'GMT+7', 'elevation': 725.0}
# API request for coordinates: Lat=-15.376706, Lon=166.959158
# Received data for Lat=-15.376706, Lon=166.959158: {'latitude': -15.400002, 'longitude': 167.0, 'generationtime_ms': 0.006079673767089844, 'utc_offset_seconds': 39600, 'timezone': 'Pacific/Efate', 'timezone_abbreviation': 'GMT+11', 'elevation': 647.0}
# API request for coordinates: Lat=-13.768752, Lon=-177.156097
# Received data for Lat=-13.768752, Lon=-177.156097: {'latitude': -13.799995, 'longitude': -177.2, 'generationtime_ms': 0.002384185791015625, 'utc_offset_seconds': -43200, 'timezone': 'Etc/GMT+12', 'timezone_abbreviation': 'GMT-12', 'elevation': 0.0}
# API request for coordinates: Lat=-13.759029, Lon=-172.104629
# Received data for Lat=-13.759029, Lon=-172.104629: {'latitude': -13.799995, 'longitude': -172.1, 'generationtime_ms': 0.005245208740234375, 'utc_offset_seconds': 46800, 'timezone': 'Pacific/Apia', 'timezone_abbreviation': 'GMT+13', 'elevation': 0.0}
# API request for coordinates: Lat=42.602636, Lon=20.902977
# Received data for Lat=42.602636, Lon=20.902977: {'latitude': 42.6, 'longitude': 20.900002, 'generationtime_ms': 0.0017881393432617188, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Belgrade', 'timezone_abbreviation': 'GMT+1', 'elevation': 587.0}
# API request for coordinates: Lat=15.552727, Lon=48.516388
# Received data for Lat=15.552727, Lon=48.516388: {'latitude': 15.599998, 'longitude': 48.5, 'generationtime_ms': 0.0019073486328125, 'utc_offset_seconds': 10800, 'timezone': 'Asia/Aden', 'timezone_abbreviation': 'GMT+3', 'elevation': 980.0}
# API request for coordinates: Lat=-12.8275, Lon=45.166244
# Received data for Lat=-12.8275, Lon=45.166244: {'latitude': -12.799995, 'longitude': 45.199997, 'generationtime_ms': 0.0035762786865234375, 'utc_offset_seconds': 10800, 'timezone': 'Indian/Mayotte', 'timezone_abbreviation': 'GMT+3', 'elevation': 200.0}
# API request for coordinates: Lat=-30.559482, Lon=22.937506
# Received data for Lat=-30.559482, Lon=22.937506: {'latitude': -30.599998, 'longitude': 22.90001, 'generationtime_ms': 0.004649162292480469, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Johannesburg', 'timezone_abbreviation': 'GMT+2', 'elevation': 1106.0}
# API request for coordinates: Lat=-13.133897, Lon=27.849332
# Received data for Lat=-13.133897, Lon=27.849332: {'latitude': -13.099998, 'longitude': 27.800003, 'generationtime_ms': 0.00286102294921875, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Lusaka', 'timezone_abbreviation': 'GMT+2', 'elevation': 1202.0}
# API request for coordinates: Lat=-19.015438, Lon=29.154857
# Received data for Lat=-19.015438, Lon=29.154857: {'latitude': -19.0, 'longitude': 29.199997, 'generationtime_ms': 0.002384185791015625, 'utc_offset_seconds': 7200, 'timezone': 'Africa/Harare', 'timezone_abbreviation': 'GMT+2', 'elevation': 1240.0}
# Data collection complete. Results saved to air_quality_2023.csv

# %%
# Retrieve average air quality from https://air-quality-api.open-meteo.com per country for 2023

def get_air_quality(lat, lon):
    """Fetches air quality data for given latitude and longitude dynamically handling different resolutions."""
    print(f"Fetching air quality data for: Lat={lat}, Lon={lon}")

    url = "https://air-quality-api.open-meteo.com/v1/air-quality"
    
    params_daily = {
        "latitude": lat,
        "longitude": lon,
        "start_date": "2023-01-01",
        "end_date": "2023-12-31",
        "daily": ["pm10", "pm2_5", "no2", "so2", "o3"],
        "timezone": "UTC"
    }
    
    response = requests.get(url, params=params_daily)
    data = response.json()

    # Check if "daily" data exists
    if "daily" in data and any(data["daily"].get(p) for p in ["pm10", "pm2_5", "no2", "so2", "o3"]):
        print("✅ Using daily data")
        daily_data = data["daily"]
        pollutants = ["pm10", "pm2_5", "no2", "so2", "o3"]
        averages = [sum(daily_data.get(p, [])) / len(daily_data.get(p, [])) if daily_data.get(p) else None for p in pollutants]
        return tuple(averages)

    # If no daily data, try hourly
    print("⚠️ No daily data. Trying hourly data instead...")
    params_hourly = {
        "latitude": lat,
        "longitude": lon,
        "start_date": "2023-01-01",
        "end_date": "2023-12-31",
        "hourly": ["pm10", "pm2_5", "no2", "so2", "o3"],
        "timezone": "UTC"
    }
    
    response = requests.get(url, params=params_hourly)
    data = response.json()

    if "hourly" in data and any(data["hourly"].get(p) for p in ["pm10", "pm2_5", "no2", "so2", "o3"]):
        print("✅ Using hourly data")
        hourly_data = data["hourly"]
        pollutants = ["pm10", "pm2_5", "no2", "so2", "o3"]
        
        # Compute daily averages from hourly data
        averages = []
        for pollutant in pollutants:
            values = hourly_data.get(pollutant, [])
            avg_value = sum(values) / len(values) if values else None
            averages.append(avg_value)
        
        return tuple(averages)

    print(f"❌ No air quality data found for Lat={lat}, Lon={lon}")
    return None, None, None, None, None

# Example: Processing all countries in the dataframe
df_countries[['avg_pm10', 'avg_pm2_5', 'avg_no2', 'avg_so2', 'avg_o3']] = df_countries.apply(
    lambda row: get_air_quality(row['latitude'], row['longitude']), axis=1, result_type='expand'
)

# Save results to CSV
df_countries.to_csv("air_quality_2023.csv", index=False)
print("Data collection complete. Results saved to air_quality_2023.csv")
# Out:
# Fetching air quality data for: Lat=42.546245, Lon=1.601554
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=42.546245, Lon=1.601554
# Fetching air quality data for: Lat=23.424076, Lon=53.847818
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=23.424076, Lon=53.847818
# Fetching air quality data for: Lat=33.93911, Lon=67.709953
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=33.93911, Lon=67.709953
# Fetching air quality data for: Lat=17.060816, Lon=-61.796428
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=17.060816, Lon=-61.796428
# Fetching air quality data for: Lat=18.220554, Lon=-63.068615
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=18.220554, Lon=-63.068615
# Fetching air quality data for: Lat=41.153332, Lon=20.168331
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=41.153332, Lon=20.168331
# Fetching air quality data for: Lat=40.069099, Lon=45.038189
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=40.069099, Lon=45.038189
# Fetching air quality data for: Lat=12.226079, Lon=-69.060087
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=12.226079, Lon=-69.060087
# Fetching air quality data for: Lat=-11.202692, Lon=17.873887
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-11.202692, Lon=17.873887
# Fetching air quality data for: Lat=-75.250973, Lon=-0.071389
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-75.250973, Lon=-0.071389
# Fetching air quality data for: Lat=-38.416097, Lon=-63.616672
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-38.416097, Lon=-63.616672
# Fetching air quality data for: Lat=-14.270972, Lon=-170.132217
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-14.270972, Lon=-170.132217
# Fetching air quality data for: Lat=47.516231, Lon=14.550072
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=47.516231, Lon=14.550072
# Fetching air quality data for: Lat=-25.274398, Lon=133.775136
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-25.274398, Lon=133.775136
# Fetching air quality data for: Lat=12.52111, Lon=-69.968338
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=12.52111, Lon=-69.968338
# Fetching air quality data for: Lat=40.143105, Lon=47.576927
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=40.143105, Lon=47.576927
# Fetching air quality data for: Lat=43.915886, Lon=17.679076
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=43.915886, Lon=17.679076
# Fetching air quality data for: Lat=13.193887, Lon=-59.543198
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=13.193887, Lon=-59.543198
# Fetching air quality data for: Lat=23.684994, Lon=90.356331
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=23.684994, Lon=90.356331
# Fetching air quality data for: Lat=50.503887, Lon=4.469936
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=50.503887, Lon=4.469936
# Fetching air quality data for: Lat=12.238333, Lon=-1.561593
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=12.238333, Lon=-1.561593
# Fetching air quality data for: Lat=42.733883, Lon=25.48583
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=42.733883, Lon=25.48583
# Fetching air quality data for: Lat=25.930414, Lon=50.637772
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=25.930414, Lon=50.637772
# Fetching air quality data for: Lat=-3.373056, Lon=29.918886
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-3.373056, Lon=29.918886
# Fetching air quality data for: Lat=9.30769, Lon=2.315834
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=9.30769, Lon=2.315834
# Fetching air quality data for: Lat=32.321384, Lon=-64.75737
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=32.321384, Lon=-64.75737
# Fetching air quality data for: Lat=4.535277, Lon=114.727669
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=4.535277, Lon=114.727669
# Fetching air quality data for: Lat=-16.290154, Lon=-63.588653
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-16.290154, Lon=-63.588653
# Fetching air quality data for: Lat=-14.235004, Lon=-51.92528
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-14.235004, Lon=-51.92528
# Fetching air quality data for: Lat=25.03428, Lon=-77.39628
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=25.03428, Lon=-77.39628
# Fetching air quality data for: Lat=27.514162, Lon=90.433601
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=27.514162, Lon=90.433601
# Fetching air quality data for: Lat=-54.423199, Lon=3.413194
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-54.423199, Lon=3.413194
# Fetching air quality data for: Lat=-22.328474, Lon=24.684866
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-22.328474, Lon=24.684866
# Fetching air quality data for: Lat=53.709807, Lon=27.953389
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=53.709807, Lon=27.953389
# Fetching air quality data for: Lat=17.189877, Lon=-88.49765
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=17.189877, Lon=-88.49765
# Fetching air quality data for: Lat=56.130366, Lon=-106.346771
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=56.130366, Lon=-106.346771
# Fetching air quality data for: Lat=-12.164165, Lon=96.870956
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-12.164165, Lon=96.870956
# Fetching air quality data for: Lat=-4.038333, Lon=21.758664
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-4.038333, Lon=21.758664
# Fetching air quality data for: Lat=6.611111, Lon=20.939444
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=6.611111, Lon=20.939444
# Fetching air quality data for: Lat=-0.228021, Lon=15.827659
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-0.228021, Lon=15.827659
# Fetching air quality data for: Lat=46.818188, Lon=8.227512
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=46.818188, Lon=8.227512
# Fetching air quality data for: Lat=7.539989, Lon=-5.54708
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=7.539989, Lon=-5.54708
# Fetching air quality data for: Lat=-21.236736, Lon=-159.777671
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-21.236736, Lon=-159.777671
# Fetching air quality data for: Lat=-35.675147, Lon=-71.542969
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-35.675147, Lon=-71.542969
# Fetching air quality data for: Lat=7.369722, Lon=12.354722
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=7.369722, Lon=12.354722
# Fetching air quality data for: Lat=35.86166, Lon=104.195397
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=35.86166, Lon=104.195397
# Fetching air quality data for: Lat=4.570868, Lon=-74.297333
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=4.570868, Lon=-74.297333
# Fetching air quality data for: Lat=9.748917, Lon=-83.753428
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=9.748917, Lon=-83.753428
# Fetching air quality data for: Lat=21.521757, Lon=-77.781167
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=21.521757, Lon=-77.781167
# Fetching air quality data for: Lat=16.002082, Lon=-24.013197
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=16.002082, Lon=-24.013197
# Fetching air quality data for: Lat=-10.447525, Lon=105.690449
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-10.447525, Lon=105.690449
# Fetching air quality data for: Lat=35.126413, Lon=33.429859
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=35.126413, Lon=33.429859
# Fetching air quality data for: Lat=49.817492, Lon=15.472962
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=49.817492, Lon=15.472962
# Fetching air quality data for: Lat=51.165691, Lon=10.451526
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=51.165691, Lon=10.451526
# Fetching air quality data for: Lat=11.825138, Lon=42.590275
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=11.825138, Lon=42.590275
# Fetching air quality data for: Lat=56.26392, Lon=9.501785
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=56.26392, Lon=9.501785
# Fetching air quality data for: Lat=15.414999, Lon=-61.370976
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=15.414999, Lon=-61.370976
# Fetching air quality data for: Lat=18.735693, Lon=-70.162651
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=18.735693, Lon=-70.162651
# Fetching air quality data for: Lat=28.033886, Lon=1.659626
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=28.033886, Lon=1.659626
# Fetching air quality data for: Lat=-1.831239, Lon=-78.183406
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-1.831239, Lon=-78.183406
# Fetching air quality data for: Lat=58.595272, Lon=25.013607
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=58.595272, Lon=25.013607
# Fetching air quality data for: Lat=26.820553, Lon=30.802498
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=26.820553, Lon=30.802498
# Fetching air quality data for: Lat=24.215527, Lon=-12.885834
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=24.215527, Lon=-12.885834
# Fetching air quality data for: Lat=15.179384, Lon=39.782334
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=15.179384, Lon=39.782334
# Fetching air quality data for: Lat=40.463667, Lon=-3.74922
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=40.463667, Lon=-3.74922
# Fetching air quality data for: Lat=9.145, Lon=40.489673
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=9.145, Lon=40.489673
# Fetching air quality data for: Lat=61.92411, Lon=25.748151
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=61.92411, Lon=25.748151
# Fetching air quality data for: Lat=-16.578193, Lon=179.414413
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-16.578193, Lon=179.414413
# Fetching air quality data for: Lat=-51.796253, Lon=-59.523613
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-51.796253, Lon=-59.523613
# Fetching air quality data for: Lat=7.425554, Lon=150.550812
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=7.425554, Lon=150.550812
# Fetching air quality data for: Lat=61.892635, Lon=-6.911806
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=61.892635, Lon=-6.911806
# Fetching air quality data for: Lat=46.227638, Lon=2.213749
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=46.227638, Lon=2.213749
# Fetching air quality data for: Lat=-0.803689, Lon=11.609444
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-0.803689, Lon=11.609444
# Fetching air quality data for: Lat=55.378051, Lon=-3.435973
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=55.378051, Lon=-3.435973
# Fetching air quality data for: Lat=12.262776, Lon=-61.604171
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=12.262776, Lon=-61.604171
# Fetching air quality data for: Lat=42.315407, Lon=43.356892
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=42.315407, Lon=43.356892
# Fetching air quality data for: Lat=3.933889, Lon=-53.125782
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=3.933889, Lon=-53.125782
# Fetching air quality data for: Lat=49.465691, Lon=-2.585278
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=49.465691, Lon=-2.585278
# Fetching air quality data for: Lat=7.946527, Lon=-1.023194
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=7.946527, Lon=-1.023194
# Fetching air quality data for: Lat=36.137741, Lon=-5.345374
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=36.137741, Lon=-5.345374
# Fetching air quality data for: Lat=71.706936, Lon=-42.604303
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=71.706936, Lon=-42.604303
# Fetching air quality data for: Lat=13.443182, Lon=-15.310139
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=13.443182, Lon=-15.310139
# Fetching air quality data for: Lat=9.945587, Lon=-9.696645
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=9.945587, Lon=-9.696645
# Fetching air quality data for: Lat=16.995971, Lon=-62.067641
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=16.995971, Lon=-62.067641
# Fetching air quality data for: Lat=1.650801, Lon=10.267895
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=1.650801, Lon=10.267895
# Fetching air quality data for: Lat=39.074208, Lon=21.824312
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=39.074208, Lon=21.824312
# Fetching air quality data for: Lat=-54.429579, Lon=-36.587909
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-54.429579, Lon=-36.587909
# Fetching air quality data for: Lat=15.783471, Lon=-90.230759
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=15.783471, Lon=-90.230759
# Fetching air quality data for: Lat=13.444304, Lon=144.793731
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=13.444304, Lon=144.793731
# Fetching air quality data for: Lat=11.803749, Lon=-15.180413
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=11.803749, Lon=-15.180413
# Fetching air quality data for: Lat=4.860416, Lon=-58.93018
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=4.860416, Lon=-58.93018
# Fetching air quality data for: Lat=31.354676, Lon=34.308825
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=31.354676, Lon=34.308825
# Fetching air quality data for: Lat=22.396428, Lon=114.109497
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=22.396428, Lon=114.109497
# Fetching air quality data for: Lat=-53.08181, Lon=73.504158
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-53.08181, Lon=73.504158
# Fetching air quality data for: Lat=15.199999, Lon=-86.241905
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=15.199999, Lon=-86.241905
# Fetching air quality data for: Lat=45.1, Lon=15.2
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=45.1, Lon=15.2
# Fetching air quality data for: Lat=18.971187, Lon=-72.285215
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=18.971187, Lon=-72.285215
# Fetching air quality data for: Lat=47.162494, Lon=19.503304
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=47.162494, Lon=19.503304
# Fetching air quality data for: Lat=-0.789275, Lon=113.921327
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-0.789275, Lon=113.921327
# Fetching air quality data for: Lat=53.41291, Lon=-8.24389
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=53.41291, Lon=-8.24389
# Fetching air quality data for: Lat=31.046051, Lon=34.851612
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=31.046051, Lon=34.851612
# Fetching air quality data for: Lat=54.236107, Lon=-4.548056
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=54.236107, Lon=-4.548056
# Fetching air quality data for: Lat=20.593684, Lon=78.96288
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=20.593684, Lon=78.96288
# Fetching air quality data for: Lat=-6.343194, Lon=71.876519
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-6.343194, Lon=71.876519
# Fetching air quality data for: Lat=33.223191, Lon=43.679291
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=33.223191, Lon=43.679291
# Fetching air quality data for: Lat=32.427908, Lon=53.688046
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=32.427908, Lon=53.688046
# Fetching air quality data for: Lat=64.963051, Lon=-19.020835
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=64.963051, Lon=-19.020835
# Fetching air quality data for: Lat=41.87194, Lon=12.56738
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=41.87194, Lon=12.56738
# Fetching air quality data for: Lat=49.214439, Lon=-2.13125
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=49.214439, Lon=-2.13125
# Fetching air quality data for: Lat=18.109581, Lon=-77.297508
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=18.109581, Lon=-77.297508
# Fetching air quality data for: Lat=30.585164, Lon=36.238414
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=30.585164, Lon=36.238414
# Fetching air quality data for: Lat=36.204824, Lon=138.252924
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=36.204824, Lon=138.252924
# Fetching air quality data for: Lat=-0.023559, Lon=37.906193
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-0.023559, Lon=37.906193
# Fetching air quality data for: Lat=41.20438, Lon=74.766098
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=41.20438, Lon=74.766098
# Fetching air quality data for: Lat=12.565679, Lon=104.990963
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=12.565679, Lon=104.990963
# Fetching air quality data for: Lat=-3.370417, Lon=-168.734039
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-3.370417, Lon=-168.734039
# Fetching air quality data for: Lat=-11.875001, Lon=43.872219
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-11.875001, Lon=43.872219
# Fetching air quality data for: Lat=17.357822, Lon=-62.782998
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=17.357822, Lon=-62.782998
# Fetching air quality data for: Lat=40.339852, Lon=127.510093
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=40.339852, Lon=127.510093
# Fetching air quality data for: Lat=35.907757, Lon=127.766922
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=35.907757, Lon=127.766922
# Fetching air quality data for: Lat=29.31166, Lon=47.481766
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=29.31166, Lon=47.481766
# Fetching air quality data for: Lat=19.513469, Lon=-80.566956
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=19.513469, Lon=-80.566956
# Fetching air quality data for: Lat=48.019573, Lon=66.923684
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=48.019573, Lon=66.923684
# Fetching air quality data for: Lat=19.85627, Lon=102.495496
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=19.85627, Lon=102.495496
# Fetching air quality data for: Lat=33.854721, Lon=35.862285
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=33.854721, Lon=35.862285
# Fetching air quality data for: Lat=13.909444, Lon=-60.978893
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=13.909444, Lon=-60.978893
# Fetching air quality data for: Lat=47.166, Lon=9.555373
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=47.166, Lon=9.555373
# Fetching air quality data for: Lat=7.873054, Lon=80.771797
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=7.873054, Lon=80.771797
# Fetching air quality data for: Lat=6.428055, Lon=-9.429499
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=6.428055, Lon=-9.429499
# Fetching air quality data for: Lat=-29.609988, Lon=28.233608
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-29.609988, Lon=28.233608
# Fetching air quality data for: Lat=55.169438, Lon=23.881275
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=55.169438, Lon=23.881275
# Fetching air quality data for: Lat=49.815273, Lon=6.129583
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=49.815273, Lon=6.129583
# Fetching air quality data for: Lat=56.879635, Lon=24.603189
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=56.879635, Lon=24.603189
# Fetching air quality data for: Lat=26.3351, Lon=17.228331
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=26.3351, Lon=17.228331
# Fetching air quality data for: Lat=31.791702, Lon=-7.09262
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=31.791702, Lon=-7.09262
# Fetching air quality data for: Lat=43.750298, Lon=7.412841
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=43.750298, Lon=7.412841
# Fetching air quality data for: Lat=47.411631, Lon=28.369885
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=47.411631, Lon=28.369885
# Fetching air quality data for: Lat=42.708678, Lon=19.37439
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=42.708678, Lon=19.37439
# Fetching air quality data for: Lat=-18.766947, Lon=46.869107
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-18.766947, Lon=46.869107
# Fetching air quality data for: Lat=7.131474, Lon=171.184478
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=7.131474, Lon=171.184478
# Fetching air quality data for: Lat=41.608635, Lon=21.745275
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=41.608635, Lon=21.745275
# Fetching air quality data for: Lat=17.570692, Lon=-3.996166
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=17.570692, Lon=-3.996166
# Fetching air quality data for: Lat=21.913965, Lon=95.956223
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=21.913965, Lon=95.956223
# Fetching air quality data for: Lat=46.862496, Lon=103.846656
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=46.862496, Lon=103.846656
# Fetching air quality data for: Lat=22.198745, Lon=113.543873
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=22.198745, Lon=113.543873
# Fetching air quality data for: Lat=17.33083, Lon=145.38469
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=17.33083, Lon=145.38469
# Fetching air quality data for: Lat=14.641528, Lon=-61.024174
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=14.641528, Lon=-61.024174
# Fetching air quality data for: Lat=21.00789, Lon=-10.940835
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=21.00789, Lon=-10.940835
# Fetching air quality data for: Lat=16.742498, Lon=-62.187366
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=16.742498, Lon=-62.187366
# Fetching air quality data for: Lat=35.937496, Lon=14.375416
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=35.937496, Lon=14.375416
# Fetching air quality data for: Lat=-20.348404, Lon=57.552152
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-20.348404, Lon=57.552152
# Fetching air quality data for: Lat=3.202778, Lon=73.22068
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=3.202778, Lon=73.22068
# Fetching air quality data for: Lat=-13.254308, Lon=34.301525
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-13.254308, Lon=34.301525
# Fetching air quality data for: Lat=23.634501, Lon=-102.552784
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=23.634501, Lon=-102.552784
# Fetching air quality data for: Lat=4.210484, Lon=101.975766
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=4.210484, Lon=101.975766
# Fetching air quality data for: Lat=-18.665695, Lon=35.529562
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-18.665695, Lon=35.529562
# Fetching air quality data for: Lat=-22.95764, Lon=18.49041
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-22.95764, Lon=18.49041
# Fetching air quality data for: Lat=-20.904305, Lon=165.618042
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-20.904305, Lon=165.618042
# Fetching air quality data for: Lat=17.607789, Lon=8.081666
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=17.607789, Lon=8.081666
# Fetching air quality data for: Lat=-29.040835, Lon=167.954712
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-29.040835, Lon=167.954712
# Fetching air quality data for: Lat=9.081999, Lon=8.675277
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=9.081999, Lon=8.675277
# Fetching air quality data for: Lat=12.865416, Lon=-85.207229
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=12.865416, Lon=-85.207229
# Fetching air quality data for: Lat=52.132633, Lon=5.291266
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=52.132633, Lon=5.291266
# Fetching air quality data for: Lat=60.472024, Lon=8.468946
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=60.472024, Lon=8.468946
# Fetching air quality data for: Lat=28.394857, Lon=84.124008
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=28.394857, Lon=84.124008
# Fetching air quality data for: Lat=-0.522778, Lon=166.931503
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-0.522778, Lon=166.931503
# Fetching air quality data for: Lat=-19.054445, Lon=-169.867233
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-19.054445, Lon=-169.867233
# Fetching air quality data for: Lat=-40.900557, Lon=174.885971
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-40.900557, Lon=174.885971
# Fetching air quality data for: Lat=21.512583, Lon=55.923255
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=21.512583, Lon=55.923255
# Fetching air quality data for: Lat=8.537981, Lon=-80.782127
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=8.537981, Lon=-80.782127
# Fetching air quality data for: Lat=-9.189967, Lon=-75.015152
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-9.189967, Lon=-75.015152
# Fetching air quality data for: Lat=-17.679742, Lon=-149.406843
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-17.679742, Lon=-149.406843
# Fetching air quality data for: Lat=-6.314993, Lon=143.95555
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-6.314993, Lon=143.95555
# Fetching air quality data for: Lat=12.879721, Lon=121.774017
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=12.879721, Lon=121.774017
# Fetching air quality data for: Lat=30.375321, Lon=69.345116
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=30.375321, Lon=69.345116
# Fetching air quality data for: Lat=51.919438, Lon=19.145136
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=51.919438, Lon=19.145136
# Fetching air quality data for: Lat=46.941936, Lon=-56.27111
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=46.941936, Lon=-56.27111
# Fetching air quality data for: Lat=-24.703615, Lon=-127.439308
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-24.703615, Lon=-127.439308
# Fetching air quality data for: Lat=18.220833, Lon=-66.590149
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=18.220833, Lon=-66.590149
# Fetching air quality data for: Lat=31.952162, Lon=35.233154
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=31.952162, Lon=35.233154
# Fetching air quality data for: Lat=39.399872, Lon=-8.224454
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=39.399872, Lon=-8.224454
# Fetching air quality data for: Lat=7.51498, Lon=134.58252
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=7.51498, Lon=134.58252
# Fetching air quality data for: Lat=-23.442503, Lon=-58.443832
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-23.442503, Lon=-58.443832
# Fetching air quality data for: Lat=25.354826, Lon=51.183884
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=25.354826, Lon=51.183884
# Fetching air quality data for: Lat=-21.115141, Lon=55.536384
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-21.115141, Lon=55.536384
# Fetching air quality data for: Lat=45.943161, Lon=24.96676
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=45.943161, Lon=24.96676
# Fetching air quality data for: Lat=44.016521, Lon=21.005859
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=44.016521, Lon=21.005859
# Fetching air quality data for: Lat=61.52401, Lon=105.318756
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=61.52401, Lon=105.318756
# Fetching air quality data for: Lat=-1.940278, Lon=29.873888
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-1.940278, Lon=29.873888
# Fetching air quality data for: Lat=23.885942, Lon=45.079162
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=23.885942, Lon=45.079162
# Fetching air quality data for: Lat=-9.64571, Lon=160.156194
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-9.64571, Lon=160.156194
# Fetching air quality data for: Lat=-4.679574, Lon=55.491977
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-4.679574, Lon=55.491977
# Fetching air quality data for: Lat=12.862807, Lon=30.217636
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=12.862807, Lon=30.217636
# Fetching air quality data for: Lat=60.128161, Lon=18.643501
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=60.128161, Lon=18.643501
# Fetching air quality data for: Lat=1.352083, Lon=103.819836
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=1.352083, Lon=103.819836
# Fetching air quality data for: Lat=-24.143474, Lon=-10.030696
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-24.143474, Lon=-10.030696
# Fetching air quality data for: Lat=46.151241, Lon=14.995463
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=46.151241, Lon=14.995463
# Fetching air quality data for: Lat=77.553604, Lon=23.670272
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=77.553604, Lon=23.670272
# Fetching air quality data for: Lat=48.669026, Lon=19.699024
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=48.669026, Lon=19.699024
# Fetching air quality data for: Lat=8.460555, Lon=-11.779889
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=8.460555, Lon=-11.779889
# Fetching air quality data for: Lat=43.94236, Lon=12.457777
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=43.94236, Lon=12.457777
# Fetching air quality data for: Lat=14.497401, Lon=-14.452362
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=14.497401, Lon=-14.452362
# Fetching air quality data for: Lat=5.152149, Lon=46.199616
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=5.152149, Lon=46.199616
# Fetching air quality data for: Lat=3.919305, Lon=-56.027783
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=3.919305, Lon=-56.027783
# Fetching air quality data for: Lat=0.18636, Lon=6.613081
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=0.18636, Lon=6.613081
# Fetching air quality data for: Lat=13.794185, Lon=-88.89653
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=13.794185, Lon=-88.89653
# Fetching air quality data for: Lat=34.802075, Lon=38.996815
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=34.802075, Lon=38.996815
# Fetching air quality data for: Lat=-26.522503, Lon=31.465866
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-26.522503, Lon=31.465866
# Fetching air quality data for: Lat=21.694025, Lon=-71.797928
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=21.694025, Lon=-71.797928
# Fetching air quality data for: Lat=15.454166, Lon=18.732207
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=15.454166, Lon=18.732207
# Fetching air quality data for: Lat=-49.280366, Lon=69.348557
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-49.280366, Lon=69.348557
# Fetching air quality data for: Lat=8.619543, Lon=0.824782
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=8.619543, Lon=0.824782
# Fetching air quality data for: Lat=15.870032, Lon=100.992541
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=15.870032, Lon=100.992541
# Fetching air quality data for: Lat=38.861034, Lon=71.276093
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=38.861034, Lon=71.276093
# Fetching air quality data for: Lat=-8.967363, Lon=-171.855881
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-8.967363, Lon=-171.855881
# Fetching air quality data for: Lat=-8.874217, Lon=125.727539
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-8.874217, Lon=125.727539
# Fetching air quality data for: Lat=38.969719, Lon=59.556278
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=38.969719, Lon=59.556278
# Fetching air quality data for: Lat=33.886917, Lon=9.537499
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=33.886917, Lon=9.537499
# Fetching air quality data for: Lat=-21.178986, Lon=-175.198242
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-21.178986, Lon=-175.198242
# Fetching air quality data for: Lat=38.963745, Lon=35.243322
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=38.963745, Lon=35.243322
# Fetching air quality data for: Lat=10.691803, Lon=-61.222503
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=10.691803, Lon=-61.222503
# Fetching air quality data for: Lat=-7.109535, Lon=177.64933
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-7.109535, Lon=177.64933
# Fetching air quality data for: Lat=23.69781, Lon=120.960515
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=23.69781, Lon=120.960515
# Fetching air quality data for: Lat=-6.369028, Lon=34.888822
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-6.369028, Lon=34.888822
# Fetching air quality data for: Lat=48.379433, Lon=31.16558
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=48.379433, Lon=31.16558
# Fetching air quality data for: Lat=1.373333, Lon=32.290275
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=1.373333, Lon=32.290275
# Fetching air quality data for: Lat=37.09024, Lon=-95.712891
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=37.09024, Lon=-95.712891
# Fetching air quality data for: Lat=-32.522779, Lon=-55.765835
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-32.522779, Lon=-55.765835
# Fetching air quality data for: Lat=41.377491, Lon=64.585262
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=41.377491, Lon=64.585262
# Fetching air quality data for: Lat=41.902916, Lon=12.453389
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=41.902916, Lon=12.453389
# Fetching air quality data for: Lat=12.984305, Lon=-61.287228
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=12.984305, Lon=-61.287228
# Fetching air quality data for: Lat=6.42375, Lon=-66.58973
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=6.42375, Lon=-66.58973
# Fetching air quality data for: Lat=18.420695, Lon=-64.639968
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=18.420695, Lon=-64.639968
# Fetching air quality data for: Lat=18.335765, Lon=-64.896335
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=18.335765, Lon=-64.896335
# Fetching air quality data for: Lat=14.058324, Lon=108.277199
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=14.058324, Lon=108.277199
# Fetching air quality data for: Lat=-15.376706, Lon=166.959158
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-15.376706, Lon=166.959158
# Fetching air quality data for: Lat=-13.768752, Lon=-177.156097
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-13.768752, Lon=-177.156097
# Fetching air quality data for: Lat=-13.759029, Lon=-172.104629
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-13.759029, Lon=-172.104629
# Fetching air quality data for: Lat=42.602636, Lon=20.902977
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=42.602636, Lon=20.902977
# Fetching air quality data for: Lat=15.552727, Lon=48.516388
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=15.552727, Lon=48.516388
# Fetching air quality data for: Lat=-12.8275, Lon=45.166244
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-12.8275, Lon=45.166244
# Fetching air quality data for: Lat=-30.559482, Lon=22.937506
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-30.559482, Lon=22.937506
# Fetching air quality data for: Lat=-13.133897, Lon=27.849332
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-13.133897, Lon=27.849332
# Fetching air quality data for: Lat=-19.015438, Lon=29.154857
# ⚠️ No daily data. Trying hourly data instead...
# ❌ No air quality data found for Lat=-19.015438, Lon=29.154857
# Data collection complete. Results saved to air_quality_2023.csv

# %%
# Wait 2 seconds between each request
import time
time.sleep(2)

# %%
# Retrieve average air quality from https://air-quality-api.open-meteo.com per country for 2023

def get_air_quality(lat, lon):
    """Fetches air quality data, ensuring we capture any missing or partial data issues."""
    print(f"Fetching data for: Lat={lat}, Lon={lon}")

    url = "https://air-quality-api.open-meteo.com/v1/air-quality"

    params = {
        "latitude": lat,
        "longitude": lon,
        "start_date": "2023-01-01",
        "end_date": "2023-12-31",
        "daily": ["pm10", "pm2_5", "no2", "so2", "o3"],
        "timezone": "UTC"
    }

    response = requests.get(url, params=params)
    if response.status_code != 200:
        print(f"❌ Error {response.status_code}: No data for {lat}, {lon}")
        return None, None, None, None, None

    data = response.json()
    print(f"📊 Full response for {lat}, {lon}: {data}")

    if "daily" in data and any(p in data["daily"] for p in ["pm10", "pm2_5", "no2", "so2", "o3"]):
        print(f"✅ Using daily data for {lat}, {lon}")
        daily_data = data["daily"]
        pollutants = ["pm10", "pm2_5", "no2", "so2", "o3"]
        averages = [sum(daily_data.get(p, [])) / len(daily_data.get(p, [])) if daily_data.get(p) else None for p in pollutants]
        return tuple(averages)
    
    print(f"⚠️ No daily data for {lat}, {lon}. Trying hourly...")
    params["hourly"] = ["pm10", "pm2_5", "no2", "so2", "o3"]
    del params["daily"]

    response = requests.get(url, params=params)
    data = response.json()
    print(f"📊 Full hourly response for {lat}, {lon}: {data}")

    if "hourly" in data and any(p in data["hourly"] for p in ["pm10", "pm2_5", "no2", "so2", "o3"]):
        print(f"✅ Using hourly data for {lat}, {lon}")
        hourly_data = data["hourly"]
        pollutants = ["pm10", "pm2_5", "no2", "so2", "o3"]
        averages = [sum(hourly_data.get(p, [])) / len(hourly_data.get(p, [])) if hourly_data.get(p) else None for p in pollutants]
        return tuple(averages)

    print(f"❌ No air quality data for {lat}, {lon}")
    return None, None, None, None, None

# %%
df_countries
# Out:
#     country_abbr   latitude  longitude          country_name avg_pm10  \
# 0             AD  42.546245   1.601554               Andorra     None
# 1             AE  23.424076  53.847818  United Arab Emirates     None
# 2             AF  33.939110  67.709953           Afghanistan     None
# 3             AG  17.060816 -61.796428   Antigua and Barbuda     None
# 4             AI  18.220554 -63.068615              Anguilla     None
# ..           ...        ...        ...                   ...      ...
# 239           YE  15.552727  48.516388                 Yemen     None
# 240           YT -12.827500  45.166244               Mayotte     None
# 241           ZA -30.559482  22.937506          South Africa     None
# 242           ZM -13.133897  27.849332                Zambia     None
# 243           ZW -19.015438  29.154857              Zimbabwe     None
#
#     avg_pm2_5 avg_no2 avg_so2 avg_o3
# 0        None    None    None   None
# 1        None    None    None   None
# 2        None    None    None   None
# 3        None    None    None   None
# 4        None    None    None   None
# ..        ...     ...     ...    ...
# 239      None    None    None   None
# 240      None    None    None   None
# 241      None    None    None   None
# 242      None    None    None   None
# 243      None    None    None   None
#
# [244 rows x 9 columns]

# %%
# Verify If the API Is Providing Data for the Specified Dates
# Some locations may not have complete air quality records for all of 2023. Try a shorter date range.

# %%
# This approach does not work at all, because OpenMeteo gives AQI values for the specific location with in the country.
# Rather use Webscraping of IQAIR homepage, which gives a list of averaged data per country for 2023.

import requests
from bs4 import BeautifulSoup
import csv

url2 = "https://www.iqair.com/us/world-most-polluted-countries"

# %%
# Function for web scraping IQAIR for air pollution values:

def scrape_iqair_pm25():
    url2 = "https://www.iqair.com/us/world-most-polluted-countries"
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}
    
    response = requests.get(url2, headers=headers)
    if response.status_code != 200:
        print(f"Failed to retrieve data: {response.status_code}")
        return
    
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find the table containing pollution data
    table = soup.find("table")
    if not table:
        print("Could not find the data table.")
        return
    
    # Extract table headers (optional)
    headers = [header.text.strip() for header in table.find_all("th")]
    
    # Extract table rows
    rows = table.find_all("tr")[1:]  # Skip header row
    
    data = []
    for row in rows:
        cols = row.find_all("td")
        if len(cols) >= 2:  # Ensure at least country and PM2.5 value exist
            country = cols[1].text.strip()
            pm25_value = cols[2].text.strip()
            data.append([country, pm25_value])
    
    # Save to CSV
    with open("iqair_pm25_2023.csv", "w", newline="", encoding="utf-8") as file:
        writer = csv.writer(file)
        writer.writerow(["Country/Region", "PM2.5 (µg/m³)"])
        writer.writerows(data)
    
    print("Data successfully scraped and saved to iqair_pm25_2023.csv")

if __name__ == "__main__":
    scrape_iqair_pm25()
# Out:
# Data successfully scraped and saved to iqair_pm25_2023.csv

# %%
# Obtain Population density data:

# URL of the website
url3 = 'https://database.earth/population/density/2023'

# Send a GET request to the website
response = requests.get(url3)
response.raise_for_status()  # Check for request errors

# Parse the HTML content
soup = BeautifulSoup(response.text, 'html.parser')

# Find the table containing the data
table = soup.find('table')

# Initialize a list to store the data
data = []

# Extract table headers
headers = ['Country', 'Population Density (people/km²)']

# Iterate over table rows
for row in table.find_all('tr')[1:]:  # Skip the header row
    cols = row.find_all('td')
    if len(cols) >= 3:
        country = cols[1].text.strip()
        density = cols[2].text.strip()
        data.append([country, density])

# Save the data to a CSV file
csv_filename = 'population_density_2023.csv'
with open(csv_filename, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(headers)  # Write headers
    writer.writerows(data)  # Write data

print(f'Data saved to {csv_filename}')
# Out:
# Data saved to population_density_2023.csv

# %%
# Urbanization Rate - Web scraping:

# URL of the website
url4 = "https://worldpopulationreview.com/country-rankings/most-urbanized-countries"

# Send GET request
headers = {"User-Agent": "Mozilla/5.0"}  # Adding headers to mimic a browser request
response = requests.get(url4, headers=headers)

# Check if request was successful
if response.status_code == 200:
    # Parse the page content
    soup = BeautifulSoup(response.text, "html.parser")
    
    # Find the table containing the data
    table = soup.find("table")
    
    # Extract table headers
    headers = [header.text.strip() for header in table.find_all("th")]
    
    # Extract table rows
    data = []
    for row in table.find_all("tr")[1:]:  # Skip header row
        cols = row.find_all("td")
        if cols:
            country = cols[0].text.strip()
            urbanization_rate = cols[1].text.strip().replace("%", "")  # Remove percentage sign
            data.append([country, float(urbanization_rate)])
    
    # Convert to DataFrame
    df = pd.DataFrame(data, columns=["Country", "Urbanization Rate (%)"])
    
    # Display the first few rows
    print(df.head())
    
    # Save to CSV (optional)
    df.to_csv("urbanization_rates_2023.csv", index=False)
    
else:
    print("Failed to retrieve data, status code:", response.status_code)

# Does not work, cause there is no table, but a map, which cannot be scraped
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[145], line 27
#      25     if cols:
#      26         country = cols[0].text.strip()
# ---> 27         urbanization_rate = cols[1].text.strip().replace("%", "")  # Remove percentage sign
#      28         data.append([country, float(urbanization_rate)])
#      30 # Convert to DataFrame
#
# IndexError: list index out of range
